# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Seaborn

# %% [markdown]
# `Seaborn` is a higher level library built on top of `Matplotlib` and `pandas` to create statistical visualizations and (in many people opinions) give a better set of default style parameters to basic `Matplotlib` functionality.  The `sns.set()` command in the beginning of the notebook sets these parameters.
#
#
# <a href="https://seaborn.pydata.org/tutorial.html">Seaborn: User guide and tutorial</a>
#
# <a href="https://seaborn.pydata.org/api.html">Seaborn API</a>

# %% [markdown]
# ## Cheat Sheet

# %% [markdown]
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf

# %%
import seaborn as sns

flights=sns.load_dataset('flights')
iris= sns.load_dataset('iris')
tips= sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')
print(flights.head())
print(iris.head())
print(tips.head())
print(titanic.head())
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set()
sns.set_style('whitegrid')
g3 = sns.lmplot(x='tip', y='total_bill',data=tips, aspect=2)
plt.show(g3)

# %% [markdown]
# #### Other types of plots:
#
# • Factorplot
# • Stripplot
# • Swarmplot
# • Barplot
# • Countplot
# • Pointplot
# • Boxplot
# • Violinplot
#
# <a href="https://seaborn.pydata.org/examples/index.html">Examples</a>

# %%
## Plot data and a linear regression model fit.

x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

# Initialize figure and ax
fig, ax = plt.subplots()

# Set the scale of the x-and y-axes
ax.set(xscale="log", yscale="log")

# Create a regplot
sns.regplot("x", "y", data, ax=ax, scatter_kws={"s": 100},fit_reg=False)

# Show plot
plt.show()

# %%
## Plot data and a linear regression model fit.
sns.regplot(x=iris['sepal_length'],
 y=iris['sepal_width'], fit_reg=True)
plt.show()

# %%
## Plot data and regression model fits across a FacetGrid.
sns.lmplot(data=iris, x='sepal_length',
 y='sepal_width', hue='species', fit_reg=True)
plt.show()

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
## Scatterplot with varying point sizes and hues

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)

# %% [markdown]
# Scatter plots are highly effective, but there is no universally optimal type of visualisation. Instead, the visual representation should be adapted for the specifics of the dataset and to the question you are trying to answer with the plot.
#
# With some datasets, you may want to understand changes in one variable as a function of time, or a similarly continuous variable. In this situation, a good choice is to draw a line plot. In seaborn, this can be accomplished by the `lineplot()` function, either directly or with relplot() by setting `kind="line"`

# %%
#It may be used to examine the brain's functional anatomy, 
#(determine which parts of the brain are handling critical functions), 
#evaluate the effects of stroke or other disease, or to guide brain treatment. 
#fMRI may detect abnormalities within the brain that cannot be found with other 
#imaging techniques, more here: https://github.com/mwaskom/Waskom_CerebCortex_2017

fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", estimator=None, data=fmri);

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region",
            units="subject", estimator=None,
            kind="line", data=fmri.query("event == 'stim'"));

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            kind="line", data=dots);

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
## Scatterplot with varying point sizes and hues

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)

# %%
fig, ax = plt.subplots()

# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create violinplot
ax.violinplot(tips["total_bill"], vert=True)

# Show the plot
plt.show()

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Draw a categorical scatterplot with non-overlapping points

sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()
# Out:
# C:\Users\sarma\Anaconda3\envs\py-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# color palette: https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
from matplotlib.colors import ListedColormap

N = 500

# Construct the colormap
current_palette = sns.color_palette("muted", n_colors=5)

# Color hex is a easy to use tool to get the color codes
# information including color models (RGB,HSL,HSV and CMYK), 
# css and html color codes.
cmap = ListedColormap(sns.color_palette(current_palette).as_hex())

# Initialize the data
data1 = np.random.randn(N)
data2 = np.random.randn(N)
# Assume that there are 5 possible labels
colors = np.random.randint(0,5,N)

# Create a scatter plot
plt.scatter(data1, data2, c=colors, cmap=cmap)

# Add a color bar
plt.colorbar()

# Show the plot
plt.show()

# %%
## Factor plot is informative when we have multiple groups to compare. 

titanic = sns.load_dataset("titanic")

g = sns.factorplot("class", "survived", "sex",
                   data=titanic, kind="bar",  #{point, bar, count, box, violin, strip}
                   size=6, palette="muted",
                   legend=False)
g.despine(left=True)
plt.legend(loc='upper left')
g.set_ylabels("survival probability")
# Out:
# C:\Users\sarma\Anaconda3\envs\py-env\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\sarma\Anaconda3\envs\py-env\lib\site-packages\seaborn\categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\sarma\Anaconda3\envs\py-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### FacetGrid and PairGrid

# %% [markdown]
# We can use a `FacetGrid` to plot the data in a grid with a plot for each categorical variable.  We will give the `FacetGrid` `col` and `row` arguments to specify which category should represent each column and row respectively.
#
# Just creating the `FacetGrid` creates a plotting grid, but if we want to put some data on the plots, we need to specify which plotting function we want applied to each subset of the data (filtered by row and column).  We can do this by using the `map` method of the `FacetGrid`.

# %%
from datetime import datetime
def get_quarter(x):
    if x < 4 :
        return 1
    elif x < 7:
        return 2
    elif x < 10:
        return 3
    else:
        return 4
df = pd.read_csv('flights14.csv')
# restrict to largest carriers
df = df[df['carrier'].isin(df['carrier'].value_counts().index[:4])]
df['quarter'] = df['month'].apply(get_quarter)
df.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2014      1    1       1.0       96.0     235.0       70.0      AS  N508AS
# 2  2014      1    1       8.0       13.0     548.0       -4.0      UA  N37422
# 4  2014      1    1      34.0       44.0     325.0       43.0      AS  N762AS
# 6  2014      1    1     346.0      227.0     936.0      219.0      UA  N14219
# 7  2014      1    1     526.0       -4.0    1148.0       15.0      UA  N813UA
#
#    flight origin dest  air_time  distance  hour  minute  quarter
# 0   145.0    PDX  ANC     194.0    1542.0   0.0     1.0        1
# 2  1609.0    PDX  IAH     201.0    1825.0   0.0     8.0        1
# 4   121.0    SEA  ANC     201.0    1448.0   0.0    34.0        1
# 6  1481.0    SEA  ORD     202.0    1721.0   3.0    46.0        1
# 7   229.0    PDX  IAH     217.0    1825.0   5.0    26.0        1

# %%
#df.query("carrier=='AS'")['dep_delay'].hist(bins=50)
np.log10(df.query("carrier=='AS'")['dep_delay']+100).hist()
# Out:
# <AxesSubplot:>

# %%
g = sns.FacetGrid(df, row='carrier', col='quarter')
g.map(plt.hist, "dep_delay")
plt.tight_layout()

# %% [markdown]
# We can also do other types of plots, good examples can be found in the [Gallery](https://seaborn.pydata.org/examples/index.html).  For example let's take a look at a box plot broken up by quarter and origin for a few different airports.  Here we will only look at the "non-extreme" delays of less than an hour.

# %%
g

# %%
sns.boxplot(x='quarter', 
            hue='origin', 
            y='dep_delay',showfliers=False ,
            data=df[df['arr_delay'] < 60])
# Out:
# <AxesSubplot:xlabel='quarter', ylabel='dep_delay'>

# %%
ax=sns.boxplot(x='quarter', 
            hue='origin', 
            y='dep_delay', 
            flierprops = dict(markerfacecolor = '0.50', markersize = 0),
            data=df[df['arr_delay'] < 60])

ax.set_ylim([-35, 35])
ax.legend(loc='lower left')

# %% [markdown]
# We can also do cool things like create a `PairGrid` to look at distributions and relationships between different variables.

# %%
penguins = sns.load_dataset("penguins")

g = sns.PairGrid(penguins, hue="species", corner=True)
g.map_diag(plt.hist)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
(sns.PairGrid(df[['dep_delay', 'arr_delay']].iloc[:500], diag_sharey=True)
  .map_diag(plt.hist, lw=3, bins=20)
  .map_upper(sns.scatterplot)
  .map_lower(sns.kdeplot))

# %% [markdown]
# Much more customization is possible in both `Matplotlib` and libraries built upon it such as `Seaborn`.  They are effective tools to represent data in a useful way.

# %%
sns.set_style('whitegrid')
#sns.PairGrid(iris).map(plt.scatter)
sns.pairplot(iris)
plt.show()

# %% [markdown]
# ### methods: https://seaborn.pydata.org/generated/seaborn.PairGrid.html

# %% [markdown]
# #### Hacking PairGrids (more on this topic: https://catherineh.github.io/programming/2016/05/24/seaborn-pairgrid-tips)

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)

iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue='species')
replacements = {'sepal_length': r'$\alpha$', 'sepal_width': 'sepal',
                'petal_length': r'$\beta$', 'petal_width': 'petal',
                'versicolor': 'bloop'}

for i in range(4):
    for j in range(4):
        xlabel = g.axes[i][j].get_xlabel()
        ylabel = g.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel])
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel])

# %%
house_data_df = pd.read_csv('house_data.csv')
house_data_df.set_index('id',inplace=True)
corr_to_price = house_data_df.corr().sort_values('price', ascending=False)
display(corr_to_price["price"].reset_index())
# Out:
#             index     price
# 0           price  1.000000
# 1     sqft_living  0.702035
# 2           grade  0.667434
# 3      sqft_above  0.605567
# 4   sqft_living15  0.585379
# 5       bathrooms  0.525138
# 6            view  0.397293
# 7   sqft_basement  0.323816
# 8        bedrooms  0.308350
# 9             lat  0.307003
# 10     waterfront  0.266369
# 11         floors  0.256794
# 12   yr_renovated  0.126434
# 13       sqft_lot  0.089661
# 14     sqft_lot15  0.082447
# 15       yr_built  0.054012
# 16      condition  0.036362
# 17           long  0.021626
# 18        zipcode -0.053203

# %%
house_data_df[['price','view']].boxplot(by='view',showfliers=False)
plt.tight_layout()

# %%
sns.set_context('talk')
plt.figure(figsize=(15,10))
plt.plot(corr_to_price["price"])
plt.title('Correlation of Parameters to Price')
plt.xlabel('Parameter')
plt.ylabel('Correlation')
plt.xticks(rotation=45)
plt.show()
