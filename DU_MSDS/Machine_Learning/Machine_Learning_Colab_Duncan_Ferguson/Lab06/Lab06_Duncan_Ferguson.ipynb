# %% [markdown]
# # Objectives
# - 1). Understand how the various hyperparameters and vectorization methods used in LDA change the category labels that are generated for a given text corpus
# - 2). Compare the results of LDA using different hyperparamter and vectorization settings, and describe what relationship is being represented by the generated category labels

# %% [markdown]
# # Step 1: Compy the code blocks "Topic modeling section of the ch08 exampl into lab.
# - Note Make Sure that lab06 is in the same folder as cha08 ipny so that it can access needed files

# %% [markdown]
# # Step 2 Modify the read
# - df = pd.read_csv(google_file_prefix + 'movie_data.csv', encoding='utf-8')

# %% [markdown]
# # Step 3
# - Set the number of topics being calcuated to 15 by changing the n_compents property of the LatentDirichletAllocation initializer to n_compenents15

# %% [markdown]
# - 1). Answer the following questions about the generated topics:
# -- 1). Do the first 10 topics in the list change from what was genreated previously?
# -- 2). What categories are the 15 generated topics most likely representing? Are there meaningful relationships being demonstrated?
# - Note ceah latentDirichletAllocation execution will take a few minutes to complete, so be patient while running them

# %% [markdown]
# # Step 4
# - Look at the maximum document frequency (max_df) and the number of words to be considered (max_features) used by the CountVectorizer that feeds the LatentDirchletAllocation algorithm

# %% [markdown]
# # Step 5
# - Currently max_df=.1 and max_features=5000. What ahppens if I change those values? Runn four different tests with each one tuning these values slighlty differentlyt, to see how it impacts the results of the LDA analysis:
# - 1). Test 1 - max_df and max_features are both set to a lower value
# - 2). Test 2 - max_df and max_features are both set to a higher value
# - 3). Test 3 - max_df is set lower and max_features is set higher
# - 4). Test 4 - max_df is set higher, and max_features is set lower
# - For each of the test result above, document what changes (if any) were observed in the generated list of 15 topics.
# - Examplain if my observations what the impact of changing max_df and max_features settings is to the data that will be considered in each test

# %% [markdown]
# # Step 6.
# - Explore batch vs online learning methods for LatentDirichletAllocation.
# - Set CountVectorizer to its original settings of max_df=.1 and max_features=5000 and run two tests, one with  LatentDirchletAllocation inialized with learning_method='batch; and one with learning_method='online'

# %% [markdown]
# # Step 7
# - Do the lists of 15 topics created by the LDA differ between these two learning methods? If so, what are the differences? Did learning_method='online' run faster than learning_method='batch'
