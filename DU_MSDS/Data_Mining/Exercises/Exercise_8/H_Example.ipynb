# %%
import pandas as pd
import numpy as np
import random as rd


dataset = pd.read_csv('exercise8_infile1.csv')
# print(dataset.describe())

X = dataset.values

# %%
m=X.shape[0] #number of training examples
n=X.shape[1] #number of features. Here n=3

# %%
n_iter = 100

K = 3 #number of clusters

rd.seed(0)

Centroids=np.array([]).reshape(n,0)
Centroids
# Out:
# array([], shape=(3, 0), dtype=float64)

# %%
for i in range(K):
    rand=rd.randint(0,m-1)
    Centroids=np.c_[Centroids, X[rand]]

Centroids
# Out:
# array([[30.96752128, 20.50786733, 22.58645177],
#        [27.96099865, 21.6644563 , 23.53520191],
#        [30.42075504, 19.59854475, 18.42445252]])

# %%
Output={}

EuclidianDistance=np.array([]).reshape(m,0)
EuclidianDistance
# Out:
# array([], shape=(100, 0), dtype=float64)

# %%
for k in range(K):
    tempDist=np.sum((X-Centroids[:,k])**2,axis=1)
    EuclidianDistance=np.c_[EuclidianDistance,tempDist]
C=np.argmin(EuclidianDistance,axis=1)+1
C
# Out:
# array([2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1,
#        2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2,
#        2, 1, 2, 2, 1, 1, 1, 1, 2, 3, 1, 2, 2, 1, 1, 2, 1, 3, 2, 1, 2, 1,
#        2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 1, 2, 1, 2, 2, 2, 1,
#        2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 1], dtype=int64)

# %%
Y = {}
for k in range(K):
    Y[k + 1] = np.array([]).reshape(3, 0)
Y
# Out:
# {1: array([], shape=(3, 0), dtype=float64),
#  2: array([], shape=(3, 0), dtype=float64),
#  3: array([], shape=(3, 0), dtype=float64)}

# %%
for i in range(m):
    Y[C[i]] = np.c_[Y[C[i]], X[i]]
Y
# Out:
# {1: array([[32.30452983, 29.88635144, 31.41014476, 28.40166261, 29.66427827,
#          27.72509654, 28.44178609, 31.48651714, 31.54520668, 30.96752128,
#          29.58787518, 33.95938105, 30.56133015, 26.58656947, 27.82446698,
#          32.22876595, 33.47476935, 30.40366036, 31.1818055 , 33.25095666,
#          32.21055575, 30.52799694, 31.98677116, 29.8172419 , 28.71733167,
#          33.88515712, 30.92971026, 33.68525037, 32.24857821],
#         [30.39328682, 28.42378979, 26.64011609, 29.99290876, 30.65011486,
#          29.38759197, 29.66296012, 29.80896829, 29.43298535, 27.96099865,
#          30.08431088, 29.23546907, 29.85377459, 27.33609667, 30.18630078,
#          28.82695212, 30.99400602, 27.88576093, 30.39275995, 28.50930775,
#          31.36581132, 29.82563463, 29.78532685, 32.79801997, 31.8898348 ,
#          30.11443663, 30.87633269, 32.90285852, 29.78001702],
#         [26.9095717 , 30.13541958, 33.99995127, 31.02518927, 29.57617415,
#          31.65594929, 31.14741844, 29.38896202, 29.85451224, 30.42075504,
#          27.19087878, 31.05064016, 32.32067714, 26.47862288, 27.53698213,
#          27.52629325, 32.27383796, 31.08431455, 30.52821442, 30.84907394,
#          34.80658512, 30.58106936, 34.8849834 , 32.46692729, 30.15050877,
#          25.75220397, 32.24465664, 28.7639263 , 30.01709789]]),
#  2: array([[12.92421587,  9.14709982,  9.26108503, 12.31392655, 11.2786098 ,
#         [ 8.18265234,  8.51656298, 11.27731741],
#         [13.25075547, 11.86888894, 13.22705896]]),
#  3: array([[18.90050765, 17.19425457, 23.1655046 ],
#         [17.90970634, 15.27306279, 22.2706907 ],
#         [19.23189129, 21.7716588 , 21.26380374],
#         [21.45995119, 20.74598758, 21.06762182],
#         [19.8160534 , 18.73778334, 18.18531329],
#         [17.92218815, 17.88348688, 21.31256816],
#         [24.08405749, 20.89504138, 21.36676846],
#         [20.04577195, 20.21617323, 22.03052584],
#         [21.05295662, 22.49659957, 18.48465172],
#         [20.76122161, 18.50446728, 17.36464499],
#         [19.61202082, 23.14826294, 21.51380094],
#         [18.94575147, 19.20146366, 20.36213483],
#         [17.06341553, 20.08310555, 20.05366298],
#         [18.71774801, 20.24364254, 22.25896782],
#         [19.09366279, 21.20830728, 24.77041163],
#         [22.54751186, 23.9342035 , 16.28403627],
#         [21.04115267, 17.71131722, 21.60372206],
#         [20.03481882, 17.75596254, 18.96581108],
#         [18.00594634, 20.1795442 , 22.01436122],
#         [17.45488249, 20.62709544, 21.00636963],
#         [22.58645177, 23.53520191, 18.42445252],
#         [19.08069652, 20.4269489 , 19.5277486 ],
#         [20.45571506, 17.94207903, 21.21388066],
#         [21.75167786, 20.74863781, 16.30089769],
#         [20.64356494, 22.68263566, 20.28335037],
#         [18.59920299, 19.5932111 , 20.48533888],
#         [15.8055188 , 19.10273873, 20.94111919],
#         [17.20284354, 20.25137966, 17.75018878],
#         [19.00357287, 19.37803004, 19.99621703],
#         [19.47007864, 22.21456446, 17.30252696],
#         [21.171324  , 18.40821392, 21.44046498],
#         [20.15434788, 18.24543696, 18.26442555],
#         [20.44511133, 19.8133898 , 22.07311185],
#         [19.23902842, 20.0227454 , 17.46239225],
#         [21.64916925, 21.30916031, 19.8976231 ],
#         [18.68265491, 22.34845483, 21.03706366],
#         [23.38123485, 19.40507529, 19.49480041],
#         [20.10089907, 20.5699592 , 18.77069965],
#         [20.50786733, 21.6644563 , 19.59854475],
#         [19.39442827, 20.20120145, 21.93069051]])}

# %%
for k in range(K):
    Centroids[:, k] = np.mean(Y[k + 1], axis=0)

Centroids

# %%
for i in range(n_iter):
    EuclidianDistance = np.array([]).reshape(m, 0)
    for k in range(K):
        tempDist = np.sum((X - Centroids[:, k]) ** 2, axis=1)
        EuclidianDistance = np.c_[EuclidianDistance, tempDist]
    C = np.argmin(EuclidianDistance, axis=1) + 1
    Y = {}
    for k in range(K):
        Y[k + 1] = np.array([]).reshape(3, 0)

    for i in range(m):
        Y[C[i]] = np.c_[Y[C[i]], X[i]]

    for k in range(K):
        Y[k + 1] = Y[k + 1].T

    for k in range(K):
        Centroids[:, k] = np.mean(Y[k + 1], axis=0)
    Output = Y

print('number of points in cluster 1: ',len(Output[1]))
# print(Output[1])

print('number of points in cluster 2: ',len(Output[2]))
# print(Output[2])

print('number of points in cluster 3: ',len(Output[3]))
# print(Output[3])
# Out:
# number of points in cluster 1:  29
# number of points in cluster 2:  31
# number of points in cluster 3:  40
