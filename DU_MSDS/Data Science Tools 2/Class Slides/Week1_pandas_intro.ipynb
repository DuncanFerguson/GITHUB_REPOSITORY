# %% [markdown]
# <center><font size="50"> <b> Pandas </b> </font></center>

# %% [markdown]
# From the [pandas github](https://github.com/pandas-dev/pandas) page. Here is a nice article from [towardsdatascience](https://towardsdatascience.com/pandas-series-a-lightweight-intro-b7963a0d62a2) that covers Series and DataFrames pretty well.
#
# Pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.
#
# I recommend you reference the book "Python for Data Analysis" by Wes McKinney.  It is free to access on O-Reilly Media web page.
#
# 2nd Edition: https://www.oreilly.com/library/view/python-for-data/9781491957653/
#
# 3rd edition (pre-release version): https://www.oreilly.com/library/view/python-for-data/9781098104023/
#
# Amazon: https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython/dp/1491957662/ref=sr_1_5?crid=24N2E5QAGATTP&keywords=python+for+data+analysis+by+wes+mckinney&qid=1648438493&sprefix=python+for+data+ana%2Caps%2C107&sr=8-5

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Two most fundamental data structure in pandas
# - [Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)
# - [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# # Series
#
# One dimensional array like object with associated label(index)

# %%
import numpy as np
np.random.seed(1)
random_int = np.random.randint(1, 100, 5)
series = pd.Series(random_int)

# %% [markdown]
# Note the index of a series is automatically assigned unless one is specified (just like data frame).

# %%
series
# Out:
# 0    38
# 1    13
# 2    73
# 3    10
# 4    76
# dtype: int32

# %%
series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# If we don't give index then a default starting from 0 is created.
# We can give index with labels

# %%
series = pd.Series(random_int, index=['a', 'b', 'c', 'd', 'e'])

series2 = pd.Series(random_int, index=list('abcde'))
series2
# Out:
# a    38
# b    13
# c    73
# d    10
# e    76
# dtype: int32

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series.values
# Out:
# array([38, 13, 73, 10, 76])

# %% [markdown]
# ## We can use boolean filtering(indexing) and math operation

# %%
series > 60  # creates a series with values of ture/false and the same index
# Out:
# a    False
# b    False
# c     True
# d    False
# e     True
# dtype: bool

# %%
series[series > 60]  # the true/false series is put into [] to act as a filter.  Only True values are returned.
# Out:
# c    73
# e    76
# dtype: int32

# %%
np.sqrt(series)
# Out:
# a    6.164414
# b    3.605551
# c    8.544004
# d    3.162278
# e    8.717798
# dtype: float64

# %% [markdown]
# or we can use python dict to create a Series (**a common theme in python libraries to take dict**)

# %%
sdata = {'Colorado': 5.6, 'Utah': 3.1, 'Nevada': 2.9}
state_ser= pd.Series(sdata)

state_ser
# Out:
# Colorado    5.6
# Utah        3.1
# Nevada      2.9
# dtype: float64

# %% [markdown]
# Series object itself and its index have a name attribute

# %%
state_ser.index.name= 'Population in Million'
state_ser.name = 'State'

# %%
state_ser
# Out:
# Population in Million
# Colorado    5.6
# Utah        3.1
# Nevada      2.9
# Name: State, dtype: float64

# %% [markdown]
# We can use labels to index value

# %%
state_ser[['Colorado', 'Utah']]  # return rows where Colorado or Utah are the index name (not the values)
# Out:
# Population in Million
# Colorado    5.6
# Utah        3.1
# Name: State, dtype: float64

# %% [markdown]
# In real dataset there will be values missing for an attribute. Let's add a state with missing value

# %%
# state_ser['Texas']= np.NAN
state_ser2 = state_ser
state_ser2
# Out:
# Population in Million
# Colorado    5.6
# Utah        3.1
# Nevada      2.9
# Name: State, dtype: float64

# %%
state_ser2['Texas']= ''
print(state_ser2)
pd.isna(state_ser2)
# Out:
# Population in Million
# Colorado    5.6
# Utah        3.1
# Nevada      2.9
# Texas
# Name: State, dtype: object
# Population in Million
# Colorado    False
# Utah        False
# Nevada      False
# Texas       False
# Name: State, dtype: bool

# %%
state_ser
# Out:
# Population in Million
# Colorado    5.6
# Utah        3.1
# Nevada      2.9
# Texas
# Name: State, dtype: object

# %% [markdown]
# ## Checking for missing value(isna, isnull, notnull)

# %%
pd.isna(state_ser)
# Out:
# Population in Million
# Colorado    False
# Utah        False
# Nevada      False
# Texas       False
# Name: State, dtype: bool

# %%
pd.isnull(state_ser)
# Out:
# Population in Million
# Colorado    False
# Utah        False
# Nevada      False
# Texas       False
# Name: State, dtype: bool

# %%
# Looks like isnull is an alias for isna...
pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj)>

# %% [markdown]
# # DataFrame
#
# Used for tabular data(2D) representation.
# - It has both row and column index.
# - Can can be thought of as collection(dict) of Series sharing same index.
# - Hierarchical indexing can be used for higher dimensional data.

# %%
#Creating a DataFrame from a dictionary
crime = {
    'years':['2007','2008','2009','2010'],
    'vandalism':[33,69,48,44],
    'drug abuse':[46,60,61,67],
    'liquor laws':[86,81,76,86]
}
crime_df = pd.DataFrame(crime)
crime_df
# Out:
#   years  vandalism  drug abuse  liquor laws
# 0  2007         33          46           86
# 1  2008         69          60           81
# 2  2009         48          61           76
# 3  2010         44          67           86

# %% [markdown]
# Note That pandas render table in a nice html format

# %%
crime_df.to_html()  # df.read_html(url) reads a table from web page with address url.
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>years</th>\n      <th>vandalism</th>\n      <th>drug abuse</th>\n      <th>liquor laws</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2007</td>\n      <td>33</td>\n      <td>46</td>\n      <td>86</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2008</td>\n      <td>69</td>\n      <td>60</td>\n      <td>81</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2009</td>\n      <td>48</td>\n      <td>61</td>\n      <td>76</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2010</td>\n      <td>44</td>\n      <td>67</td>\n      <td>86</td>\n    </tr>\n  </tbody>\n</table>'

# %%
#Checking the keys from the original dictionary used to build the dataframe
crime.keys()
# Out:
# dict_keys(['years', 'vandalism', 'drug abuse', 'liquor laws'])

# %% [markdown]
# # Some properties of pandas dataframe

# %%
#Get column names
crime_df.columns
# Out:
# Index(['years', 'vandalism', 'drug abuse', 'liquor laws'], dtype='object')

# %%
#Get indices
crime_df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Get data types in the dataframe
crime_df.dtypes
# Out:
# years          object
# vandalism       int64
# drug abuse      int64
# liquor laws     int64
# dtype: object

# %%
#Check for null values
crime_df.isna()
# Out:
#    years  vandalism  drug abuse  liquor laws
# 0  False      False       False        False
# 1  False      False       False        False
# 2  False      False       False        False
# 3  False      False       False        False

# %%
#Show only a subsample of the dataframe, in this case just the first 2 rows
crime_df.head(2)
# Out:
#   years  vandalism  drug abuse  liquor laws
# 0  2007         33          46           86
# 1  2008         69          60           81

# %%
## How to view bottom two rows ??
crime_df.tail(2)
# Out:
#   years  vandalism  drug abuse  liquor laws
# 2  2009         48          61           76
# 3  2010         44          67           86

# %%
# How to get underlying 2d numpy array??
crime_df.values
# Out:
# array([['2007', 33, 46, 86],
#        ['2008', 69, 60, 81],
#        ['2009', 48, 61, 76],
#        ['2010', 44, 67, 86]], dtype=object)

# %% [markdown]
# In a real dataset we have lot of columns. We can arrange columns and give index values

# %%
#Creating the same dataframe but specifying the column names and indices 
crime_df = {
    'years':['2007','2008','2009','2010'],
    'vandalism':[33,69,48,44],
    'drug abuse':[46,60,61,67],
    'liquor laws':[86,81,76,86]
}

pd.DataFrame(crime,
             columns=['years', 'liquor laws', 'drug abuse', 'vandalism'], 
             index =list('abcd'))
# Out:
#   years  liquor laws  drug abuse  vandalism
# a  2007           86          46         33
# b  2008           81          60         69
# c  2009           76          61         48
# d  2010           86          67         44

# %%
# or we alrady have read the dataframe and we specify which columns to use/order
pd.DataFrame(crime_df, columns=['liquor laws', 'drug abuse', 'vandalism', 'years'])
# Out:
#    liquor laws  drug abuse  vandalism years
# 0           86          46         33  2007
# 1           81          60         69  2008
# 2           76          61         48  2009
# 3           86          67         44  2010

# %%
# or we want the years to be the indices
crime_df = pd.DataFrame(crime_df, columns=['years', 'liquor laws', 'drug abuse', 'vandalism'] )
crime_df2 = crime_df.set_index('years')
crime_df2
crime_df
# Out:
#   years  liquor laws  drug abuse  vandalism
# 0  2007           86          46         33
# 1  2008           81          60         69
# 2  2009           76          61         48
# 3  2010           86          67         44

# %%
crime_df
# Out:
#   years  liquor laws  drug abuse  vandalism
# 0  2007           86          46         33
# 1  2008           81          60         69
# 2  2009           76          61         48
# 3  2010           86          67         44

# %% [markdown]
# What happened, we just set the index....

# %%
# Use inplace to modify data frame
crime_df.set_index('years', inplace=True)
crime_df
# Out:
#        liquor laws  drug abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %% [markdown]
# # Slicing and dicing DataFrame([ ], loc, iloc)

# %%
#To access a single column :
crime_df[['drug abuse']]
# type(crime_df[['drug abuse']])
# type(crime_df['drug abuse'])
# Out:
#        drug abuse
# years
# 2007           46
# 2008           60
# 2009           61
# 2010           67

# %%
#To access multiple columns :
crime_df[['drug abuse', 'vandalism']]
# Out:
#        drug abuse  vandalism
# years
# 2007           46         33
# 2008           60         69
# 2009           61         48
# 2010           67         44

# %% [markdown]
# ## slicing or selecting data with a boolean array

# %%
# crime_df
# crime_df['vandalism']>40
crime_df[crime_df['vandalism']>40]
# Out:
#        liquor laws  drug abuse  vandalism
# years
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %%
#or use attribute access
crime_df.vandalism
# Out:
# years
# 2007    33
# 2008    69
# 2009    48
# 2010    44
# Name: vandalism, dtype: int64

# %%
# use drug abuse as property to access this colums
# crime_df.drug abuse #can't have a space in the name

# %% [markdown]
# Valid Python variable name is required. Let's change it.
#
# **Search for pandas function and use it to rename drug abuse to *drug_abuse***

# %%
crime_df.columns = [col.replace(' ', '_') for col in crime_df.columns]
crime_df.columns
# crime_df.drug_abuse
# Out:
# Index(['liquor_laws', 'drug_abuse', 'vandalism'], dtype='object')

# %%
#Write code here
crime_df.rename(columns={"drug abuse":"drug_abuse"}, inplace=True)
crime_df
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %% [markdown]
# ## Rows can be retrieved using loc and iloc

# %% [markdown]
# ## loc
# - loc uses label/index
# - conditional lookup

# %%
#
crime_df
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %%
# Using label

series_2010 = crime_df.loc[['2010'], ['drug_abuse', 'vandalism']]
series_2010
# Out:
#        drug_abuse  vandalism
# years
# 2010           67         44

# %%
crime_df
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %%
# Conditional row selection
crime_df.loc[crime_df.drug_abuse>50]
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %% [markdown]
# <font color = "red">Indexing returns a view </font>

# %%
series_2010.drug_abuse = 1.0
series_2010
# Out:
#        drug_abuse  vandalism
# years
# 2010          1.0         44

# %%
crime_df
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %% [markdown]
# ## iloc
# use it for integer location based indexing

# %%
crime_df
# Out:
#        liquor_laws  drug_abuse  vandalism
# years
# 2007            86          46         33
# 2008            81          60         69
# 2009            76          61         48
# 2010            86          67         44

# %%
crime_df.iloc[1:3, 1:3]
# Out:
#        drug_abuse  vandalism
# years
# 2008           60         69
# 2009           61         48

# %%
#There are times when we want to inverse the rows and columns. 
#The built-in transpose method takes care of it for us
crime_df.T
# Out:
# years        2007  2008  2009  2010
# liquor_laws    86    81    76    86
# drug_abuse     46    60    61    67
# vandalism      33    69    48    44

# %% [markdown]
# # Reindex
# create new DataFrame as per new index

# %%
df = pd.DataFrame(np.arange(12).reshape((4,3)), index=[0, 3 ,5 ,9], columns=['a', 'b', 'c'])
df
# Out:
#    a   b   c
# 0  0   1   2
# 3  3   4   5
# 5  6   7   8
# 9  9  10  11

# %%
# row reindexing
df.reindex(range(10))
# Out:
#      a     b     c
# 0  0.0   1.0   2.0
# 1  NaN   NaN   NaN
# 2  NaN   NaN   NaN
# 3  3.0   4.0   5.0
# 4  NaN   NaN   NaN
# 5  6.0   7.0   8.0
# 6  NaN   NaN   NaN
# 7  NaN   NaN   NaN
# 8  NaN   NaN   NaN
# 9  9.0  10.0  11.0

# %%
# column reindexing
df.reindex(columns=['c', 'b'])
# Out:
#     c   b
# 0   2   1
# 3   5   4
# 5   8   7
# 9  11  10

# %% [markdown]
# # Drop row or column

# %%
data_df = pd.DataFrame(np.arange(16).reshape((4, 4)),
                      index=['Ohio', 'Colorado', 'Florida', 'New York'],
                      columns=['one', 'two', 'three', 'four'])
data_df
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Florida     8    9     10    11
# New York   12   13     14    15

# %%
data_df.drop(['Florida'])
# data_df
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York   12   13     14    15

# %% [markdown]
# ## To drop column use axis = 1, axis =0 is default

# %%
data_df.drop(['one', 'three'], axis=1)
# Out:
#           two  four
# Ohio        1     3
# Colorado    5     7
# Florida     9    11
# New York   13    15

# %% [markdown]
# ## Let's combine dropping rows with missing values

# %%
data_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# dropna function arguments : 
# axis (row = 0, column = 1) 
# how (any or all values are NA)
# thresh (required number of non NAs, can only drop row is x values or more in row are NA)
# subset (if dropping rows it would be a subset of columns to consider)
# inplace (dropping to be done in place or not)
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Florida     8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ## We can also replace missing values with a given value

# %%
# data_df.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
data_df.fillna?
data_df.fillna(0) #shift tab-tab
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Florida     8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ### pandas fillna method:
# method{‘backfill’, ‘bfill’, ‘pad’, ‘ffill’, None}, default None
#
# Method to use for filling holes in reindexed Series pad / ffill: propagate last valid observation forward to next valid backfill / bfill: use next valid observation to fill gap.

# %%
data_df.replace(0,np.nan, inplace=True)  # make a NaN value
data_df.fillna(method='ffill')  # foward fill doesn't go up to fill in the first row.  inplace=True not set so df is not changed
# Out:
#            one  two  three  four
# Ohio       NaN    1      2     3
# Colorado   4.0    5      6     7
# Florida    8.0    9     10    11
# New York  12.0   13     14    15

# %%
data_df.fillna(method='bfill')  # goes up to first row.  inplace=True not set so df is not changed
# Out:
#            one  two  three  four
# Ohio       4.0    1      2     3
# Colorado   4.0    5      6     7
# Florida    8.0    9     10    11
# New York  12.0   13     14    15

# %% [markdown]
# # Arithmetic operation support and element wise array operation from numpy

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                    columns=list('abcde'))
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1 + df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0  11.0  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %%
np.exp(df1)
# df1
# Out:
#              a            b             c             d
# 0     1.000000     2.718282      7.389056     20.085537
# 1    54.598150   148.413159    403.428793   1096.633158
# 2  2980.957987  8103.083928  22026.465795  59874.141715

# %% [markdown]
# # Applying lambda function to frame

# %%
# Apply a function row wise
df1.apply(lambda x: x.max())
# Out:
# a     8.0
# b     9.0
# c    10.0
# d    11.0
# dtype: float64

# %%
# Or apply column wise axis =1 or columns
df1.apply(lambda x: x.max(), axis='columns')
# Out:
# 0     3.0
# 1     7.0
# 2    11.0
# dtype: float64

# %% [markdown]
# Do these results seem strange to you ?... Are the results row-wise and column-wise or did we brake something ?

# %% [markdown]
# # Applymap for element wise function

# %%
#Casting each individual value to type int
df1.applymap(lambda x: int(x) )
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
#Squaring each individual value of column 'a'
df1['a'].map(lambda x: x**2)
# Out:
# 0     0.0
# 1    16.0
# 2    64.0
# Name: a, dtype: float64

# %% [markdown]
# ### Apply to call a function that can apply to any or just one of the columns

# %%
def func(row):  # apply a function to multiple columns
    x = row['a'] + row['b'] * row['c']
    return x

df1['d'] = df1.apply(func,axis=1)
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   2.0
# 1  4.0  5.0   6.0  34.0
# 2  8.0  9.0  10.0  98.0

# %% [markdown]
# ## Grouping similar data

# %%
df_animals = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                    'Max Speed': [380., 370., 24., 26.]})
df_animals
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
#Group data based on the 'Animal' column and calculate the mean
# df_animals.groupby(['Animal'])
df_animals.groupby(['Animal']).mean()  # can use mean, max, min, count, sum, etc.
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %% [markdown]
# We can create subcategories in our indices, this is called multi-indexing and group based on those.

# %%
#We create the indices for two animals and their respective habitats
animal_habitat = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]


#We create a multi-index
index = pd.MultiIndex.from_arrays(animal_habitat, names=('Animal', 'Habitat'))


#Create our dataframe like before and we specify the indices to use
df_subcat = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
                   index=index)


#Ta-da!
df_subcat
# Out:
#                 Max Speed
# Animal Habitat
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %%
#How do we access the Parrot information only ?
print(df_subcat.loc['Parrot'],"\n\n")

#How do we access the parrot's flight speed in the wild ?
print(df_subcat.loc['Parrot', 'Wild'])
# Out:
#          Max Speed
# Habitat
# Captive       30.0
# Wild          20.0
#
#
# Max Speed    20.0
# Name: (Parrot, Wild), dtype: float64

# %%
#How do we use the group by if we have multi-index ? Say we want the average flight speed of each animal
print(df_subcat.groupby(level=0).mean(),"\n\n")

df_subcat.groupby(level=1).mean()
# Out:
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0
#          Max Speed
# Habitat
# Captive      210.0
# Wild         185.0

# %% [markdown]
# ## Joining, Appending, Concatenating and Merging

# %% [markdown]
# There are 4 ways to combine dat from dataframes, these are grouped into 2 types : combining data by columns and by rows.
#
# - Merge : SQL-like joins. Takes different columns from different dataframes and combines them into a dataframe.
#
# - Join : SQL-like joins, has small syntax differences with merge but has essentially same functionality.
#
# - Append : "stacks" dataframes on top of each other
#
# - Concatenate : "stacks" dataframes on top of each other

# %% [markdown]
# ### Let's tackle column wise merge

# %%
#Load up the data
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Create two df with different data
totalBill = tips.groupby(['sex', 'smoker'])[['total_bill']].sum()
people = tips.groupby(['sex', 'smoker'])[['size']].sum()

# %%
totalBill
# Out:
#                total_bill
# sex    smoker
# Male   Yes        1337.07
#        No         1919.75
# Female Yes         593.27
#        No          977.68

# %%
people
# Out:
#                size
# sex    smoker
# Male   Yes      150
#        No       263
# Female Yes       74
#        No       140

# %%
#We want to join on the indices. Note, since we have multi-index the number of levels must match.
pd.merge(totalBill, people,
        right_index=True, left_index=True)
# Out:
#                total_bill  size
# sex    smoker
# Male   Yes        1337.07   150
#        No         1919.75   263
# Female Yes         593.27    74
#        No          977.68   140

# %%
#We can get an even more SQL-like join by picking on which columns we want to merge on:
pd.merge(totalBill.reset_index(),
        people.reset_index(),
        on=['sex','smoker'])
# Out:
#       sex smoker  total_bill  size
# 0    Male    Yes     1337.07   150
# 1    Male     No     1919.75   263
# 2  Female    Yes      593.27    74
# 3  Female     No      977.68   140

# %% [markdown]
# ### Now for stacking dataframes together

# %%
#At the top is totalBill, followed by tip, followed by totalBill :
pd.concat([totalBill, people, totalBill], sort=False)
#Note we can specify the axis and concateate by columns also, by default we have axis=0
# Out:
#                total_bill   size
# sex    smoker
# Male   Yes        1337.07    NaN
#        No         1919.75    NaN
# Female Yes         593.27    NaN
#        No          977.68    NaN
# Male   Yes            NaN  150.0
#        No             NaN  263.0
# Female Yes            NaN   74.0
#        No             NaN  140.0
# Male   Yes        1337.07    NaN
#        No         1919.75    NaN
# Female Yes         593.27    NaN
#        No          977.68    NaN

# %% [markdown]
# ## Pivot tables and Cross-tabulations

# %% [markdown]
# ### Pivot tables
#
# As we saw with the example above where we take the transpose of a matrix which swaps columns and rows, there are times when we want more granular control over how we're swapping columns and rows. It is important to remember that pivot tables are primarily used for aggregating data, by default pivot tables use numpy.mean().

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                          "bar", "bar", "bar", "bar"],
                    "B": ["one", "one", "one", "two", "two",
                          "one", "one", "two", "two"],
                    "C": ["small", "large", "large", "small",
                          "small", "large", "small", "small",
                          "large"],
                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                    "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
#This first example aggregates values by taking the sum.
table = pd.pivot_table(df, values='D', index=['A', 'B'],
                     columns=['C'], aggfunc=np.sum)
table
# Out:
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %%
#We can also fill missing values using the `fill_value` parameter.
table = pd.pivot_table(df, values=['D','E'], index=['A', 'B'],
                     columns=['C'], aggfunc=np.sum, fill_value=0)
table
# Out:
#             D           E
# C       large small large small
# A   B
# bar one     4     5     6     8
#     two     7     6     9     9
# foo one     4     1     9     2
#     two     0     6     0    11

# %%
#The next example aggregates by taking the mean across multiple columns.
table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                     aggfunc={'D': np.mean,
                              'E': np.mean})
table
# Out:
#                   D         E
# A   C
# bar large  5.500000  7.500000
#     small  5.500000  8.500000
# foo large  2.000000  4.500000
#     small  2.333333  4.333333

# %%
#Variation :
table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                     aggfunc={'D': np.mean,
                              'E': np.sum})
table
# Out:
#                   D   E
# A   C
# bar large  5.500000  15
#     small  5.500000  17
# foo large  2.000000   9
#     small  2.333333  13

# %%
#We can also calculate multiple types of aggregations for any given value column.
table = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                     aggfunc={'D': np.mean,
                              'E': [min, max, np.mean]})
table
# Out:
#                   D    E
#                mean  max      mean  min
# A   C
# bar large  5.500000  9.0  7.500000  6.0
#     small  5.500000  9.0  8.500000  8.0
# foo large  2.000000  5.0  4.500000  4.0
#     small  2.333333  6.0  4.333333  2.0

# %%
#Let's access data by row
#Get bar stuff :
# table.loc['bar']

#Get bar and large stuff : (returns a series, try for a dataframe)
# table.loc['bar'].loc['large']

#Can use iloc as well :
# table.iloc[2]

#Let's access data by column :
#Get everything in column E
# table['E']

#Get only the mean column 
table['E']['mean'] #(returns a series, try for a dataframe)
# table['E'][['mean']] #returning a dataframe
# pd.DataFrame(table['E']['mean']) #casting
# Out:
# A    C
# bar  large    7.500000
#      small    8.500000
# foo  large    4.500000
#      small    4.333333
# Name: mean, dtype: float64

# %%
#Let's load up a data set from seaborn
exercise = sns.load_dataset('exercise')

#Unnamed column is useless...
exercise.drop('Unnamed: 0', axis=1, inplace=True)
exercise
# Out:
#     id     diet  pulse    time     kind
# 0    1  low fat     85   1 min     rest
# 1    1  low fat     85  15 min     rest
# 2    1  low fat     88  30 min     rest
# 3    2  low fat     90   1 min     rest
# 4    2  low fat     92  15 min     rest
# ..  ..      ...    ...     ...      ...
# 85  29   no fat    135  15 min  running
# 86  29   no fat    130  30 min  running
# 87  30   no fat     99   1 min  running
# 88  30   no fat    111  15 min  running
# 89  30   no fat    150  30 min  running
#
# [90 rows x 5 columns]

# %%
#Let get diet as the index and have columns pulse, time and kind....
exercise.pivot_table(index="diet", columns=["time","kind","pulse"])
# Out:
#            id                                                   ...          \
# time    1 min                                                   ...  30 min
# kind     rest                                          walking  ... walking
# pulse     80   83   85   87   90   91   92   97    100     84   ...     104
# diet                                                            ...
# no fat    NaN  6.0  NaN  7.0  NaN  NaN  8.0  9.0  10.0    16.0  ...     NaN
# low fat   4.0  NaN  1.0  NaN  2.0  5.0  NaN  3.0   NaN     NaN  ...    12.0
#
#
# time
# kind    running
# pulse       99    110   112   116   120   130   140   143   150
# diet
# no fat      NaN   NaN   NaN   NaN   NaN  29.0  27.5  26.0  30.0
# low fat    23.0  21.0  22.0  25.0  24.0   NaN   NaN   NaN   NaN
#
# [2 rows x 79 columns]

# %%
pd.pivot_table?

# %%
#If we just want an average over all participants we can drop the participants ID
exercise.drop('id', axis=1, inplace=True)
exercise
# Out:
#        diet  pulse    time     kind
# 0   low fat     85   1 min     rest
# 1   low fat     85  15 min     rest
# 2   low fat     88  30 min     rest
# 3   low fat     90   1 min     rest
# 4   low fat     92  15 min     rest
# ..      ...    ...     ...      ...
# 85   no fat    135  15 min  running
# 86   no fat    130  30 min  running
# 87   no fat     99   1 min  running
# 88   no fat    111  15 min  running
# 89   no fat    150  30 min  running
#
# [90 rows x 4 columns]

# %%
exercise.pivot_table(index=["diet","kind"], columns="time")
# Out:
#                 pulse
# time            1 min 15 min 30 min
# diet    kind
# no fat  rest     91.8   92.2   93.0
#         walking  95.6   98.6   96.6
#         running  98.2  124.4  140.6
# low fat rest     88.6   89.6   89.8
#         walking  90.6   94.6   95.2
#         running  94.0  109.8  111.4

# %%
#Let's try this !
exercise.pivot_table(index=["kind"], columns=["time"])
# Out:
#         pulse
# time    1 min 15 min 30 min
# kind
# rest     90.2   90.9   91.4
# walking  93.1   96.6   95.9
# running  96.1  117.1  126.0

# %% [markdown]
# # Uh-oh......

# %%
#Let's load up a data set from seaborn
exercise = sns.load_dataset('exercise')

#Unnamed column is useless...
exercise.drop('Unnamed: 0', axis=1, inplace=True)

#Let's look at participant 1's information
exercise[exercise['id'] == 1]
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest

# %%
#Since pivot tables are used to aggregate data, a more natural use is getting the average pulse for all 
#participants in each diet and kind of exercise.
exercise.drop(['id'], axis=1, inplace= True)
exercise.pivot_table(index=["diet","kind"], columns=["time"])
# Out:
#                 pulse
# time            1 min 15 min 30 min
# diet    kind
# no fat  rest     91.8   92.2   93.0
#         walking  95.6   98.6   96.6
#         running  98.2  124.4  140.6
# low fat rest     88.6   89.6   89.8
#         walking  90.6   94.6   95.2
#         running  94.0  109.8  111.4

# %% [markdown]
# ## Cross-tabulations
# these are also known as contingency tables, which show the multivariate frequency distribution of variables. It gives you an overview of the interrelations between two variables.

# %%
titanic = sns.load_dataset('titanic')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Let's look at how many people survived based on gender :
pd.crosstab(titanic.sex, titanic.survived)
#Notice that the data should be categorical, otherwise you will get sparce matrices...
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
#If we want to get totals based on row/columns we need to use an additional argument:
pd.crosstab(titanic.sex, titanic.survived, margins=True)
# Out:
# survived    0    1  All
# sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
#We can have multiple variables :
pd.crosstab([titanic.sex, titanic.who], [titanic.survived])
# Out:
# survived        0    1
# sex    who
# female child   15   28
#        woman   66  205
# male   child   19   21
#        man    449   88

# %%
#We can also extract percentages directly :
pd.crosstab(titanic.sex, [titanic.survived, titanic.who], normalize="index")
# Out:
# survived         0                             1
# who          child       man     woman     child       man     woman
# sex
# female    0.047771  0.000000  0.210191  0.089172  0.000000  0.652866
# male      0.032929  0.778163  0.000000  0.036395  0.152513  0.000000

# %% [markdown]
# ## Binning data and Dummy coding
#
# Binning data is simply grouping together data based on their numerical value, i.e. [1,2,4] [6,7,8] [23,24,25]
#
# Dummy coding is changing a categorical variable into a numerical (int) value.
#
# Let's jump into binning data first.

# %%
crashes = sns.load_dataset('car_crashes')
crashes.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# 7      151.48     DE
# 8      136.05     DC
# 9      144.18     FL

# %%
#Let's look at the minimum and maximum in crashs
print("Min number of total",crashes.total.min())
print("Max number of total",crashes.total.max())
# Out:
# Min number of total 5.9
# Max number of total 23.9

# %%
#Let's define our bins :
bins = [0, 8.9, 11.9, 14.9, 17.9, 20.9, 23.9]

titles = ['very low', 'low', 'moderate-low', 'moderate-high', 'high', 'very high']

#Let's create a new column titled safety_rating
crashes['safety_rating'] = pd.cut(crashes['total'], bins, labels=titles)
crashes.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev  safety_rating
# 0      145.08     AL           high
# 1      133.93     AK           high
# 2      110.35     AZ           high
# 3      142.39     AR      very high
# 4      165.63     CA   moderate-low
# 5      139.91     CO   moderate-low
# 6      167.02     CT            low
# 7      151.48     DE  moderate-high
# 8      136.05     DC       very low
# 9      144.18     FL  moderate-high

# %% [markdown]
# ### Pandas can cut in many ways.  You can cut evenly spaced across the range of values.

# %%
pd.cut(crashes['total'], 6, labels=titles).head(10)  # make six bins, ranging from min(total) to max(total)
# Out:
# 0             high
# 1             high
# 2             high
# 3        very high
# 4     moderate-low
# 5     moderate-low
# 6              low
# 7    moderate-high
# 8         very low
# 9    moderate-high
# Name: total, dtype: category
# Categories (6, object): ['very low' < 'low' < 'moderate-low' < 'moderate-high' < 'high' < 'very high']

# %% [markdown]
# ### Pandas can cut on quantiles, quintiles, etc using qcut.  This makes each bin have an equal number of rows.

# %%
pd.qcut(crashes['total'], 6, labels=titles).head(10)  # make six bins, ranging from min(total) to max(total)
# Out:
# 0             high
# 1             high
# 2             high
# 3        very high
# 4              low
# 5              low
# 6         very low
# 7    moderate-high
# 8         very low
# 9             high
# Name: total, dtype: category
# Categories (6, object): ['very low' < 'low' < 'moderate-low' < 'moderate-high' < 'high' < 'very high']

# %% [markdown]
# ### One-hot encoding using pandas dummies

# %%
#Mmm.... we still only have 0 and 1 but we have 3 variables. What do we do now ?...
# titanic who column is "man" or "woman".  
pd.get_dummies(titanic.who, drop_first=True)  # breaks into one column for each unique value in column "who"
# Out:
#      man  woman
# 0      1      0
# 1      0      1
# 2      0      1
# 3      0      1
# 4      1      0
# ..   ...    ...
# 886    1      0
# 887    0      1
# 888    0      1
# 889    1      0
# 890    1      0
#
# [891 rows x 2 columns]

# %%
#Let's take a closer look at the documentation : 
pd.get_dummies?

# %%
#We can also pass in a dataframe to the function :
# note sex column is male or female and who column is man or woman.
# drop_first mean: Whether to get k-1 dummies out of k categorical levels by removing the first level.
# drop_first means we drop the column sex_female.
pd.get_dummies(titanic, columns=['sex', 'who'], drop_first=True)
# Out:
#      survived  pclass    age  sibsp  parch      fare embarked   class  \
# 0           0       3  22.00      1      0    7.2500        S   Third
# 1           1       1  38.00      1      0   71.2833        C   First
# 2           1       3  26.00      0      0    7.9250        S   Third
# 3           1       1  35.00      1      0   53.1000        S   First
# 4           0       3  35.00      0      0    8.0500        S   Third
# 5           0       3    NaN      0      0    8.4583        Q   Third
# 6           0       1  54.00      0      0   51.8625        S   First
# 7           0       3   2.00      3      1   21.0750        S   Third
# 8           1       3  27.00      0      2   11.1333        S   Third
# 9           1       2  14.00      1      0   30.0708        C  Second
# 10          1       3   4.00      1      1   16.7000        S   Third
# 11          1       1  58.00      0      0   26.5500        S   First
# 12          0       3  20.00      0      0    8.0500        S   Third
# 13          0       3  39.00      1      5   31.2750        S   Third
# 14          0       3  14.00      0      0    7.8542        S   Third
# 15          1       2  55.00      0      0   16.0000        S  Second
# 16          0       3   2.00      4      1   29.1250        Q   Third
# 17          1       2    NaN      0      0   13.0000        S  Second
# 18          0       3  31.00      1      0   18.0000        S   Third
# 19          1       3    NaN      0      0    7.2250        C   Third
# 20          0       2  35.00      0      0   26.0000        S  Second
# 21          1       2  34.00      0      0   13.0000        S  Second
# 22          1       3  15.00      0      0    8.0292        Q   Third
# 23          1       1  28.00      0      0   35.5000        S   First
# 24          0       3   8.00      3      1   21.0750        S   Third
# 25          1       3  38.00      1      5   31.3875        S   Third
# 26          0       3    NaN      0      0    7.2250        C   Third
# 633         0       1    NaN      0      0    0.0000        S   First
# 634         0       3   9.00      3      2   27.9000        S   Third
# 635         1       2  28.00      0      0   13.0000        S  Second
# 636         0       3  32.00      0      0    7.9250        S   Third
# 637         0       2  31.00      1      1   26.2500        S  Second
# 638         0       3  41.00      0      5   39.6875        S   Third
# 639         0       3    NaN      1      0   16.1000        S   Third
# 640         0       3  20.00      0      0    7.8542        S   Third
# 641         1       1  24.00      0      0   69.3000        C   First
# 642         0       3   2.00      3      2   27.9000        S   Third
# 643         1       3    NaN      0      0   56.4958        S   Third
# 644         1       3   0.75      2      1   19.2583        C   Third
# 645         1       1  48.00      1      0   76.7292        C   First
# 646         0       3  19.00      0      0    7.8958        S   Third
# 647         1       1  56.00      0      0   35.5000        C   First
# 648         0       3    NaN      0      0    7.5500        S   Third
# 649         1       3  23.00      0      0    7.5500        S   Third
# 650         0       3    NaN      0      0    7.8958        S   Third
# 651         1       2  18.00      0      1   23.0000        S  Second
# 652         0       3  21.00      0      0    8.4333        S   Third
# 653         1       3    NaN      0      0    7.8292        Q   Third
# 654         0       3  18.00      0      0    6.7500        Q   Third
# 655         0       2  24.00      2      0   73.5000        S  Second
# ...
# 689       False    B  Southampton   yes  False         0        0          0
# 690        True    B  Southampton   yes  False         1        1          0
# 691       False  NaN    Cherbourg   yes  False         0        0          0
# 692        True  NaN  Southampton   yes   True         1        1          0
# 693        True  NaN    Cherbourg    no   True         1        1          0
# 694        True  NaN  Southampton    no   True         1        1          0
# 695        True  NaN  Southampton    no   True         1        1          0
# 696        True  NaN  Southampton    no   True         1        1          0
# 697       False  NaN   Queenstown   yes   True         0        0          1
# 698        True    C    Cherbourg    no  False         1        1          0
# 699        True    F  Southampton    no   True         1        1          0
# 700       False    C    Cherbourg   yes  False         0        0          1
# 701        True    E  Southampton   yes   True         1        1          0
# 702       False  NaN    Cherbourg    no  False         0        0          1
# 703        True  NaN   Queenstown    no   True         1        1          0
# 704        True  NaN  Southampton    no  False         1        1          0
# 705        True  NaN  Southampton    no   True         1        1          0
# 706       False  NaN  Southampton   yes   True         0        0          1
# 707        True    E  Southampton   yes   True         1        1          0
# 708       False  NaN  Southampton   yes   True         0        0          1
# 709        True  NaN    Cherbourg   yes  False         1        1          0
# 710       False    C    Cherbourg   yes   True         0        0          1
# 711        True    C  Southampton    no   True         1        1          0
# 712        True    C  Southampton   yes  False         1        1          0
# 713        True  NaN  Southampton    no   True         1        1          0
# 714        True  NaN  Southampton    no   True         1        1          0
# 715        True    F  Southampton    no   True         1        1          0
# 716       False    C    Cherbourg   yes   True         0        0          1
# 717       False    E  Southampton   yes   True         0        0          1
# 718        True  NaN   Queenstown    no   True         1        1          0
# 719        True  NaN  Southampton    no   True         1        1          0
# 720       False  NaN  Southampton   yes  False         0        0          0
# 721        True  NaN  Southampton    no  False         1        1          0
# 722        True  NaN  Southampton    no   True         1        1          0
# 723        True  NaN  Southampton    no   True         1        1          0
# 724        True    E  Southampton   yes  False         1        1          0
# 725        True  NaN  Southampton    no   True         1        1          0
# 726       False  NaN  Southampton   yes  False         0        0          1
# 727       False  NaN   Queenstown   yes   True         0        0          1
# 728        True  NaN  Southampton    no  False         1        1          0
# 729       False  NaN  Southampton    no  False         0        0          1
# 730       False    B  Southampton   yes   True         0        0          1
# 731       False  NaN    Cherbourg    no   True         1        0          0
# 732        True  NaN  Southampton    no   True         1        1          0
# 733        True  NaN  Southampton    no   True         1        1          0
# 734        True  NaN  Southampton    no   True         1        1          0
# 735        True  NaN  Southampton    no   True         1        1          0
# 736       False  NaN  Southampton    no  False         0        0          1
# 737        True    B    Cherbourg   yes   True         1        1          0
# 738        True  NaN  Southampton    no   True         1        1          0
# 739        True  NaN  Southampton    no   True         1        1          0
# 740        True    D  Southampton   yes   True         1        1          0
# 741        True    C  Southampton    no  False         1        1          0
# 742       False    B    Cherbourg   yes  False         0        0          1
# 743        True  NaN  Southampton    no  False         1        1          0
# 744        True  NaN  Southampton   yes   True         1        1          0
# 745        True    B  Southampton    no  False         1        1          0
# 746        True  NaN  Southampton    no  False         1        1          0
# 747       False  NaN  Southampton   yes   True         0        0          1
# 748        True    D  Southampton    no  False         1        1          0
# 749        True  NaN   Queenstown    no   True         1        1          0
# 750       False  NaN  Southampton   yes  False         0        0          0
# 751       False    E  Southampton   yes  False         1        0          0
# 752        True  NaN  Southampton    no   True         1        1          0
# 753        True  NaN  Southampton    no   True         1        1          0
# 754       False  NaN  Southampton   yes  False         0        0          1
# 755       False  NaN  Southampton   yes  False         1        0          0
# 756        True  NaN  Southampton    no   True         1        1          0
# 757        True  NaN  Southampton    no   True         1        1          0
# 758        True  NaN  Southampton    no   True         1        1          0
# 759       False    B  Southampton   yes   True         0        0          1
# 760        True  NaN  Southampton    no   True         1        1          0
# 761        True  NaN  Southampton    no   True         1        1          0
# 762        True  NaN    Cherbourg   yes   True         1        1          0
# 763       False    B  Southampton   yes  False         0        0          1
# 764        True  NaN  Southampton    no   True         1        1          0
# 765       False    D  Southampton   yes  False         0        0          1
# 766        True  NaN    Cherbourg    no   True         1        1          0
# 767       False  NaN   Queenstown    no   True         0        0          1
# 768        True  NaN   Queenstown    no  False         1        1          0
# 769        True  NaN  Southampton    no   True         1        1          0
# 770        True  NaN  Southampton    no   True         1        1          0
# 771        True  NaN  Southampton    no   True         1        1          0
# 772       False    E  Southampton    no   True         0        0          1
# 773        True  NaN    Cherbourg    no   True         1        1          0
# 774       False  NaN  Southampton   yes  False         0        0          1
# 775        True  NaN  Southampton    no   True         1        1          0
# 776        True    F   Queenstown    no   True         1        1          0
# 777       False  NaN  Southampton   yes   True         0        0          0
# 778        True  NaN   Queenstown    no   True         1        1          0
# 779       False    B  Southampton   yes  False         0        0          1
# 780       False  NaN    Cherbourg   yes   True         0        0          0
# 781       False    B  Southampton   yes  False         0        0          1
# 782        True    D  Southampton    no   True         1        1          0
# 783        True  NaN  Southampton    no  False         1        1          0
# 784        True  NaN  Southampton    no   True         1        1          0
# 785        True  NaN  Southampton    no   True         1        1          0
# 786       False  NaN  Southampton   yes   True         0        0          1
# 787       False  NaN   Queenstown    no  False         1        0          0
# 788       False  NaN  Southampton   yes  False         1        0          0
# 789        True    B    Cherbourg    no   True         1        1          0
# 790        True  NaN   Queenstown    no   True         1        1          0
# 791        True  NaN  Southampton    no   True         1        1          0
# 792       False  NaN  Southampton    no  False         0        0          1
# 793        True  NaN    Cherbourg    no   True         1        1          0
# 794        True  NaN  Southampton    no   True         1        1          0
# 795        True  NaN  Southampton    no   True         1        1          0
# 796       False    D  Southampton   yes   True         0        0          1
# 797       False  NaN  Southampton   yes   True         0        0          1
# 798        True  NaN    Cherbourg    no   True         1        1          0
# 799       False  NaN  Southampton    no  False         0        0          1
# 800        True  NaN  Southampton    no   True         1        1          0
# 801       False  NaN  Southampton   yes  False         0        0          1
# 802       False    B  Southampton   yes  False         1        0          0
# 803       False  NaN    Cherbourg   yes  False         1        0          0
# 804        True  NaN  Southampton   yes   True         1        1          0
# 805        True  NaN  Southampton    no   True         1        1          0
# 806        True    A  Southampton    no   True         1        1          0
# 807       False  NaN  Southampton    no   True         0        0          1
# 808        True  NaN  Southampton    no   True         1        1          0
# 809       False    E  Southampton   yes  False         0        0          1
# 810        True  NaN  Southampton    no   True         1        1          0
# 811        True  NaN  Southampton    no   True         1        1          0
# 812        True  NaN  Southampton    no   True         1        1          0
# 813       False  NaN  Southampton    no  False         0        0          0
# 814        True  NaN  Southampton    no   True         1        1          0
# 815        True    B  Southampton    no   True         1        1          0
# 816       False  NaN  Southampton    no   True         0        0          1
# 817        True  NaN    Cherbourg    no  False         1        1          0
# 818        True  NaN  Southampton    no   True         1        1          0
# 819       False  NaN  Southampton    no  False         1        0          0
# 820       False    B  Southampton   yes  False         0        0          1
# 821        True  NaN  Southampton   yes   True         1        1          0
# 822        True  NaN  Southampton    no   True         1        1          0
# 823       False    E  Southampton   yes  False         0        0          1
# 824       False  NaN  Southampton    no  False         1        0          0
# 825        True  NaN   Queenstown    no   True         1        1          0
# 826        True  NaN  Southampton    no   True         1        1          0
# 827       False  NaN    Cherbourg   yes  False         1        0          0
# 828        True  NaN   Queenstown   yes   True         1        1          0
# 829       False    B          NaN   yes   True         0        0          1
# 830       False  NaN    Cherbourg   yes  False         0        0          0
# 831       False  NaN  Southampton   yes  False         1        0          0
# 832        True  NaN    Cherbourg    no   True         1        1          0
# 833        True  NaN  Southampton    no   True         1        1          0
# 834        True  NaN  Southampton    no   True         1        1          0
# 835       False    E    Cherbourg   yes  False         0        0          1
# 836        True  NaN  Southampton    no   True         1        1          0
# 837        True  NaN  Southampton    no   True         1        1          0
# 838        True  NaN  Southampton   yes   True         1        1          0
# 839        True    C    Cherbourg   yes   True         1        1          0
# 840        True  NaN  Southampton    no   True         1        1          0
# 841        True  NaN  Southampton    no   True         1        1          0
# 842       False  NaN    Cherbourg   yes   True         0        0          1
# 843        True  NaN    Cherbourg    no   True         1        1          0
# 844        True  NaN  Southampton    no   True         1        1          0
# 845        True  NaN  Southampton    no   True         1        1          0
# 846        True  NaN  Southampton    no  False         1        1          0
# 847        True  NaN    Cherbourg    no   True         1        1          0
# 848        True  NaN  Southampton    no  False         1        1          0
# 849       False    C    Cherbourg   yes  False         0        0          1
# 850       False  NaN  Southampton    no  False         1        0          0
# 851        True  NaN  Southampton    no   True         1        1          0
# 852       False  NaN    Cherbourg    no  False         0        0          0
# 853       False    D  Southampton   yes  False         0        0          1
# 854       False  NaN  Southampton    no  False         0        0          1
# 855       False  NaN  Southampton   yes  False         0        0          1
# 856       False  NaN  Southampton   yes  False         0        0          1
# 857        True    E  Southampton   yes   True         1        1          0
# 858       False  NaN    Cherbourg   yes  False         0        0          1
# 859        True  NaN    Cherbourg    no   True         1        1          0
# 860        True  NaN  Southampton    no  False         1        1          0
# 861        True  NaN  Southampton    no  False         1        1          0
# 862       False    D  Southampton   yes   True         0        0          1
# 863       False  NaN  Southampton    no  False         0        0          1
# 864        True  NaN  Southampton    no   True         1        1          0
# 865       False  NaN  Southampton   yes   True         0        0          1
# 866       False  NaN    Cherbourg   yes  False         0        0          1
# 867        True    A  Southampton    no   True         1        1          0
# 868        True  NaN  Southampton    no   True         1        1          0
# 869       False  NaN  Southampton   yes  False         1        0          0
# 870        True  NaN  Southampton    no   True         1        1          0
# 871       False    D  Southampton   yes  False         0        0          1
# 872        True    B  Southampton    no   True         1        1          0
# 873        True  NaN  Southampton    no   True         1        1          0
# 874       False  NaN    Cherbourg   yes  False         0        0          1
# 875       False  NaN    Cherbourg   yes   True         0        0          0
# 876        True  NaN  Southampton    no   True         1        1          0
# 877        True  NaN  Southampton    no   True         1        1          0
# 878        True  NaN  Southampton    no   True         1        1          0
# 879       False    C    Cherbourg   yes  False         0        0          1
# 880       False  NaN  Southampton   yes  False         0        0          1
# 881        True  NaN  Southampton    no   True         1        1          0
# 882       False  NaN  Southampton    no   True         0        0          1
# 883        True  NaN  Southampton    no   True         1        1          0
# 884        True  NaN  Southampton    no   True         1        1          0
# 885       False  NaN   Queenstown    no  False         0        0          1
# 886        True  NaN  Southampton    no   True         1        1          0
# 887       False    B  Southampton   yes   True         0        0          1
# 888       False  NaN  Southampton    no  False         0        0          1
# 889        True    C    Cherbourg   yes   True         1        1          0
# 890        True  NaN   Queenstown    no   True         1        1          0

# %%
#Settings :
# pd.describe_option()

# pd.get_option('display.max_rows')
pd.set_option('display.max_rows',None)

# %%
titanic.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 84          1       2  female  17.0      0      0   10.5000        S  Second
# 688         0       3    male  18.0      0      0    7.7958        S   Third
# 142         1       3  female  24.0      1      0   15.8500        S   Third
# 794         0       3    male  25.0      0      0    7.8958        S   Third
# 744         1       3    male  31.0      0      0    7.9250        S   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 809         1       1  female  33.0      1      0   53.1000        S   First
# 320         0       3    male  22.0      0      0    7.2500        S   Third
# 742         1       1  female  21.0      2      2  262.3750        C   First
# 623         0       3    male  21.0      0      0    7.8542        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 84   woman       False  NaN  Southampton   yes   True
# 688    man        True  NaN  Southampton    no   True
# 142  woman       False  NaN  Southampton   yes  False
# 794    man        True  NaN  Southampton    no   True
# 744    man        True  NaN  Southampton   yes   True
# 6      man        True    E  Southampton    no   True
# 809  woman       False    E  Southampton   yes  False
# 320    man        True  NaN  Southampton    no   True
# 742  woman       False    B    Cherbourg   yes  False
# 623    man        True  NaN  Southampton    no   True
