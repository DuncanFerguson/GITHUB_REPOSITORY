# %% [markdown]
# # Web Scrapping
#
# Extracting webpages and parsing them for in readable format.
#
# Usually it is HTML. We'll use
# - **Requests** to get the webpage
# - **[Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/)** to parse it. It parses HTML and XML with the help of a parser(**html or lxml**)
#
#
# Let's start with an example from [geeksforgeeks](https://www.geeksforgeeks.org/python-convert-an-html-table-into-excel/)

# %%
#A quick example of how to import files from the internet using pandas built-in features :
import pandas as pd 
  
# The URL where we want to extract the table
url = "https://www.geeksforgeeks.org/extended-operators-in-relational-algebra/"
  
# Read in the first table. The read_html returns a list of tables
table = pd.read_html(url)[0]
table
# Out:
#          0       1        2           3    4
# 0  ROLL_NO    NAME  ADDRESS       PHONE  AGE
# 1        1     RAM    DELHI  9455123451   18
# 2        2  RAMESH  GURGAON  9652431543   18
# 3        3   SUJIT   ROHTAK  9156253131   20
# 4        4  SURESH    DELHI  9156768971   18

# %% [markdown]
# <center> <h1> Beautiful Soup  </h1> </center>
#
# From the website
#
# **"You didn't write that awful page. You're just trying to get some data out of it. Beautiful Soup is here to help."**
#
# Install
# - **pip install beautifulsoup4**
# - **pip install lxml**
# in your virtual environment.
#
# Documentation available [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %% [markdown]
# # Protocol to follow when scrapping the web page
# - Check for robot.txt and see what is allowed
# - Avoid lots of simultaneous calls. Your IP may get blocked. Use sleep between making get call to avoid this.
#
# - Use Requests get method to get the webpage html
# - Parse it using BeautifulSoup and lxml. It creates a hierarchical structure of html elements.
# - In Chrome/Safari/Mozzilla/etc right click and click on inspect to open developer tools. Inspecting the html elements for their attributes and hierarchical order.
# - Use Beautiful Soup object to get to the desired element.

# %% [markdown]
# # An example of parsing html
#
# Visit this [w3schools](https://www.w3schools.com/html/html_basic.asp) to get an idea about HTML

# %%
html_doc = """
<!DOCTYPE html>
<html><head><title>The Dormouse's story</title></head>
<body>

<p class="story_title"><b>The Dormouse's story three little sisters</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</body>
</html>
"""

# %% [markdown]
# <!DOCTYPE html>
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
# <p class="story">...</p>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup as bsoup

# %%
soup = bsoup(html_doc, 'lxml')
print(type(soup))
print(soup)
# Out:
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %% [markdown]
# # Navigating this data structure

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.text
# Out:
# "The Dormouse's story"

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parents
# Out:
# <generator object PageElement.parents at 0x11bcfcde0>

# %%
# print the name and text in parent tag 
soup.title.parent.text
# Out:
# "The Dormouse's story"

# %%
head_tag = soup.head
head_tag

#Returns the children of head
head_tag.contents
# Out:
# [<title>The Dormouse's story</title>]

# %%
title_tag = head_tag.contents[0]
title_tag

title_tag.contents

#there is also the .children function 
for child in title_tag.children:
    print(child)
# Out:
# The Dormouse's story

# %%
#Gets the first occurrence 
soup.body.b
# Out:
# <b>The Dormouse's story three little sisters</b>

# %%
#Finds the first hyperlink
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %% [markdown]
# # p tag represent a paragraph of text

# %%
soup.p
# Out:
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>

# %% [markdown]
# p tag has some attribute too, like class here. How to get the value of attribute

# %%
soup.p['class']

#Get all attributes 
# soup.p.attrs
# Out:
# {'class': ['story_title']}

# %% [markdown]
# But there were more **p** tags. How to get them from soup data structure

# %%
soup.find_all('p')
# Out:
# [<p class="story_title"><b>The Dormouse's story three little sisters</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %% [markdown]
# The **a** tag defines a hyperlink, to link  to another webpage
#
# <img src=""> </img>

# %%
# Find all the url(href) in a tags
for atag in soup.find_all('a'):
    print(atag['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# Third link
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# complete text
soup.get_text()
# Out:
# "The Dormouse's story\n\nThe Dormouse's story three little sisters\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n\n\n"

# %% [markdown]
# # Let's create some Beautiful Soup
#
# We will scrap fry electronics for telescopes following the protocol and store the result in a csv file.

# %% [markdown]
# # Checking robots.txt

# %%
# !curl  https://www.frys.com/robots.txt
# Out:
# User-agent: *
# Crawl-delay: 10
# Sitemap: https://www.frys.com/sitemap_index.xml
# Visit-time: 0030-0300
# Disallow: /ShopCartServlet
# Disallow: /wf

# %%
# import requests and bs4 
from bs4 import BeautifulSoup as bsoup
import requests

# %%
response = requests.get('https://www.frys.com/search?query_search=&cat=-68822&nearbyStoreName=false&pType=pDisplay&fq=a%20Regular%20Items&start=0&cat=-68822&from=0&to=99&isKeyword=true')

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '\r\n\r\n<!-- Desktop page for search. -->\r\n\r\n<HTML lang="en">\r\n\t<HEAD>\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n\t\t<base href="https://www.frys.com/">\r\n\t\t<TITLE>Fry\'s Electronics | </TITLE>\r\n\t\t<!-- Turn off telephone number detection. -->\r\n<meta name = "format-detection" content = "telephone=no">\r\n\r\n\r\n<LINK rel="stylesheet" href="/js/menus.css" type="text/css" media="screen"/>\r\n\r\n\r\n\r\n\r\n<!-- 629171 -->\r\n<script type="text/javascript">\r\nfunction fnvalidatePhoneNumber(phoneNumbers,id) {\r\n\t\t  var phonenumber=jQuery(phoneNumbers).val();\r\n\t\t  if(phonenumber!=null && phonenumber!=\'\' && phonenumber!=\' \') { \r\n\t\t  phonenumber = phonenumber.trim();\r\n\t\t  var phonenumber_d=phonenumber.replace(/-/gi,"").replace(/[(]/gi,"").replace(/ /gi,"").replace(/[)]/gi,"");\r\n\t\t\t  var regExp1 = "^[0-9]{11,}$";\r\n\t\t\t  var phone = (phonenumber_d).match(regExp1);\r\n\t\t\t  if (phone) {\r\n\t\t\t\t  jQuery(phoneNumbers).val(phonenumber_d.substring(0,3)+"-"+phonenumber_d.substring(3,6)+"-"+phonenumber_d.substring(6,15));\r\n\t\t\t\t  document.getElementById(id).innerHTML =\'* Phone numbers must be 10 digits\';\r\n\t\t\t\t  return false;\r\n\t\t\t  } else {\r\n\t\t\t\t  var regExp2 = "^[0-9]{10}$";\r\n\t\t\t\t  phone = (phonenumber_d).match(regExp2);\r\n\t\t\t\t  if (phone) {\r\n\t\t\t\t\t  document.getElementById(id).innerHTML =\'\';\r\n\t\t\t\t\t  jQuery(phoneNumbers).val(phonenumber_d.substring(0,3)+"-"+phonenumber_d.substring(3,6)+"-"+phonenumber_d.substring(6,15));\r\n\t\t\t\t\t  return true;\r\n\t\t\t\t  } \r\n\t\t\t\t  else {\r\n\t\t\t\t\t  document.getElementById(id).innerHTML =\'<font color="#CC3300">* Phone numbers must be 10 digits</font>\';\r\n\t\t\t\t\t  return false;\r\n\t\t\t\t  }\r\n\t\t\t  }\t  \r\n\t\t  } else {\r\n\t\t  var phone = jQuery(phoneNumbers).attr(\'id\');\r\n\t\t  if(null!=phone){\r\n\t\t\t  if((phone.trim())!=\'evening_phone\' ) {\r\n\t\t\t\t  document.getElementById(id).innerHTML =\'* Field cannot be blank\';\r\n\t\t\t\t  return false;\r\n\t\t\t  } else {\r\n\t\t\t\t  document.getElementById(id).innerHTML =\'\';\r\n\t\t\t\t  return true;\r\n\t\t\t  }\r\n\t\t  }\r\n\t\t  }\r\n\t   \r\n}\r\n\r\nfunction fnvalidform(){\r\n\tvar divValue = jQuery("#day_phone");\r\n\tvar phoneDivValue = jQuery("#evening_phone");\r\n\tvar zipcode = jQuery("#zip");\r\n\tvar country=jQuery( "#countryCode option:selected" ).text().trim();\r\n\r\n\t\tif(null!=divValue && null!=phoneDivValue && undefined!=divValue.val() && undefined !=phoneDivValue.val()){\r\n\t\t\tif(!fnvalidatePhoneNumber(divValue,\'msg-day_phone\') && !fnvalidatePhoneNumber(phoneDivValue,\'msg-evening_phone\'))\r\n\t\t\t\t{\r\n\t\t\t\t\treturn false;\r\n\t\t\t\t}\r\n\t\t}\r\n\t\tif(null!=divValue && undefined!=divValue.val()){\r\n\t\t\tif(!fnvalidatePhoneNumber(divValue,\'msg-day_phone\'))\r\n\t\t\t{\r\n\t\t\t\treturn false;\r\n\t\t\t}\r\n\t\t}\r\n\r\n\t\tif(null!=phoneDivValue && undefined !=phoneDivValue.val()) {\r\n\t\t\tif(!fnvalidatePhoneNumber(phoneDivValue,\'msg-evening_phone\'))\r\n\t\t\t{\r\n\t\t\t\treturn false;\r\n\t\t\t}\r\n\t\t}\r\n\t\tif(null!=zipcode && undefined !=zipcode.val() && zipcode !=\'\' && country !=\'Canada\') {\r\n\t\t\tif(!fnvalidatezipValue(zipcode,\'msg-zip\'))\r\n\t\t\t{\r\n\t\t\t\treturn false;\r\n\t\t\t}\r\n\t\t}\r\n\t\treturn true; \r\n\t}\r\nfunction fnvalidatezipValue(zipcode,errorMessageDiv){\r\n\tvar zipValue = jQuery(zipcode).val();\r\n\tzipValue = zipValue.trim();\r\n\tvar ziplength = zipValue.length;\r\n\t\r\n\tif(ziplength == 5) { \r\n\t\treturn true;  \r\n\t} else {\r\n\t\tupdateDivMessages(errorMessageDiv,\'*Please enter a valid 5-digit ZIP Code\'); \r\n\t\treturn false;\r\n\t}\r\n\t\r\n\t}\r\n\r\nfunction fnisNumber(event){ \r\n\r\n\t var keycode = event.which;\r\n    if (!(event.shiftKey == false && (keycode == 9 || keycode == 46 || keycode == 8 || keycode == 37 || keycode == 39 || (keycode >= 48 && keycode <= 57) || (keycode >= 96 && keycode <= 105) ...

# %%
soup= bsoup(response.text, 'lxml')
soup
# Out:
# <!-- Desktop page for search. --><html lang="en">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <base href="https://www.frys.com/"/>
# <title>Fry's Electronics | </title>
# <!-- Turn off telephone number detection. -->
# <meta content="telephone=no" name="format-detection"/>
# <link href="/js/menus.css" media="screen" rel="stylesheet" type="text/css"/>
# <!-- 629171 -->
# <script type="text/javascript">
# function fnvalidatePhoneNumber(phoneNumbers,id) {
# 		  var phonenumber=jQuery(phoneNumbers).val();
# 		  if(phonenumber!=null && phonenumber!='' && phonenumber!=' ') {
# 		  phonenumber = phonenumber.trim();
# 		  var phonenumber_d=phonenumber.replace(/-/gi,"").replace(/[(]/gi,"").replace(/ /gi,"").replace(/[)]/gi,"");
# 			  var regExp1 = "^[0-9]{11,}$";
# 			  var phone = (phonenumber_d).match(regExp1);
# 			  if (phone) {
# 				  jQuery(phoneNumbers).val(phonenumber_d.substring(0,3)+"-"+phonenumber_d.substring(3,6)+"-"+phonenumber_d.substring(6,15));
# 				  document.getElementById(id).innerHTML ='* Phone numbers must be 10 digits';
# 				  return false;
# 			  } else {
# 				  var regExp2 = "^[0-9]{10}$";
# 				  phone = (phonenumber_d).match(regExp2);
# 				  if (phone) {
# 					  document.getElementById(id).innerHTML ='';
# 					  jQuery(phoneNumbers).val(phonenumber_d.substring(0,3)+"-"+phonenumber_d.substring(3,6)+"-"+phonenumber_d.substring(6,15));
# 					  return true;
# 				  }
# 				  else {
# 					  document.getElementById(id).innerHTML ='<font color="#CC3300">* Phone numbers must be 10 digits</font>';
# 					  return false;
# 				  }
# 			  }
# 		  } else {
# 		  var phone = jQuery(phoneNumbers).attr('id');
# 		  if(null!=phone){
# 			  if((phone.trim())!='evening_phone' ) {
# 				  document.getElementById(id).innerHTML ='* Field cannot be blank';
# 				  return false;
# 			  } else {
# 				  document.getElementById(id).innerHTML ='';
# 				  return true;
# 			  }
# 		  }
# 		  }
#
# }
#
# function fnvalidform(){
# 	var divValue = jQuery("#day_phone");
# 	var phoneDivValue = jQuery("#evening_phone");
# 	var zipcode = jQuery("#zip");
# 	var country=jQuery( "#countryCode option:selected" ).text().trim();
#
# 		if(null!=divValue && null!=phoneDivValue && undefined!=divValue.val() && undefined !=phoneDivValue.val()){
# 			if(!fnvalidatePhoneNumber(divValue,'msg-day_phone') && !fnvalidatePhoneNumber(phoneDivValue,'msg-evening_phone'))
# 				{
# 					return false;
# 				}
# 		}
# 		if(null!=divValue && undefined!=divValue.val()){
# 			if(!fnvalidatePhoneNumber(divValue,'msg-day_phone'))
# 			{
# 				return false;
# 			}
# 		}
#
# 		if(null!=phoneDivValue && undefined !=phoneDivValue.val()) {
# 			if(!fnvalidatePhoneNumber(phoneDivValue,'msg-evening_phone'))
# 			{
# 				return false;
# 			}
# 		}
# 		if(null!=zipcode && undefined !=zipcode.val() && zipcode !='' && country !='Canada') {
# 			if(!fnvalidatezipValue(zipcode,'msg-zip'))
# 			{
# 				return false;
# 			}
# 		}
# 		return true;
# 	}
# function fnvalidatezipValue(zipcode,errorMessageDiv){
# 	var zipValue = jQuery(zipcode).val();
# 	zipValue = zipValue.trim();
# 	var ziplength = zipValue.length;
#
# 	if(ziplength == 5) {
# 		return true;
# 	} else {
# 		updateDivMessages(errorMessageDiv,'*Please enter a valid 5-digit ZIP Code');
# 		return false;
# 	}
#
# 	}
#
# function fnisNumber(event){
#
# 	 var keycode = event.which;
#     if (!(event.shiftKey == false && (keycode == 9 || keycode == 46 || keycode == 8 || keycode == 37 || keycode == 39 || (keycode >= 48 && keycode <= 57) || (keycode >= 96 && keycode <= 105)))) {
#         event.preventDefault();
#     }
# }
# </script>
# <!-- 629171 end-->
# <!-- 516370 -->
# <script type="text/javascript">
# window.gr_pageType ="";
# window.gr_prodId = [];
# window.gr_total = [];
# </script>
# <script type="text/javascript">
# function setGoogleRemarketingParam(pagetype,prodid,total){
# 	window.gr_pageType = pagetype;
# 	window.gr_prodId.push(prodid);
# 	window.gr_total.push(total);
# }
# </script>
# <!-- 516370 end-->
# <script src="/js/jquery-3.4.1.min.js" type="text/javascript"></script>
# <link href="css/frys1.0.0.css?ver=105" media="screen" rel="stylesheet" type="text/css"/>
# <link href="js/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://images.frys.com/art/icons/frys_appicon_071714_57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://images.frys.com/art/icons/frys_appicon_071714_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://images.frys.com/art/icons/frys_appicon_071714_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://images.frys.com/art/icons/frys_appicon_071714_144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <meta content="0489C5FB2EF574231482A9798D012E12" name="msvalidate.01"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script>
# //Added Function as callback to close the panel on mobile.
# function closeMenuPanel() {
# 	if(jQuery("#csMenu").length && (!jQuery("#csMenu").hasClass("ui-panel-closed")) && jQuery("#csMenu").hasClass("ui-panel-display-reveal")) {
# 		if(typeof $jq3 != "undefined") {
# 			$jq3("#csMenu").panel("close");
# 		}
# 		// else --
# 		// Panel is not initialized correctly.
# 		// Cannot close it from here.
# 	}
# 	else if(jQuery('#menu-toggle').length && jQuery('#wrapper').length && jQuery('#wrapper').hasClass('toggled')) {
# 			jQuery("#wrapper").toggleClass("toggled");
# 		}
# 	}
# </script>
# <!-- MAIN OL ENGINE -->
# <script charset="windows-1252" language="javascript" src="/onlineopinionV5/oo_engine.min.js?ver=105" type="text/javascript"></script>
# <!-- MAIN OL STYLESHEET -->
# <link href="/onlineopinionV5/oo_style.css?ver=105" rel="stylesheet" type="text/css"/>
# <!-- Custom Stylesheet for frysmain -->
# <link href="/onlineopinionV5/oo_style_sub.css?ver=105" rel="stylesheet" type="text/css"/>
# </head>
# <script type="text/javascript">
# 	jQuery(function(){
# 	 	var getView=localStorage.getItem("VarName");
# 		if(getView=="grid")
# 		{
# 			//var togrid = "togrid";
# 			//var toGirdDesc = "toGirdDesc";
# 			//jQuery(".product").addClass("grid-view");
# 			//jQuery(".toGridRemoveClass").removeClass("col-md-offset-1").removeClass("col-sm-offset-1");
# 			//jQuery(".toGridPrice").removeClass("col-md-offset-3").removeClass("col-sm-offset-2");
# 			//equalizeDiv(togrid);
# 			//equalizeDiv(toGirdDesc);
# 			switchToGrid();
# 		}
# 		else{
# 			//jQuery(".product").removeClass("grid-view").css({height: ""});
# 			//jQuery(".toGirdDesc").css({height:""});
# 			//jQuery(".toGridRemoveClass").addClass("col-md-offset-1").addClass("col-sm-offset-1");
# 			//jQuery(".toGridPrice").addClass("col-md-offset-3").addClass("col-sm-offset-2");
# 			switchToList();
# 		}
# 	});
# 	</script>
# <body onload="convertSelectToUlLI();">
# <div id="MainContainer" style="box-sizing: content-box; background-color: white;">
# <header>
# <link href="css/all.min.css" rel="stylesheet"/>
# <style>
# div#ispuWrapper *,
# div#homeDelWrapper *,
# div.modal-content * {
# 	box-sizing: border-box;
# }
# 	#cartCountDiv{width: 35px;top: 2.5px;right: 28px;position: absolute;color: rgb(0, 0, 0);font-size: 11px;font-weight: bold;text-align: center;}
# 	.notShown{display:none;}
# 	.dropdown:hover .dropdown-menu {
#     display: block;
#     margin-top: 0;
#  }
#  .no-click-cat{
#  	text-align:left !important;
#     display: inherit;
#     background-color: #f7f7f7 !important;
#     font-size: 1.2em !important;
#     font-weight: normal !important;
#     margin-bottom:5px !important;
#     margin-top:5px !important;
#     border-bottom: 1px solid red !important;
#    }
#   .acct-main-responsive-layout #MainContainer {
#   	box-sizing: content-box;
#   }
# </style>
# <script defer="" type="text/javascript">
# 	function getFloatWithoutComma(strValue){
# 		var floatValue;
# 		if(strValue){
# 			if(strValue.indexOf(',') > -1) {
# 				floatValue = parseFloat(strValue.replace(/,/g,''));
# 			}
# 			else{
# 				floatValue = parseFloat(strValue);
# 			}
# 		}
# 		return floatValue;
# 	}
# 	function removeArrow(){
# 		 $("a.maintainHover").removeClass("maintainHover");
# 	}
# function signinRedirectPage(event,thisElement) {
# 	event.preventDefault(); // otherwise, it won't wait for the ajax response
# 	jQuerylink = jQuery(thisElement);
# 	var redirectHref = jQuerylink.data("redirecturi");
# 	jQuery.ajax({
#        type: 'POST',
#        data: {searchPage: redirectHref},
#        url:  '/include/searchLogin_page.jsp',
#        success : function() {
#      	 window.location.href = jQuerylink.attr('href');
#           return true;
#        },
#        error : function(xhr,e) {
#     	   var err = eval("(" + xhr.responseText + ")");
#        }
#    });
# }
# //#651670 Starts
# function signIn(event,thisElement) {
# 	event.preventDefault(); // otherwise, it won't wait for the ajax response
# 	jQuerylink = jQuery(thisElement);
# 	var currentHref = window.location.pathname+window.location.search;
# 	jQuery.ajax({
#        type: 'POST',
#        data: {searchPage: currentHref},
#        url:  '/include/searchLogin_page.jsp',
#        success : function() {
#      	 window.location.href = jQuerylink.attr('href');
#           return true;
#        },
#        error : function(xhr,e) {
#     	   console.debug(xhr);
#    		   console.debug(e);
#     	   var err = eval("(" + xhr.responseText + ")");
#        }
#    });
# }
# function signOut(event,thisElement) {
# 	event.preventDefault(); // otherwise, it won't wait for the ajax response
# 	jQuerylink = jQuery(thisElement);
# 	var currentHref = window.location.pathname+window.location.search;
# 	if (jQuery("#thankscontainer").length > 0){
# 		currentHref = "/template/index/";
# 	}
# 	if(window.location.href.indexOf('/wf') >= 0){
# 		currentHref = '/template/index/';
# 	}
# 	jQuery.ajax({
#        type: 'POST',
#        data: {currentPage: currentHref},
#        url:  '/include/current_page.jsp',
#        success : function() {
#               window.location.href = jQuerylink.attr('href');
#               return true;
#           },
#           error : function(xhr,e) {
#        	   console.debug(xhr);
#       		   console.debug(e);
#        	   var err = eval("(" + xhr.responseText + ")");
#           }
#     });
# }
# //#651670 Ends
# </script>
# <style>
# #no_arrow:hover { background:none; background-color:#000000;color:#ffffff;}
# .no_arrow:hover { background:none !important; background-color:#000000;color:#ffffff;}
# .globalbackgroundcolor {background-color: #CCDDFF;}
# .grayLinks {color:#555555;font-family:Verdana,Arial,Helvetica;font-size:10px;font-weight:bold;}
# .search {font-family: Verdana;font-size: 10px;color:#000000}
# p#descpt {font-size: x-small;color: gray; }
# </style>
# <script defer="">
#  $.ajaxSetup ({cache: false });
#  function clrSiteEHU(){
#          $.post("/ac/site_ehu/?dummy="+new Date().getTime(),function(data){}, "text");
#  }
# </script>
# <script defer="">
# jQuery(document).ready(function($) {
# 	//select all the a tag with name equal to modal
# 	$('a[name="modal"]').click(function(e) {
# 		//Cancel the link behaviour
# 		e.preventDefault();
# 		var specButton = $(this).offset();
# 		var specHref = $(this).attr('href');
# 		$(specHref).parent().prependTo('#MainContainer');
# 		$("#mask").prependTo('#MainContainer');
# 		$(specHref).css({
# 		display:"block",
# 		right: "170px",
# 		left: "auto",
# 		top: specButton.top + 20 + "px"
# 		});
# 		//Get the screen height and width
# 		var maskHeight = $(document).height();
# 		var maskWidth = $('body').width();
# 		//Set heigth and width to mask to fill up the whole screen
# 		$('#mask').css({'width':maskWidth,'height':maskHeight});
# 		//transition effect
# 		$('#mask').fadeOut(1000);
# 		$('#mask').fadeTo("slow",0);
# 	});
# 	//if close button is clicked
# 	$('.window .close').click(function (e) {
# 		e.preventDefault();//Cancel the link behavior
# 		$('#mask').hide();
# 		$('.window').hide();
# 	});
# 	//if mask is clicked
# 	$('#mask').click(function () {
# 		$(this).hide();
# 		$('.window').hide();
# 	});
# });
# function closeSPWindow() {
#  	$('#mask').hide();
# 	$('.window').hide();
# 		return false;
# }
# function loadMinSP(prodId,imageHost) {
#     var loadUrl = "/template/inc/priceincart/index.jsp?n=" + prodId + "&ih=" + imageHost;
#     $("#specPrice").load(loadUrl);
#     return false;
# }
# </script>
# <script language="JavaScript" type="text/javascript">
# function isWhiteSpace1(s) {
# 	 var query=document.getElementById("searchbxquery").value;
# 	 query=query.trim();
# 	 document.getElementById("searchbxquery").value=query;
# 	s = s.replace(/[^\w\s\][^,]/gi, '');
# 	for(var i = 0; i < s.length; i++) {
# 		var c = s.charAt(i);
# 		if ((c != ' ') && (c != '\n') && (c != '\t'))
# 		return false;
#         }
# 	return true;
# }
# function chkWhiteSpace(f) {
# 	var msg;    var empty_fields = "";    var errors = "";    if (isWhiteSpace1(f.query_string.value))    {      alert("Please enter your query first!");	  return false;    }         return true;}
# </script>
# <!-- Scr#558221 -->
# <link href="bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- End. -->
# <link href="css/cohead.css?ver=105" media="screen" rel="stylesheet" type="text/css"/>
# <style>
#     /* Scr#558221  */
#     * {
#     -webkit-box-sizing: content-box;
#     -moz-box-sizing: border-box;
#     box-sizing: content-box;
# }
# #pageHeader .navbar-inverse {
#      background-color: white;
#     border-color: white;
# }
#  /* End. */
#         .navbar .popover {
#             width: 400px;
#             -webkit-border-top-left-radius: 0px;
#             -webkit-border-bottom-left-radius: 0px;
#             border-top-left-radius: 0px;
#             border-bottom-left-radius: 0px;
#             overflow: hidden;
#         }
#         .navbar .popover-content {
#             text-align: left;
#         }
#         .navbar .popover-content img {
#             height: 212px;
#             max-width: 250px;
#         }
#         .navbar .dropdown-menu {
#             -webkit-border-top-right-radius: 0px;
#             -webkit-border-bottom-right-radius: 0px;
#             border-top-right-radius: 0px;
#             border-bottom-right-radius: 0px;
#             -webkit-box-shadow: 5px 5px 10px rgba(0, 0, 0, 0.2);
#             -moz-box-shadow: 5px 5px 10px rgba(0, 0, 0, 0.2);
#             box-shadow: 5px 5px 10px rgba(0, 0, 0, 0.2);
#         }
#          .navbar .dropdown-menu > li > a {
#             background-image: none;
#             color: #000000;
#
#         }
#         .navbar .dropdown-menu > li > a:hover {
#             background-image: none;
#             color: #ffffff !important;
#              background-color:#000000 !important;
#              text-decoration:none !important;
#         }
# #SearchContainer {display:inline-block;	width:460px;position:relative;margin-left:10px;height:30px;
# }
# .searchOptions {position:absolute;top:0;left:0;visibility:visible;width:40px;overflow:hidden;opacity: 0;filter: alpha(opacity=0);cursor:pointer;z-index:80; background: transparent;
#    padding: 5px;
#    line-height: 1;
#    border: 1px solid #000;
#    border-color: #000;
#    background-color: #fff;
#    border-radius: 0;
#    height: 100%;}
#
# .search {display:inline;margin:2px 0;padding:4px 0 4px 10px;width:375px; height: 18px;
# }
# .searchGo ,.searchOptions_SelectedVal {
# 	background:-webkit-gradient( linear, left top, left bottom, color-stop(0.05, #000000), color-stop(1, #000000) );
# 	background:-moz-linear-gradient( center top, #7a7a7a 5%, #3b3b3b 100% );
# 	filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#000000', endColorstr='#000000');
# 	background-color:#000000;
# 	-moz-border-radius:6px;
# 	-webkit-border-radius:6px;
# 	border-radius:6px;
# 	border:1px solid #000000;
# 	display:inline-block;
# 	color:#ffffff;
# 	font-family:Arial,Verdana,Helvetica,Sans-Serif;
# 	font-size:15px;
# 	font-weight:bold;
# 	padding:2px 4px;
# 	text-decoration:none;
# }.searchGo:hover {
# 	background:-webkit-gradient( linear, left top, left bottom, color-stop(0.05, #3b3b3b), color-stop(1, #7a7a7a) );
# 	background:-moz-linear-gradient( center top, #3b3b3b 5%, #7a7a7a 100% );
# 	filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#3b3b3b', endColorstr='#7a7a7a');
# 	background-color:#3b3b3b;
# }.searchGo:active {
# 	position:relative;
# 	top:1px;
# }
# .searchGo {float:right;position:relative;}
# .searchOptions_SelectedVal {position:relative;height:20px;margin:2px 0 0;vertical-align:top;font-size:.75em;padding:4px 4px 0;}
# .searchOptions_SelectedVal span {font-size:.75em;vertical-align:middle;}
# }
# </style>
# <div align="left" id="pageHeader" style="height: 116px;">
# <span style="line-height:10px;"> </span>
# <div class="navbar navbar-inverse" style="background-color: white; border-color: white;">
# <style>
# #header-1{
# height:50px;
# width: 1000px;
# margin: 0px 0px 0px 0px;
# }
# #fryslogo{
# float:left;
# height:50px;
# width: 290px;
# width:auto\0;
# }
# #see-ads{
# float:right;
# height:50px;
# width: 200px;
# margin: 0px 0px 0px 0px;
# padding: 0px 0px 0px 0px;
#
#
# font-size:14px;
# }
# #see-ads-text{
# margin: 17px 0px 0px 0px;
# width: 100px;
#
# }
# #see-ads-art{
# width: 65px;
# float:right;
# }
#
# #see-ads a{
# color:#336699;
# text-decoration:none;
# float: left;
# display: inline-block;
# }
# #see-ads a:hover{
# color:#ed1c24;
# text-decoration:underline;
# }
#
# #search-1{
# float:left;
# width: 495px;
# margin: 0px 0px 0px 0px;
# }
# .search {
# width: 490px;
# height:29px;
# /*padding: 0px 0px 0px 0px;*/
#
# margin: 0px 0px 0px 0px;
# }
# .search .searchform {
# margin:0px 0px 0px 0px;
# display: inline;
# height:29px;
# }
# .search .searchbutton {
# position: absolute;
# margin: 0px 0 0 0;
# background: #ed1c24;
# width:50px;
# height: 1.8em;
# font-size:16px;
# font-family:Verdana, Geneva, sans-serif;
# color:#FFF;
# border: 0px;
#  -moz-box-sizing: content-box;
#     -webkit-box-sizing: content-box;
#     box-sizing: content-box;
# }
# .search .searchbx {
# font:normal 15px/15px;
# font-family:Verdana, Geneva, sans-serif;
# color: #555454;
# height: 25px;
# width: 400px;
# background-color: #eeeeee;
#  -moz-box-sizing: content-box;
#     -webkit-box-sizing: content-box;
#     box-sizing: content-box;
# }
# </style>
# <div id="header-1">
# <div id="see-ads">
# <a href="https://www.frys.com/ads/view-all-store-ads?topbannertop010115"><img alt="Weekly Deals" border="0" height="50" hspace="0" src="https://images.frys.com/art/homepage/images/topicon_12-26-15_ads.jpg" width="100"/></a><a href="https://www.frys.com/workflow/AcctMaint/fryspromocom/subc.jsp?site=topbannertop032615"><img alt="Sign Up for PromoCode Emails" border="0" height="50" hspace="0" src="https://images.frys.com/art/homepage/images/topicon_12-26-15_email.jpg" width="100"/></a>
# </div>
# <div id="fryslogo"><a href="https://www.frys.com/template/index/"><img alt="Frys" border="0" src="https://images.frys.com/art/misc/fryslogo.png"/></a></div>
# <div id="search-1">
# <div class="search">
# <form action="/search" method="get" name="search" onsubmit="return chkWhiteSpace(this);" style="margin:0; padding:0;">
# <input name="search_type" type="hidden" value="regular"/>
# <input name="sqxts" type="hidden" value="1"/>
# <input name="isFSK" type="hidden" value="true"/><!-- added for 683738 -->
# <input id="searchCatSel_ip" name="cat" type="hidden" value="0"/>
# <div style="display:none;"><label for="searchbxquery">Keyword Search</label></div>
# <input class="searchbx" id="searchbxquery" name="query_string" placeholder="keyword, model#, or frys.com#" size="" type="text" value=""/>
# <!--   518477 end -->
# <input class="searchbutton" type="submit" value="GO"/>
# </form>
# </div>
# </div>
# </div>
# <br/>
# <div class="navbar-inner" style="width:1000px;">
# <div class=""> <!-- container -->
# <div class="noPrint">
# <ul class="nav">
# <li class="active">
# <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="#" style="font-weight:bold;border-right:1px solid white;color:#ffffff;text-decoration:none;">Cool Stuff We Sell</a>
# <ul class="dropdown-menu" id="dropdown-menu1" role="menu">
# <li data-submenu-id="submenu-1">
# <a href="https://www.frys.com/template/computerspc">PC Computers</a>
# <div class="popover" id="submenu-1" style="width: 250px; max-width: 250px !important;">
# <h3 class="popover-title popover-title-custom">PC Computers</h3>
# <div class="popover-content" style="width: 250px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Ink+&amp;+Toner/">Ink &amp; Toner</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Desktops/">Desktops</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Monitors+&amp;+Projectors/">Monitors &amp; Projectors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Printers+&amp;+Scanners/">Printers &amp; Scanners</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Optical+Drives+&amp;+Storage+Devices/">Optical Drives &amp; Storage Devices</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/USB+Flash+&amp;+Mini+Drives/">USB Flash &amp; Mini Drives</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Video+Cards+&amp;+Video+Devices/">Video Cards &amp; Video Devices</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Microphones,+Headsets+&amp;+Headphones/">Microphones, Headsets &amp; Headphones</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Sound+Cards/">Sound Cards</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Speakers/">Speakers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Surge+Protectors+&amp;+UPS+Battery+Back+Up/">Surge Protectors &amp; UPS Battery Back Up</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/PC+Cables+&amp;+Accessories/">PC Cables &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Input+Devices/">Input Devices</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/PC+Gaming/">PC Gaming</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Keyboards+&amp;+Mice/">Keyboards &amp; Mice</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Blank+Media+&amp;+Storage+Accessories/">Blank Media &amp; Storage Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PCtab/Virtual+Reality+Headsets/">Virtual Reality Headsets</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-2">
# <a href="https://www.frys.com/template/computersmac">Apple</a>
# <div class="popover" id="submenu-2" style="width: 250px; max-width: 250px !important;">
# <h3 class="popover-title popover-title-custom">Apple</h3>
# <div class="popover-content" style="width: 250px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Apple+Watch/">Apple Watch</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/iPhone/">iPhone</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Mac+Desktops/">Mac Desktops</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Mac+Laptops/">Mac Laptops</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Mac+Accessories/">Mac Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Mac+Cables+&amp;+Adapters/">Mac Cables &amp; Adapters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Mac+Keyboards+&amp;+Mice/">Mac Keyboards &amp; Mice</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/MacBook+Accessories/">MacBook Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Graphic+Tablets+&amp;+Stylus/">Graphic Tablets &amp; Stylus</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/iPad/">iPad</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/iPod/">iPod</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/iPad-iPod+Accessories/">iPad/iPod Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/MACtab/Selfie+Sticks/">Selfie Sticks</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-3">
# <a href="https://www.frys.com/template/notebook">Laptops</a>
# <div class="popover" id="submenu-3" style="width: 250px; max-width: 250px !important;">
# <h3 class="popover-title popover-title-custom">Laptops</h3>
# <div class="popover-content" style="width: 250px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Notebooks+and+Tablets/Laptops/">Laptops</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Notebooks+and+Tablets/Laptop+Accessories/">Laptop Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Notebooks+and+Tablets/Cases+&amp;+Backpacks/">Cases &amp; Backpacks</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Notebooks+and+Tablets/Travel+Accessories+&amp;+Luggage/">Travel Accessories &amp; Luggage</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-4">
# <a href="https://www.frys.com/template/tablets">Tablets</a>
# <div class="popover" id="submenu-4" style="width: 250px; max-width: 250px !important;">
# <h3 class="popover-title popover-title-custom">Tablets</h3>
# <div class="popover-content" style="width: 250px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Tablets/">Tablets</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Wearables/">Wearables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Tablet+Accessories/">Tablet Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Cases/">Cases</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Cleaning+Kits/">Cleaning Kits</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Tablets/Portable+Power+Banks/">Portable Power Banks</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-5">
# <a href="https://www.frys.com/template/networking">Networking</a>
# <div class="popover" id="submenu-5" style="width: 250px; max-width: 250px !important;">
# <h3 class="popover-title popover-title-custom">Networking</h3>
# <div class="popover-content" style="width: 250px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Routers/">Routers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Range+Extenders/">Range Extenders</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Cable+&amp;+DSL+Modems+-+Gateways/">Cable &amp; DSL Modems/Gateways</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Adapters+&amp;+Cards/">Adapters &amp; Cards</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Access+Points/">Access Points</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Bridges/">Bridges</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Switches/">Switches</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/PoE+Injectors/">PoE Injectors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Antennas+&amp;+Accessories/">Antennas &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Powerline+Networking/">Powerline Networking</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Firewalls+&amp;+Security+Devices/">Firewalls &amp; Security Devices</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Networkingtab/Print+Servers/">Print Servers</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-6">
# <a href="https://www.frys.com/template/pccomponents">PC Components</a>
# <div class="popover" id="submenu-6" style="width: 500px; max-width: 500px !important;">
# <h3 class="popover-title popover-title-custom">PC Components</h3>
# <div class="popover-content" style="width: 500px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="no-click-cat menu_li">Storage</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Flash+Memory/">Flash Memory</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/External+Hard+Drives/">External Hard Drives</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Internal+Hard+Drives/">Internal Hard Drives</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/SSD+-+Solid+State+Drives/">SSD - Solid State Drives</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Wireless+Storage/">Wireless Storage</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Network+Attached+Storage/">Network Attached Storage</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/SSD+-+HDD+Access/">SSD/HDD Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Flash+Accessories/">Flash Memory Accessories</a></li>
# <li class="no-click-cat menu_li">Internal Components</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Processors/">Processors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Motherboards/">Motherboards</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/OEM+Software/">OEM Software</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Desktop+Memory/">Desktop Memory</a></li>
# </ul></div>
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Laptop+Memory/">Laptop Memory</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Barebones/">Barebones</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Case+Mods/">Case Mods</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Cases/">Cases</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Controller+Cards/">Controller Cards</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/DIY+Accessories/">DIY Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Fans/">Fans</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Heatsinks/">Heatsinks</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Liquid+Cooling/">Liquid Cooling</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Cooling+Accessories/">Cooling Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Internal+PC+Cables/">Internal PC Cables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Power+Supplies/">Power Supplies</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/PC+Components/Server+Solutions/">Server Solutions</a></li>
# </ul>
# </div>
# </div>
# <li data-submenu-id="submenu-7">
# <a href="https://www.frys.com/template/ecomponents">Electronic Components</a>
# <div class="popover" id="submenu-7" style="width: 1000px; max-width: 1000px !important;">
# <h3 class="popover-title popover-title-custom">Electronic Components</h3>
# <div class="popover-content" style="width: 1000px;">
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px; float:left;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Solder+Equipment/">Solder Equipment</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Prototyping/">Prototyping</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Enclosures/">Enclosures</a></li>
# <li class="no-click-cat menu_li">Electrical</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Weather,+Shortwave+Radios+&amp;+Scanners?accipterAreaString=">Weather, Shortwave Radios &amp; Scanners</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/12V+Power/">12V Power</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Alarms/">Alarms</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries?accipterAreaString=">Batteries</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Switches+-+Knobs+&amp;+Dials/">Switches - Knobs &amp; Dials</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Switches+-+Relays/">Switches - Relays</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/AC+-+DC+Adapters/">AC/DC Adapters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Adhesives,+Sealants+&amp;+Tape/">Adhesives, Sealants &amp; Tape</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Flashlights?accipterAreaString=">Flashlights</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/DC+Plugs+&amp;+Jacks/">DC Plugs &amp; Jacks</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Lighting?accipterAreaString=">Lighting</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Alkaline/">Batteries - Alkaline</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Clocks+and+Timers?accipterAreaString=">Clocks and Timers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Extension+Cords/">Extension Cords</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Cordless+Telephone/">Batteries - Cordless Telephone</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Foreign+Voltage/">Foreign Voltage</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Tools+&amp;+Soldering?accipterAreaString=">Tools &amp; Soldering</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Notebook/">Batteries - Notebook</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Fuses/">Fuses</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Photo/">Batteries - Photo</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cable+Management+&amp;+Anti-Static?accipterAreaString=">Cable Management &amp; Anti-Static</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Inverters+&amp;+Jump+Starters/">Inverters &amp; Jump Starters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Rechargeable/">Batteries - Rechargeable</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Plug+Adapters/">Plug Adapters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Prototype+Board+Equipment+&amp;+Books?accipterAreaString=">Prototype Board Equipment &amp; Books</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Batteries+-+Coin+Cell/">Batteries - Coin Cell</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Connectors,+Adapters+&amp;+Gender+Changers/">Connectors, Adapters &amp; Gender Changers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Power+Strips/">Power Strips</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Battery+-+Chargers/">Battery - Chargers</a></li>
# </ul></div>
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Solar/">Solar</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Battery+-+Holders+&amp;+Testers/">Battery - Holders &amp; Testers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Timers+&amp;+Power+Saving/">Timers &amp; Power Saving</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Adhesives+&amp;+Office+Equipment+Cleaners/">Adhesives &amp; Office Equipment Cleaners</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Audio+Cables+&amp;+Accessories/">Cables - Audio Cables &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+USB+&amp;+Firewire/">Cables - USB &amp; Firewire</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Transformers/">Transformers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Circuit+Protection+&amp;+Fuses/">Circuit Protection &amp; Fuses</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Wire+Managment/">Wire Managment</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Adapters+&amp;+Gender+Changers/">Cables - Adapters &amp; Gender Changers</a></li>
# <li class="no-click-cat menu_li">Tools &amp; Storage</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Basic+Tools/">Basic Tools</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Antennas+&amp;+Accessories/">Cables - Antennas &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Cable+Management/">Cables - Cable Management</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Knives+&amp;+Multitools/">Knives &amp; Multitools</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Legacy+PC+Cables/">Cables - Legacy PC Cables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Network+Tools/">Network Tools</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Telephone+Wire+&amp;+Accessories/">Cables - Telephone Wire &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Power+Tools/">Power Tools</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Boxes+&amp;+Cases/">Boxes &amp; Cases</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cables+-+Video+Cables+&amp;+Accessories/">Cables - Video Cables &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Carts+&amp;+Hand+Trucks/">Carts &amp; Hand Trucks</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Equipment+Cases/">Equipment Cases</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/General+Purpose/">General Purpose</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Kits/">Kits</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Metal+Detectors/">Metal Detectors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Multi-Tools+&amp;+Knives/">Multi-Tools &amp; Knives</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Power/">Power</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Speciality+Tools/">Speciality Tools</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Specialty/">Specialty</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Storage+&amp;+Organization?accipterAreaString=">Storage &amp; Organization</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Toolboxes,+Storage+&amp;+Carts/">Toolboxes, Storage &amp; Carts</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cleaning+&amp;+Dusting+Supplies/">Cleaning &amp; Dusting Supplies</a></li>
# </ul></div>
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Tool+Kits/">Tool Kits</a></li>
# <li class="no-click-cat menu_li">Cables &amp; Accessories</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Clocks+&amp;+Timers/">Clocks &amp; Timers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+2+Way+Radios/">Communications - 2 Way Radios</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+Amateur+Radios/">Communications - Amateur Radios</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Hookup+&amp;+Bulk+Wire/">Hookup &amp; Bulk Wire</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+CB+Radios/">Communications - CB Radios</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Legacy+PC+Cables/">Legacy PC Cables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+Radio+Accessories/">Communications - Radio Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Tape/">Tape</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+RF+Scanners/">Communications - RF Scanners</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/USB+&amp;+Firewire/">USB &amp; Firewire</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Cable+Management/">Cable Management</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Communications+-+Shortwave,+Weather+&amp;+Emergency+Radio/">Communications - Shortwave, Weather &amp; Emergency Radio</a></li>
# <li class="no-click-cat menu_li">Audio - Video Cables &amp; Accessories</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Components+-+Chasis+Boxes+&amp;+Accessories/">Components - Chasis Boxes &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Antennas+&amp;+Accessories/">Antennas &amp; Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Components+-+Circuits+&amp;+Connectors/">Components - Circuits &amp; Connectors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Audio+Cables/">Audio Cables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Components+-+Hardware/">Components - Hardware</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Components+-+Fuses/">Components - Fuses</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Video+Cables/">Video Cables</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Components+-+RF+Connectors+&amp;+Adapters/">Components - RF Connectors &amp; Adapters</a></li>
# <li class="no-click-cat menu_li">Telephone Accessories </li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Telephone+Accessories/">Telephone Accessories</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+12-Volt+Accessories/">Electrical - 12-Volt Accessories</a></li>
# <li class="no-click-cat menu_li">Watches &amp; Clocks</li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Clocks/">Clocks</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+DC+Power+Connectors/">Electrical - DC Power Connectors</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Foreign+Travel+Adapters+&amp;+Transformers/">Electrical - Foreign Travel Adapters &amp; Transformers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Timers/">Electrical - Timers</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Watches/">Watches</a></li>
# <li class="no-click-cat menu_li">Communications</li>
# </ul></div>
# <div style="height: 100%; width: 250px; float: left; ">
# <ul style="margin:0; padding:0; list-style-type: none; width: 250px;">
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Inverters/">Electrical - Inverters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Power+Adapters/">Electrical - Power Adapters</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/2-Way+Radios/">2-Way Radios</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Power+Saving+Equipment/">Electrical - Power Saving Equipment</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/GMRS+Radio+-+Business+Band+-+2-way/">GMRS Radio/Business Band/2-way</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Police+Scanners+-+CB+Radios+-+Shortwave+Radios/">Police Scanners/CB Radio/Shortwave Radio</a></li>
# <li class="menu_li"><a href="https://www.frys.com/category/Outpost/Electronic+Components/Electrical+-+Power+Strips+&amp;+Extension+Cords/">Electrical - Power Strips &amp; Extension Cords</a></li>
# ...
# <td align="left" id="rightfont" valign="middle" width="140"><a href="https://www.frys.com/deals">Fry's Deals</a></td>
# </tr>
# </table>
# </div>
# <div id="right-1">
# <table border="0" width="240">
# <tr>
# <td align="center" valign="middle" width="100"></td>
# <td align="left" id="rightfont" valign="middle" width="140"></td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div id="servicefoot4" style="text-align:left">
# <b>Company Info</b><br/><a href="https://www.frys.com/ads/page180?site=csfooter_D#careers">Careers</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A12ContactUs?site=csfooter_D">Contact Us</a><br/><a href="/template/maps/index/?site=csfooter_D">Site Map</a><br/><a href="/template/isp/index/Frys/isp/Middle_Topics/G2%20Store%20Feedback/?site=csfooter_D">Feedback</a><br/><a href="/contest?site=csfooter_D">Contest Info</a><br/><a href="https://images.frys.com/art/email/images/signuppages/fryspromocom.html?site=csfooter_D">Sign up for Email Specials</a><br/><a href="/ac/storeinfo/storelocator?site=csfooter_D">Store Hours and Locations</a><br/><a href="/template/isp/index/Frys/isp/Middle_Topics/G1 Store History?site=csfooter_D">Company History</a>
# <br/><br/><a href="https://fryselectronics.typeform.com/to/pXjZsi" style="font-weight:bold;" target="_blank">Help us improve your Frys.com Experience.</a>
# </div>
# <div id="servicefoot1" style="text-align:left">
# <b>Privacy, Security and Legal </b><br/>
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/C3Privacy?site=csfooter_C">Privacy</a>
# <br/>
# <!--a class="toggle-footer-links" id="CPPArequest" data-toggle="modal" data-target="#cppa-modal" style="cursor: pointer;">CPPA Request</a><br--->
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/C5Advertisements?site=csfooter_C">Advertisements</a><br/>
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/C6LegalNotices?site=csfooter_C">Legal Notice</a>
# <br/>
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/C9CAprivacy?site=csfooter_C">Your California Privacy Rights</a><br/>
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/E1SocialResponsibility?site=csfooter_C">California Transparency in Supply Chains Act</a><br/>
# <a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/C6LegalNotices?site=csfooter_C">Indiana E-Cycle</a><br/>
# <br/><br/><br/><br/><b>More Help</b><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A7PaymentMethods?site=csfooter_G">Payment Methods</a>
# <br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A5CheckingOut?site=csfooter_G">Checking Out</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A2FindingProducts?site=csfooter_G">Finding Products</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A3ExploringProducts?site=csfooter_G">Exploring Products </a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A4UsingtheCart?site=csfooter_G">Using the Cart</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A11WarrantiesRebates?site=csfooter_G">Warranties</a><br/><!--<a href="/template/buying_guide/index?site=csfooter_G">Buying Guides</a>-->
# </div>
# <div id="servicefoot2" style="text-align:left">
# <b>Fry's Stores</b><br/><a href="https://www.frys.com/template/help/index/FE30/Service3/Assistance/Left_Topics/A6ReturningPurchases?site=csfooter_B#06">30-Day Satisfaction Guarantee</a><br/><a href="https://frys.com/utm_src/page006.jsp?utm_source=pricematch&amp;utm_medium=vanityurl&amp;utm_campaign=pricematchoffline">30-Day Price Match Promise </a><br/><a href="/rebates?site=csfooter_B">Rebate Center</a><br/><a href="https://www.frys.com/ads/view-all-store-ads?site=csfooter_B">Store Ads</a><br/><a href="/ac/storeinfo/storelocator/?site=csfooter_B">Store Hours and Locations</a><br/><a href="/template/inHomeServices?site=csfooter_B">Store Services</a><br/><a href="https://images.frys.com/art/storemaps/images/servicedelivery.jpg">Installation &amp; Delivery</a>
# <!--Column 2 Upper-->
# <br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A7PaymentMethods?site=csfooter_B#giftcards">Gift Cards</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/A2DomesticShipping?site=csfooter_B#in-store_pickup">In-Store Pick Up</a><br/><br/><br/><br/>
# <!--Column 2 Lower-->
# <b>Ways to Save</b><br/>
# <a href="https://www.frys.com/template/help/index/FE30/Service3/Assistance/Left_Topics/space1?site=csfooter_F">Personal Promo Codes</a><br/>
# <a href="https://images.frys.com/art/email/images/signuppages/fryspromocom.html?site=csfooter_F">Sign up for Promo Codes</a><br/>
# <a href="https://www.frys.com/ads/view-all-store-ads?site=csfooter_F">Store Ads</a><br/><a href="http://www.facebook.com/fryselectronics">Become a Fan on Facebook</a><br/>
# <a href="/contest?site=csfooter_F">Contest Info</a>
# </div>
# <div id="servicefoot3" style="text-align:left">
# <b>Frys.com Order Info</b><br/><a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/A8WhenWillMyOrderArrive?site=csfooter_A">Shipping and Delivery Time</a><br/><a href="https://www.frys.com/ac/customerservice/?site=csfooter_A">Customer Service</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/A2DomesticShipping?site=csfooter_A#in-store_pickup">In-Store Pick up</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/A5OrderTracking?site=csfooter_A">Order Status</a><br/><a href="/template/help/index/FE30/Service3/Assistance/Left_Topics/A6ReturningPurchases?site=csfooter_A#satisfaction-guarantee">30-Day Satisfaction Guarantee</a>
# <br/><a href="/rebates?site=csfooter_A">Rebate Center</a>
# <br/><a href="/template/help/index/FE30/Service3/Assistance/Middle_Topics/B4IntlShipping?site=csfooter_A">International</a><br/><a href="/template/search/explain_ship?site=csfooter_A#pre-orders">Pre-Orders</a><br/><a href="/template/search/explain_ship?site=csfooter_A#backorders">Backorders</a><br/><a href="https://www.frys.com/template/help/index/FE30/Shipping/ShipsFree?site=csfooter_A">Free Shipping</a><br/><br/><br/><b>Account Info</b><br/>
# <a class="toggle-footer-links" data-redirecturi="https://www.frys.com//wf?a%3DUSER_INFO%2Cw%3DORDERTRACKING=1?site=csfooter_E" href="https://www.frys.com//wf?a%3DUSER_INFO%2Cw%3DORDERTRACKING=1?site=csfooter_E" onclick="signinRedirectPage(event,this)">View Your Order History </a><br/>
# <a class="toggle-footer-links" data-redirecturi="https://www.frys.com//wf?a%3DUSER_INFO%2Cw%3DORDERTRACKING=1?site=csfooter_E" href="https://www.frys.com//wf?a%3DUSER_INFO%2Cw%3DORDERTRACKING=1?site=csfooter_E" onclick="signinRedirectPage(event,this)">Track Your Order</a><br/>
# <a class="toggle-footer-links" data-redirecturi="https://www.frys.com//wf?a%3DACCT_MAINT_EXIST%2Cw%3DACCTMAINT=1?site=csfooter_E" href="https://www.frys.com//wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" onclick="signinRedirectPage(event,this)"> Manage Your Account </a><br/>
# <a class="toggle-wishlist-footer-links" data-redirecturi="https://www.frys.com//wf?a%3DGO_TO_WISHLIST_MAIN%2Cw%3DACCTMAINT=1sss=16414857:2:2260571.0?site=csfooter_E" href="https://www.frys.com//wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" onclick="signinRedirectPage(event,this)"> Wish List </a><br/>
# <!--a class="toggle-footer-links"  id="CPPArequest" data-toggle="modal" data-target="#cppa-modal"  style="cursor: pointer;">Request MyAccount Info</a></div>--></div>
# <!--Do Not Turn this off even if you turn off 09b-->
# <div id="footer-bottom">
# <div font-color="#555454" id="bottom1" style="text-align:left">
#
# Find us:  <!-- <a href="http://plus.google.com/105770605049937525517"><img src="https://images.frys.com/art/misc/google_icon.png" width="25" height="25" border="0" alt="Google+"/></a> --> <a href="http://www.facebook.com/fryselectronics"><img alt="Facebook" border="0" height="25" src="https://images.frys.com/art/misc/facebook_icon.png" width="25"/></a>
#  <a href="http://twitter.com/fryselectronics"><img alt="Twitter" border="0" height="25" src="https://images.frys.com/art/misc/twitter_icon.png" width="25"/></a> <a href="http://youtube.com/fryselectronics"><img alt="Youtube" border="0" height="25" src="https://images.frys.com/art/misc/youtube_icon.png" width="25"/></a> <a href="http://instagram.com/fryselectronics"><img alt="Instagram" border="0" height="25" src="https://images.frys.com/art/misc/Instagram_icon.png" width="25"/></a> <a href="https://www.frys.com/workflow/AcctMaint/fryspromocom/subc.jsp"><img alt="Email Deals" border="0" height="25" src="https://images.frys.com/art/misc/emaildeals_icon.gif" width="25"/></a>
# <!--Do Not Turn This Section off even if you turn off 9b-->
# </div>
# <div font-color="#555454" id="bottom2" style="text-align:left">Copyright© 1995-2020 Fry's Electronics, Incorporated. <br/>All rights reserved.Fry's Electronics, Frys.com and Outpost.com <br/>are registered trademarks of Fry's Electronics, Incorporated.
#       </div>
# <div font-color="#555454" id="bottom3" style="text-align:left">
#       Frys.com prices good for online purchases only.<br/>In-store items and prices at Fry's retail locations may vary.<br/>Some online offers are subject to prior sale and may not be available.
#       </div>
# </div>
# </div>
# <!-- Google Code for All Frys.com Users Remarketing List -->
# <script>
#   if(window.gr_pageType=="" || window.gr_pageType == null){
# 	  window.gr_pageType = "other";
# 	  window.gr_prodId = "";
# 	  window.gr_total = "";
#   }
#   var google_tag_params = {
# 		ecomm_prodid: window.gr_prodId,
# 		ecomm_pagetype: window.gr_pageType,
# 		ecomm_totalvalue: window.gr_total,
# };
#  </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 1014029178;
# var google_conversion_language = "en";
# var google_conversion_format = "3";
# var google_conversion_color = "ffffff";
# var google_conversion_label = "h0XUCIbBvAMQ-rbD4wM";
# var google_remarketing_only = true;
# var google_custom_params = window.google_tag_params;
# var google_conversion_value = 0;
# /* ]]> */
# </script>
# <script src="https://www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="http://www.googleadservices.com/pagead/conversion/1014029178/?value=0&amp;label=h0XUCIbBvAMQ-rbD4wM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <script type="text/javascript">
#  var _lrc = _lrc || [];
#  _lrc.push(['aw_lrid', '386056']);
#  _lrc.push(['ds_lrid', '386066']);
#  (function() {
#  var ga = document.createElement('script'); ga.type = 'text/javascript';
#  ga.src = '//cdn.rlcdn.com/js/ga.js?' + new Date().getTime();
#  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
# </script>
# <script type="text/javascript">
# (function () {
# var tagjs = document.createElement("script");
# var s = document.getElementsByTagName("script")[0];
# tagjs.text = "{'site':'gIgF3sY'}";
# tagjs.async = true;
# tagjs.src = "//s.btstatic.com/tag.js";
# s.parentNode.insertBefore(tagjs, s);
# }());
# </script>
# <noscript>
# <iframe frameborder="0" height="1" marginheight="0" marginwidth="0" scrolling="no" src="//s.thebrighttag.com/iframe?c=gIgF3sY" width="1"></iframe>
# </noscript>
# <p style="font-size: 6px; color: #ddd;">104</p>
# </div></td>
# </tr>
# </table>
# <div aria-labelledby="cppaModal" class="modal fade cppa-confirm-modal" id="cppa-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-sm" role="document">
# <div class="modal-content">
# <div id="phone-contact-section">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h4 class="modal-title">Request MyAccount Info</h4>
# </div>
# <div id="cppa_append">
# <div class="modal-body hide" id="cppa200">
# <p class="accountInfocpp"><strong>Thank You.</strong><br/>your request for account info has been processed.</p>
# </div>
# <div class="modal-body hide" id="cppa400">
# <p class="accountInfocpp"><strong>Error!</strong><br/>Something went wrong while processing your request.</p>
# </div>
# <div class="modal-body hide" id="cppaLogin">
# <p class="accountInfocpp"><strong>Please try again after Signing in.</strong></p> <a href="https://www.frys.com//wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1">
# <br/><button class="btn btn-danger" type="button">SignIn</button></a>
# </div>
# <div class="modal-body hide" id="cppaSubmitted">
# <p class="accountInfocpp"><strong>Request Already Submitted</strong><br/>Request for the information has already been submitted.</p>
# </div>
# <div class="modal-body hide" id="cppaForm">
# <p class="accountInfocpp"><strong>Please select  from  the following options</strong></p><br/>
# <div class="txt-left"><input id="reportCheck" type="checkbox"/> Send me a report of my personal data.<br/></div>
# <div class="txt-left"><input id="sellCheck" type="checkbox"/> Do not sell my personal data<br/></div>
# <div class="txt-left pb-15"><input id="deleteCheck" type="checkbox"/> Delete my personal data.<br/></div>
# <div><input class="btn btn-danger" id="CPPArequestSubmit" type="button" value="Submit"/></div>
# </div>
# </div>
# </div>
# </div><!-- /.modal-content -->
# </div><!-- /.modal-dialog -->
# </div><!-- /.modal -->
# </center>
# <script>
# var countMax = 10;
# function checkSpacerImages() {
#
# 	if (countMax ==0 ) {
# 		return;
# 		}
# 	else {
# 		if(jQuery('img').filter('[height=1][width=1]')!=undefined){
# 			jQuery("img").filter("[height=1][width=1]").attr('alt','');
# 		}
# 		setTimeout(checkSpacerImages,2000);
# 		countMax--;
# 	}
# }
# 	jQuery(document).ready(function() {
#
# 		checkSpacerImages();
#
# 		if(jQuery('#isSigned')!=undefined && jQuery('#isSigned').length === 0) {
#  			jQuery(".toggle-footer-links").each(function(i,e){
#  				var getRedirectUrl = jQuery(e).attr('data-redirecturi');
#  				jQuery(e).attr('href',getRedirectUrl).removeAttr('onclick').removeAttr('data-redirecturi')
#
#  			})
# 		}
#
# 		if(jQuery('#isSignedForWishlist')!=undefined && jQuery('#isSignedForWishlist').length === 0) {
#  			jQuery(".toggle-wishlist-footer-links").each(function(i,e){
#  				var getRedirectUrl = jQuery(e).attr('data-redirecturi');
#  				jQuery(e).attr('href',getRedirectUrl).removeAttr('onclick').removeAttr('data-redirecturi')
#
#  			})
# 		}
# 	});
# </script>
# <script language="JavaScript" src="/js/frtrack.js" type="text/javascript"></script>
# <script language="JavaScript">
# <!--
# if(typeof(global_ref_tr) != "undefined"){
#    getreqInfo(global_ref_tr);
# }
#
#
# -->
# </script>
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-6796986-1', 'auto');
# ga('send', 'pageview');
# </script>
# <script type="text/javascript">
# 	try {
# 		var pageTracker = _gat._getTracker("UA-6796986-1");
# 		pageTracker._setDomainName("frys.com");
# 		pageTracker._setAllowLinker(true);
# 		pageTracker._trackPageview();
# 	} catch(err) {}
# </script>
# <script>
# (function(d, t) {
# var g = d.createElement(t),
# 	s = d.getElementsByTagName(t)[0];
# g.async = true;
# g.src = 'https://apis.google.com/js/plusone.js';
# s.parentNode.insertBefore(g, s);
# })(document, 'script');
# </script>
# <!-- Redmine : #9312 SessionId in footer -->
# <div style="font-size:  10px;color:gray;">
# jback104
#
# </div>
# </footer>
# <a class="back-to-top-desktop" href="javascript:void(0)" style="display:none;"><span class="glyphicon glyphicon-arrow-up"></span> Back to Top</a> <!-- SCR#662009 -->
# </li></div> <!--MainContainer -->
# </li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></div></li></ul></li></ul></div></div></div></div></div></header></div></body></html>

# %%
telescope_containers = soup.find_all('div', {"class":"col-xs-12 col-sm-12 pad_lr_tab5 product togrid"})
telescope_containers
# Out:
# [<div class="col-xs-12 col-sm-12 pad_lr_tab5 product togrid" id="prodCol" style="margin-top: 10px;position: relative;">
#  <div class="col-xs-12 col-sm-4 col-md-4" id="prodImg" style="text-align: center">
#  <!-- start scr #583483 -->
#  <!-- end scr #583483 -->
#  <a data-ajax="false" href="product/9742974;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">
#  <img alt="Frys#9742974" height="200px" onerror="this.onerror=null;setDefaultImage(this,'tn')" src="https://images.frys.com/art/product/300x300/9742974.01.prod.jpg" width="200px"/>
#  </a>
#  </div>
#  <div class="col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc" id="prodDesc" style="margin-top: 5px;">
#  <p class="font_reg productDescp" id="prodDescp">
#  <small><b><a data-ajax="false" href="product/9742974;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm</a></b></small>
#  </p>
#  <div class="col-xs-12 pad_none_tab pad_none_desk prodModel">
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Frys #: </b></span>9742974</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Brand: </b></span>MEADE</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>UPC : </b></span>709942999839</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Model: </b></span>StarPro AZ 70mm Refr</p>
#  <input id="modalZipCode" type="hidden" value="95112"/>
#  <!-- SCR#626509	Start -->
#  <p class="col-xs-6 col-xs-offset-6 text-left font_xs pad_none_tab pad_none_desk price-match-text">
#  									Price Match Request
#
#
#  							<a data-backdrop="static" data-fprice="114.97" data-prod-desc="Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm" data-prod-email="" data-prod-id="9742974" data-prod-phone="" data-prod-username=" " data-target="#priceMatchModal" data-toggle="modal" href="javascript:void(0);">
#  <span aria-hidden="true" class="sr-only">Price Match Request</span><i class="far fa-question-circle"></i>
#  </a>
#  <!-- SCR#639684 -->
#  </p>
#  </div>
#  <!-- SCR#626509	End -->
#  <div class="clearfix"></div>
#  <div id="guestZipWrapper9742974">
#  <div class="col-xs-12 col-sm-12 col-md-12 guestZip" id="guestZip" style="border: 1px solid #949494; font-size:12px; padding: 5px; text-align: center;">
#  <!-- change action from SIGN_IN_BRIDGE to SIGN_IN as per SCR#654306-->
#  <b><a data-ajax="false" href="https://www.frys.com/wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" id="search_sign_in" onclick="signIn(event,this)" style="text-decoration: underline;color:black;">Log In</a> or Enter your ZIP Code to <br/> view availability</b>
#  <br/><span id="errormessageZip9742974" style="color:red;font-size:9px;"></span>
#  <div class="input-group col-xs-12 col-sm-12 col-md-12" style="padding-top: 10px;  margin: 0 auto; width: 100%;text-align: center;">
#  <div class="col-xs-5 col-xs-offset-2 pad_none_desk pad_none_tab">
#  <label class="sr-only" for="pickupZip19742974">ZIP Code</label>
#  <input class="form-control android-keypad-check" data-role="none" id="pickupZip19742974" inputmode="numeric" onkeydown="validateNumericZipCode(event,'pickupZip1','errormessageZip',changeForGuest,9742974,'SHIPPING');" pattern="[0-9]*" placeholder="ZIP Code" style="height: 30px;" type="tel"/></div> <!--Main code #665340 -->
#  <div class="col-xs-3 pad_none_desk pad_none_tab" style="text-align: left;"> <span class="input-group-btn">
#  <button class="btn btn-default visible-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9742974,'SHIPPING');" style="font-size: 10px; background-color: #000000; color: #ffffff;">SUBMIT</button>
#  <button class="btn btn-default hidden-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9742974,'SHIPPING');" style="font-size:12px; height:30px;background-color: #000000; color: #ffffff;" type="button">SUBMIT</button>
#  </span></div>
#  </div>
#  </div></div>
#  <!-- Store Pickup Modal Start -->
#  <div aria-labelledby="storeModal" class="modal fade changeZipModalMain" id="storeModal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-sm" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span aria-hidden="true">x</span>
#  </button>
#  <h5 class="modal-title" id="storeModalHeader">Select a Store<span class="showingNearZipCode">(Showing Stores near ZIP <span aria-label="false" id="selectedStoreZip"></span>)</span></h5>
#  </div>
#  <div class="modal-body">
#  <form class="form-inline pad_none_desk pad_none_mob">
#  <div class="form-group mar_none_desk col-xs-12 pad_none_desk chamgeZipModalForm">
#  <div class="col-xs-4 col-md-4 pad_none_desk" style="padding-right: -10px; padding-right: -19px;">
#  <label class="mt3" for="enterZip" id="enterZipLabel">Enter Zip Code to Search</label>
#  </div>
#  <div class="col-xs-5 col-md-5 pad_none_desk">
#  <input id="storeurl" type="hidden" value="/search?cat=-68822&amp;pType=pDisplay&amp;fq=a Regular Items"/>
#  <input class="form-control android-keypad-check" id="zipcodefromsearch1" inputmode="numeric" onkeydown="validateNumericZipCode(event,'zipcodefromsearch1','errorinzipcodebox',validateZipCode);" pattern="[0-9]*" placeholder="" type="tel"/>
#  <button class="btn btn-default btn-popup btnZipCodeSubmit" name="zipsubmit" onclick="validateZipCode(event,'storeSelectionPopup')" style="background-color: #000001; color: #fff;">Go</button>
#  </div>
#  <div class="col-xs-3 col-md-3 pad_none_desk pad_lr_subBtn btnZipCodeSearch">
#  <button class="btn btn-default btn-popup" name="zipsubmit" onclick="validateZipCode(event)" style="background-color: #000001; color: #fff;">Submit</button>
#  </div>
#  </div>
#  </form>
#  <div class="col-xs-12 pad_none_desk mr_top_10 changeZipFindStores">
#  <span class="col-xs-4 pad_none_desk font_sm mt5 pad_lr_17 pad_none_tab pad_none_mob"><span class="showing-within">Showing Stores within</span><span class="search-within">Search within</span></span>
#  <span class="col-xs-5 pad_lr_desk5 font_sm pad_none_tab pad_none_mob">
#  <select class="form-control input-sm" id="storewithinmiles" onchange="getStoresWithInMiles()" onmouseout="cancelBubble(event);" style="padding-left: 0px !important;padding-right: 0px !important;">
#  <option class="storemileoption" value="10">10 miles</option>
#  <option class="storemileoption" value="20">20 miles</option>
#  <option class="storemileoption" selected="selected" value="50">50 miles</option>
#  <option class="storemileoption" value="100">100 miles</option>
#  <option class="storemileoption" value="10000">6.2pc (All Locations)</option>
#  </select>
#  </span>
#  <span class="col-xs-3 pad_lr_desk5 font_sm mt5" id="storeZipCodeDefault"></span>
#  <input id="storeZipCodeHidden" type="hidden" value=""/>
#  </div>
#  <div class="checkbox1 col-xs-12 pad_none_desk" id="chkLabelDiv" style="padding-left: 20px;padding-top: 10px;">
#  <label id="chkLabel"> <input class="storeCheckbox" id="storeCheckbox" onchange="getMoreStoresForChk(event,'')" style="margin-top: 2px ! important;" type="checkbox"/>
#  															Show only stores with this item available today
#  														</label>
#  </div>
#  <div class="col-xs-12 mar_top_err mar_none_mob mar_none_tab pad_none_desk" style="margin-top: 6px; margin-bottom:8px;">
#  <span id="errorinzipcodebox" style="color: red;"></span>
#  </div>
#  </div>
#  <div class="clearfix"></div>
#  <div class="modal-footer" id="storebox"></div>
#  <div aria-label="Close" class="btn btn-block btn-danger btn-lg btn-store-modal-exit" data-dismiss="modal" type="button">Exit</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- Store Pickup Modal Ends -->
#  <!-- prodcol ends -->
#  <!-- SCR#525066(end) -->
#  <div class="col-xs-12 col-sm-4 col-md-3 pad_lr_mob5 pad_l_none toGridPriceHeight" id="prodOther">
#  <!-- scr#558221 -->
#  <!-- End. -->
#  <ul class="list-unstyled xs_text mar_none_tab mar_none_desk font_xs_desk pad_none_tab pad_none_desk font_xs_mob">
#  <li class="cls_display_none pull-left col-xs-6 pad_none_desk text-right" id="did_price1textdiv">
#  <p><span class="" id="l_price1_text_9742974">Price:</span></p>
#  </li>
#  <!-- 623552 starts -->
#  <li class="pull-right col-xs-6 pad_none_desk text-right" id="did_price1valuediv">
#  <!-- put check to increase the size of current price for WAS Products -->
#  <p style="margin-bottom:0px; margin-top:10px;"><label class="red_txt" id="l_price1_value_9742974" style="font-size: 18px; margin-bottom:0px;">
#  <b>$114.97</b></label></p>
#  </li>
#  <!-- 623552 ends -->
#  <div class="" id="did_price2_combo">
#  </div>
#  <div class="cls_display_none" id="did_price3_combo">
#  </div>
#  <!-- SCR#525066(start) -->
#  </ul>
#  <!-- <div style="clear:both;"> -->
#  <div class="clearfix"></div>
#  <!-- SCR#525066(end) -->
#  <!-- Clearance wrapper start  #SCR21629-->
#  <!-- Clearance wrapper end  #SCR21629-->
#  <div class="cls_display_block mt10" id="did_buttons" style="">
#  <div class="cls_display_none" id="did_moreinfobutton" style="">
#  <label class="" id="l_morebutton_9742974"><a href="/product/9742974"><img alt="Special Price" border="0" height="33" src="https://images.frys.com/art/a_new_home_page/images/moreinfo.gif" width="100"/></a></label>
#  </div>
#  <ul id="l_pricecartbutton_9742974" style="text-align:right;">
#  <div><button class="btn btn-success pull-right hidden-xs" data-backdrop="static" data-keyboard="false" data-target="#addToCartModal" data-toggle="modal" onclick="addToCartBtnSearch(9742974)" value="Add To Cart"><span class="glyphicon glyphicon-shopping-cart" value="Add To Cart"></span> Add To Cart</button></div> </ul>
#  <ul><div class="cls_display_none coming_soon9742974" id="did_price8textdiv" style="text-align:right;"><label class="gg" id="l_price8_text_9742974"><div style="float: right;"><div class="coming_soon_btn">Coming Soon<br/><div class="clockdiv" id="countDown" value=""><div><span class="days9742974"></span></div><div><span class="hours9742974"></span></div><div><span class="minutes9742974"></span></div><div><span class="seconds9742974"></span></div></div></div></div> </label></div></ul>
#  <!-- Comming Soon -->
#  <!-- </div> --><!--  All type of button AddToCart, Special Price, See Price In Cart, FromStore -->
#  </div>
#  <div>
#  </div>
#  <!-- --------------------SCR#589760------------------ -->
#  <input name="ProdInfo9742974" type="hidden" value=" MinMap: 111.02 MapPrice: 129.0 MapMethod: 6 isFromAd: false UnilateralPrice: false RegularPrice: 129 Price114.97 WasPrice:129.0"/>
#  <div class="prodOptionsClass0" id="prodOptions">
#  <ul class="font_xs_desk font_xs" style="margin-bottom:0px;">
#  </ul>
#  </div></div>
#  <div id="prod_score">
#
#  						8.1567
#
#  						</div>
#  </div>,
#  <div class="col-xs-12 col-sm-12 pad_lr_tab5 product togrid" id="prodCol" style="margin-top: 10px;position: relative;">
#  <div class="col-xs-12 col-sm-4 col-md-4" id="prodImg" style="text-align: center">
#  <!-- start scr #583483 -->
#  <!-- end scr #583483 -->
#  <a data-ajax="false" href="product/9672093;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">
#  <img alt="Frys#9672093" height="200px" onerror="this.onerror=null;setDefaultImage(this,'tn')" src="https://images.frys.com/art/product/300x300/9672093.01.prod.jpg" width="200px"/>
#  </a>
#  </div>
#  <div class="col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc" id="prodDesc" style="margin-top: 5px;">
#  <p class="font_reg productDescp" id="prodDescp">
#  <small><b><a data-ajax="false" href="product/9672093;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">Meade 50mm Infinity Altazimuth Refractor Telescope</a></b></small>
#  </p>
#  <div class="col-xs-12 pad_none_tab pad_none_desk prodModel">
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Frys #: </b></span>9672093</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Brand: </b></span>MEADE</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>UPC : </b></span>709942997002</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Model: </b></span>209001              </p>
#  <input id="modalZipCode" type="hidden" value="95112"/>
#  <!-- SCR#626509	Start -->
#  <p class="col-xs-6 col-xs-offset-6 text-left font_xs pad_none_tab pad_none_desk price-match-text">
#  									Price Match Request
#
#
#  							<a data-backdrop="static" data-fprice="39.32" data-prod-desc="Meade 50mm Infinity Altazimuth Refractor Telescope" data-prod-email="" data-prod-id="9672093" data-prod-phone="" data-prod-username=" " data-target="#priceMatchModal" data-toggle="modal" href="javascript:void(0);">
#  <span aria-hidden="true" class="sr-only">Price Match Request</span><i class="far fa-question-circle"></i>
#  </a>
#  <!-- SCR#639684 -->
#  </p>
#  </div>
#  <!-- SCR#626509	End -->
#  <div class="clearfix"></div>
#  <div id="guestZipWrapper9672093">
#  <div class="col-xs-12 col-sm-12 col-md-12 guestZip" id="guestZip" style="border: 1px solid #949494; font-size:12px; padding: 5px; text-align: center;">
#  <!-- change action from SIGN_IN_BRIDGE to SIGN_IN as per SCR#654306-->
#  <b><a data-ajax="false" href="https://www.frys.com/wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" id="search_sign_in" onclick="signIn(event,this)" style="text-decoration: underline;color:black;">Log In</a> or Enter your ZIP Code to <br/> view availability</b>
#  <br/><span id="errormessageZip9672093" style="color:red;font-size:9px;"></span>
#  <div class="input-group col-xs-12 col-sm-12 col-md-12" style="padding-top: 10px;  margin: 0 auto; width: 100%;text-align: center;">
#  <div class="col-xs-5 col-xs-offset-2 pad_none_desk pad_none_tab">
#  <label class="sr-only" for="pickupZip19672093">ZIP Code</label>
#  <input class="form-control android-keypad-check" data-role="none" id="pickupZip19672093" inputmode="numeric" onkeydown="validateNumericZipCode(event,'pickupZip1','errormessageZip',changeForGuest,9672093,'SHIPPING');" pattern="[0-9]*" placeholder="ZIP Code" style="height: 30px;" type="tel"/></div> <!--Main code #665340 -->
#  <div class="col-xs-3 pad_none_desk pad_none_tab" style="text-align: left;"> <span class="input-group-btn">
#  <button class="btn btn-default visible-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9672093,'SHIPPING');" style="font-size: 10px; background-color: #000000; color: #ffffff;">SUBMIT</button>
#  <button class="btn btn-default hidden-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9672093,'SHIPPING');" style="font-size:12px; height:30px;background-color: #000000; color: #ffffff;" type="button">SUBMIT</button>
#  </span></div>
#  </div>
#  </div></div>
#  <!-- Store Pickup Modal Start -->
#  <div aria-labelledby="storeModal" class="modal fade changeZipModalMain" id="storeModal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-sm" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span aria-hidden="true">x</span>
#  </button>
#  <h5 class="modal-title" id="storeModalHeader">Select a Store<span class="showingNearZipCode">(Showing Stores near ZIP <span aria-label="false" id="selectedStoreZip"></span>)</span></h5>
#  </div>
#  <div class="modal-body">
#  <form class="form-inline pad_none_desk pad_none_mob">
#  <div class="form-group mar_none_desk col-xs-12 pad_none_desk chamgeZipModalForm">
#  <div class="col-xs-4 col-md-4 pad_none_desk" style="padding-right: -10px; padding-right: -19px;">
#  <label class="mt3" for="enterZip" id="enterZipLabel">Enter Zip Code to Search</label>
#  </div>
#  <div class="col-xs-5 col-md-5 pad_none_desk">
#  <input id="storeurl" type="hidden" value="/search?cat=-68822&amp;pType=pDisplay&amp;fq=a Regular Items"/>
#  <input class="form-control android-keypad-check" id="zipcodefromsearch1" inputmode="numeric" onkeydown="validateNumericZipCode(event,'zipcodefromsearch1','errorinzipcodebox',validateZipCode);" pattern="[0-9]*" placeholder="" type="tel"/>
#  <button class="btn btn-default btn-popup btnZipCodeSubmit" name="zipsubmit" onclick="validateZipCode(event,'storeSelectionPopup')" style="background-color: #000001; color: #fff;">Go</button>
#  </div>
#  <div class="col-xs-3 col-md-3 pad_none_desk pad_lr_subBtn btnZipCodeSearch">
#  <button class="btn btn-default btn-popup" name="zipsubmit" onclick="validateZipCode(event)" style="background-color: #000001; color: #fff;">Submit</button>
#  </div>
#  </div>
#  </form>
#  <div class="col-xs-12 pad_none_desk mr_top_10 changeZipFindStores">
#  <span class="col-xs-4 pad_none_desk font_sm mt5 pad_lr_17 pad_none_tab pad_none_mob"><span class="showing-within">Showing Stores within</span><span class="search-within">Search within</span></span>
#  <span class="col-xs-5 pad_lr_desk5 font_sm pad_none_tab pad_none_mob">
#  <select class="form-control input-sm" id="storewithinmiles" onchange="getStoresWithInMiles()" onmouseout="cancelBubble(event);" style="padding-left: 0px !important;padding-right: 0px !important;">
#  <option class="storemileoption" value="10">10 miles</option>
#  <option class="storemileoption" value="20">20 miles</option>
#  <option class="storemileoption" selected="selected" value="50">50 miles</option>
#  <option class="storemileoption" value="100">100 miles</option>
#  <option class="storemileoption" value="10000">6.2pc (All Locations)</option>
#  </select>
#  </span>
#  <span class="col-xs-3 pad_lr_desk5 font_sm mt5" id="storeZipCodeDefault"></span>
#  <input id="storeZipCodeHidden" type="hidden" value=""/>
#  </div>
#  <div class="checkbox1 col-xs-12 pad_none_desk" id="chkLabelDiv" style="padding-left: 20px;padding-top: 10px;">
#  <label id="chkLabel"> <input class="storeCheckbox" id="storeCheckbox" onchange="getMoreStoresForChk(event,'')" style="margin-top: 2px ! important;" type="checkbox"/>
#  															Show only stores with this item available today
#  														</label>
#  </div>
#  <div class="col-xs-12 mar_top_err mar_none_mob mar_none_tab pad_none_desk" style="margin-top: 6px; margin-bottom:8px;">
#  <span id="errorinzipcodebox" style="color: red;"></span>
#  </div>
#  </div>
#  <div class="clearfix"></div>
#  <div class="modal-footer" id="storebox"></div>
#  <div aria-label="Close" class="btn btn-block btn-danger btn-lg btn-store-modal-exit" data-dismiss="modal" type="button">Exit</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- Store Pickup Modal Ends -->
#  <!-- prodcol ends -->
#  <!-- SCR#525066(end) -->
#  <div class="col-xs-12 col-sm-4 col-md-3 pad_lr_mob5 pad_l_none toGridPriceHeight" id="prodOther">
#  <!-- scr#558221 -->
#  <!-- End. -->
#  <ul class="list-unstyled xs_text mar_none_tab mar_none_desk font_xs_desk pad_none_tab pad_none_desk font_xs_mob">
#  <li class="cls_display_none pull-left col-xs-6 pad_none_desk text-right" id="did_price1textdiv">
#  <p><span class="" id="l_price1_text_9672093">Price:</span></p>
#  </li>
#  <!-- 623552 starts -->
#  <li class="pull-right col-xs-6 pad_none_desk text-right" id="did_price1valuediv">
#  <!-- put check to increase the size of current price for WAS Products -->
#  <p style="margin-bottom:0px; margin-top:10px;"><label class="red_txt" id="l_price1_value_9672093" style="font-size: 18px; margin-bottom:0px;">
#  <b>$39.32</b></label></p>
#  </li>
#  <!-- 623552 ends -->
#  <div class="" id="did_price2_combo">
#  </div>
#  <div class="cls_display_none" id="did_price3_combo">
#  </div>
#  <!-- SCR#525066(start) -->
#  </ul>
#  <!-- <div style="clear:both;"> -->
#  <div class="clearfix"></div>
#  <!-- SCR#525066(end) -->
#  <!-- Clearance wrapper start  #SCR21629-->
#  <!-- Clearance wrapper end  #SCR21629-->
#  <div class="cls_display_block mt10" id="did_buttons" style="">
#  <div class="cls_display_none" id="did_moreinfobutton" style="">
#  <label class="" id="l_morebutton_9672093"><a href="/product/9672093"><img alt="Special Price" border="0" height="33" src="https://images.frys.com/art/a_new_home_page/images/moreinfo.gif" width="100"/></a></label>
#  </div>
#  <ul id="l_pricecartbutton_9672093" style="text-align:right;">
#  <div><button class="btn btn-success pull-right hidden-xs" data-backdrop="static" data-keyboard="false" data-target="#addToCartModal" data-toggle="modal" onclick="addToCartBtnSearch(9672093)" value="Add To Cart"><span class="glyphicon glyphicon-shopping-cart" value="Add To Cart"></span> Add To Cart</button></div> </ul>
#  <ul><div class="cls_display_none coming_soon9672093" id="did_price8textdiv" style="text-align:right;"><label class="gg" id="l_price8_text_9672093"><div style="float: right;"><div class="coming_soon_btn">Coming Soon<br/><div class="clockdiv" id="countDown" value=""><div><span class="days9672093"></span></div><div><span class="hours9672093"></span></div><div><span class="minutes9672093"></span></div><div><span class="seconds9672093"></span></div></div></div></div> </label></div></ul>
#  <!-- Comming Soon -->
#  <!-- </div> --><!--  All type of button AddToCart, Special Price, See Price In Cart, FromStore -->
#  </div>
#  <div>
#  </div>
#  <!-- --------------------SCR#589760------------------ -->
#  <input name="ProdInfo9672093" type="hidden" value=" MinMap: 0.0 MapPrice: 0.0 MapMethod: 0 isFromAd: false UnilateralPrice: false RegularPrice: 49.95 Price39.32 WasPrice:40.37"/>
#  <div class="prodOptionsClass1" id="prodOptions">
#  <ul class="font_xs_desk font_xs" style="margin-bottom:0px;">
#  </ul>
#  </div></div>
#  <div id="prod_score">
#
#  						8.1567
#
#  						</div>
#  </div>,
#  <div class="col-xs-12 col-sm-12 pad_lr_tab5 product togrid" id="prodCol" style="margin-top: 10px;position: relative;">
#  <div class="col-xs-12 col-sm-4 col-md-4" id="prodImg" style="text-align: center">
#  <!-- start scr #583483 -->
#  <!-- end scr #583483 -->
#  <a data-ajax="false" href="product/9672053;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">
#  <img alt="Frys#9672053" height="200px" onerror="this.onerror=null;setDefaultImage(this,'tn')" src="https://images.frys.com/art/product/300x300/9672053.01.prod.jpg" width="200px"/>
#  </a>
#  </div>
#  <div class="col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc" id="prodDesc" style="margin-top: 5px;">
#  <p class="font_reg productDescp" id="prodDescp">
#  <small><b><a data-ajax="false" href="product/9672053;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">Meade ETX80 Observer 80mm f/5 Achromat Refractor Telescope</a></b></small>
#  </p>
#  <div class="col-xs-12 pad_none_tab pad_none_desk prodModel">
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Frys #: </b></span>9672053</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Brand: </b></span>MEADE</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>UPC : </b></span>709942997491</p>
#  <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
#  <span class="red_txt font_xs"><b>Model: </b></span>205002              </p>
#  <input id="modalZipCode" type="hidden" value="95112"/>
#  <!-- SCR#626509	Start -->
#  <p class="col-xs-6 col-xs-offset-6 text-left font_xs pad_none_tab pad_none_desk price-match-text">
#  									Price Match Request
#
#
#  							<a data-backdrop="static" data-fprice="285.67" data-prod-desc="Meade ETX80 Observer 80mm f/5 Achromat Refractor Telescope" data-prod-email="" data-prod-id="9672053" data-prod-phone="" data-prod-username=" " data-target="#priceMatchModal" data-toggle="modal" href="javascript:void(0);">
#  <span aria-hidden="true" class="sr-only">Price Match Request</span><i class="far fa-question-circle"></i>
#  </a>
#  <!-- SCR#639684 -->
#  </p>
#  </div>
#  <!-- SCR#626509	End -->
#  <div class="clearfix"></div>
#  <div id="guestZipWrapper9672053">
#  <div class="col-xs-12 col-sm-12 col-md-12 guestZip" id="guestZip" style="border: 1px solid #949494; font-size:12px; padding: 5px; text-align: center;">
#  <!-- change action from SIGN_IN_BRIDGE to SIGN_IN as per SCR#654306-->
#  <b><a data-ajax="false" href="https://www.frys.com/wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" id="search_sign_in" onclick="signIn(event,this)" style="text-decoration: underline;color:black;">Log In</a> or Enter your ZIP Code to <br/> view availability</b>
#  <br/><span id="errormessageZip9672053" style="color:red;font-size:9px;"></span>
#  <div class="input-group col-xs-12 col-sm-12 col-md-12" style="padding-top: 10px;  margin: 0 auto; width: 100%;text-align: center;">
#  <div class="col-xs-5 col-xs-offset-2 pad_none_desk pad_none_tab">
#  <label class="sr-only" for="pickupZip19672053">ZIP Code</label>
#  <input class="form-control android-keypad-check" data-role="none" id="pickupZip19672053" inputmode="numeric" onkeydown="validateNumericZipCode(event,'pickupZip1','errormessageZip',changeForGuest,9672053,'SHIPPING');" pattern="[0-9]*" placeholder="ZIP Code" style="height: 30px;" type="tel"/></div> <!--Main code #665340 -->
#  <div class="col-xs-3 pad_none_desk pad_none_tab" style="text-align: left;"> <span class="input-group-btn">
#  <button class="btn btn-default visible-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9672053,'SHIPPING');" style="font-size: 10px; background-color: #000000; color: #ffffff;">SUBMIT</button>
#  <button class="btn btn-default hidden-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9672053,'SHIPPING');" style="font-size:12px; height:30px;background-color: #000000; color: #ffffff;" type="button">SUBMIT</button>
#  </span></div>
#  </div>
#  </div></div>
#  <!-- Store Pickup Modal Start -->
#  <div aria-labelledby="storeModal" class="modal fade changeZipModalMain" id="storeModal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-sm" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span aria-hidden="true">x</span>
#  </button>
#  <h5 class="modal-title" id="storeModalHeader">Select a Store<span class="showingNearZipCode">(Showing Stores near ZIP <span aria-label="false" id="selectedStoreZip"></span>)</span></h5>
#  </div>
#  <div class="modal-body">
#  <form class="form-inline pad_none_desk pad_none_mob">
#  <div class="form-group mar_none_desk col-xs-12 pad_none_desk chamgeZipModalForm">
#  <div class="col-xs-4 col-md-4 pad_none_desk" style="padding-right: -10px; padding-right: -19px;">
#  <label class="mt3" for="enterZip" id="enterZipLabel">Enter Zip Code to Search</label>
#  </div>
#  <div class="col-xs-5 col-md-5 pad_none_desk">
#  <input id="storeurl" type="hidden" value="/search?cat=-68822&amp;pType=pDisplay&amp;fq=a Regular Items"/>
#  <input class="form-control android-keypad-check" id="zipcodefromsearch1" inputmode="numeric" onkeydown="validateNumericZipCode(event,'zipcodefromsearch1','errorinzipcodebox',validateZipCode);" pattern="[0-9]*" placeholder="" type="tel"/>
#  <button class="btn btn-default btn-popup btnZipCodeSubmit" name="zipsubmit" onclick="validateZipCode(event,'storeSelectionPopup')" style="background-color: #000001; color: #fff;">Go</button>
#  </div>
#  <div class="col-xs-3 col-md-3 pad_none_desk pad_lr_subBtn btnZipCodeSearch">
#  <button class="btn btn-default btn-popup" name="zipsubmit" onclick="validateZipCode(event)" style="background-color: #000001; color: #fff;">Submit</button>
#  </div>
#  </div>
#  </form>
#  <div class="col-xs-12 pad_none_desk mr_top_10 changeZipFindStores">
#  <span class="col-xs-4 pad_none_desk font_sm mt5 pad_lr_17 pad_none_tab pad_none_mob"><span class="showing-within">Showing Stores within</span><span class="search-within">Search within</span></span>
#  <span class="col-xs-5 pad_lr_desk5 font_sm pad_none_tab pad_none_mob">
#  <select class="form-control input-sm" id="storewithinmiles" onchange="getStoresWithInMiles()" onmouseout="cancelBubble(event);" style="padding-left: 0px !important;padding-right: 0px !important;">
#  <option class="storemileoption" value="10">10 miles</option>
#  <option class="storemileoption" value="20">20 miles</option>
#  <option class="storemileoption" selected="selected" value="50">50 miles</option>
#  <option class="storemileoption" value="100">100 miles</option>
#  <option class="storemileoption" value="10000">6.2pc (All Locations)</option>
#  </select>
#  </span>
#  <span class="col-xs-3 pad_lr_desk5 font_sm mt5" id="storeZipCodeDefault"></span>
#  <input id="storeZipCodeHidden" type="hidden" value=""/>
#  </div>
#  <div class="checkbox1 col-xs-12 pad_none_desk" id="chkLabelDiv" style="padding-left: 20px;padding-top: 10px;">
#  <label id="chkLabel"> <input class="storeCheckbox" id="storeCheckbox" onchange="getMoreStoresForChk(event,'')" style="margin-top: 2px ! important;" type="checkbox"/>
#  															Show only stores with this item available today
#  														</label>
#  </div>
#  <div class="col-xs-12 mar_top_err mar_none_mob mar_none_tab pad_none_desk" style="margin-top: 6px; margin-bottom:8px;">
#  <span id="errorinzipcodebox" style="color: red;"></span>
#  </div>
#  </div>
#  <div class="clearfix"></div>
#  <div class="modal-footer" id="storebox"></div>
#  <div aria-label="Close" class="btn btn-block btn-danger btn-lg btn-store-modal-exit" data-dismiss="modal" type="button">Exit</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- Store Pickup Modal Ends -->
#  <!-- prodcol ends -->
#  <!-- SCR#525066(end) -->
#  <div class="col-xs-12 col-sm-4 col-md-3 pad_lr_mob5 pad_l_none toGridPriceHeight" id="prodOther">
#  <!-- scr#558221 -->
#  <!-- End. -->
#  <ul class="list-unstyled xs_text mar_none_tab mar_none_desk font_xs_desk pad_none_tab pad_none_desk font_xs_mob">
#  <li class="cls_display_none pull-left col-xs-6 pad_none_desk text-right" id="did_price1textdiv">
#  <p><span class="" id="l_price1_text_9672053">Price:</span></p>
#  </li>
#  <!-- 623552 starts -->
#  <li class="pull-right col-xs-6 pad_none_desk text-right" id="did_price1valuediv">
#  <!-- put check to increase the size of current price for WAS Products -->
#  <p style="margin-bottom:0px; margin-top:10px;"><label class="red_txt" id="l_price1_value_9672053" style="font-size: 18px; margin-bottom:0px;">
#  <b>$285.67</b></label></p>
#  </li>
#  <!-- 623552 ends -->
#  <div class="" id="did_price2_combo">
#  </div>
#  <div class="cls_display_none" id="did_price3_combo">
#  </div>
#  <!-- SCR#525066(start) -->
#  </ul>
#  <!-- <div style="clear:both;"> -->
#  <div class="clearfix"></div>
#  <!-- SCR#525066(end) -->
#  <!-- Clearance wrapper start  #SCR21629-->
#  <!-- Clearance wrapper end  #SCR21629-->
#  <div class="cls_display_block mt10" id="did_buttons" style="">
#  <div class="cls_display_none" id="did_moreinfobutton" style="">
#  <label class="" id="l_morebutton_9672053"><a href="/product/9672053"><img alt="Special Price" border="0" height="33" src="https://images.frys.com/art/a_new_home_page/images/moreinfo.gif" width="100"/></a></label>
#  </div>
#  <ul id="l_pricecartbutton_9672053" style="text-align:right;">
#  <div><button class="btn btn-success pull-right hidden-xs" data-backdrop="static" data-keyboard="false" data-target="#addToCartModal" data-toggle="modal" onclick="addToCartBtnSearch(9672053)" value="Add To Cart"><span class="glyphicon glyphicon-shopping-cart" value="Add To Cart"></span> Add To Cart</button></div> </ul>
#  <ul><div class="cls_display_none coming_soon9672053" id="did_price8textdiv" style="text-align:right;"><label class="gg" id="l_price8_text_9672053"><div style="float: right;"><div class="coming_soon_btn">Coming Soon<br/><div class="clockdiv" id="countDown" value=""><div><span class="days9672053"></span></div><div><span class="hours9672053"></span></div><div><span class="minutes9672053"></span></div><div><span class="seconds9672053"></span></div></div></div></div> </label></div></ul>
#  <!-- Comming Soon -->
#  <!-- </div> --><!--  All type of button AddToCart, Special Price, See Price In Cart, FromStore -->
#  </div>
#  <div>
#  </div>
#  <!-- --------------------SCR#589760------------------ -->
#  <input name="ProdInfo9672053" type="hidden" value=" MinMap: 0.0 MapPrice: 0.0 MapMethod: 0 isFromAd: false UnilateralPrice: false RegularPrice: 289.99 Price285.67 WasPrice:289.99"/>
#  <div class="prodOptionsClass2" id="prodOptions">
#  <ul class="font_xs_desk font_xs" style="margin-bottom:0px;">
#  </ul>
#  </div></div>
#  <div id="prod_score">
#
#  						8.1567
#
#  						</div>
#  </div>]

# %%
telescope_container = telescope_containers[0]
telescope_container
# Out:
# <div class="col-xs-12 col-sm-12 pad_lr_tab5 product togrid" id="prodCol" style="margin-top: 10px;position: relative;">
# <div class="col-xs-12 col-sm-4 col-md-4" id="prodImg" style="text-align: center">
# <!-- start scr #583483 -->
# <!-- end scr #583483 -->
# <a data-ajax="false" href="product/9742974;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">
# <img alt="Frys#9742974" height="200px" onerror="this.onerror=null;setDefaultImage(this,'tn')" src="https://images.frys.com/art/product/300x300/9742974.01.prod.jpg" width="200px"/>
# </a>
# </div>
# <div class="col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc" id="prodDesc" style="margin-top: 5px;">
# <p class="font_reg productDescp" id="prodDescp">
# <small><b><a data-ajax="false" href="product/9742974;jsessionid=2FC7901AF82DFE55986E7F35ED4CCF5A.node1?site=sr:SEARCH:MAIN_RSLT_PG">Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm</a></b></small>
# </p>
# <div class="col-xs-12 pad_none_tab pad_none_desk prodModel">
# <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
# <span class="red_txt font_xs"><b>Frys #: </b></span>9742974</p>
# <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
# <span class="red_txt font_xs"><b>Brand: </b></span>MEADE</p>
# <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
# <span class="red_txt font_xs"><b>UPC : </b></span>709942999839</p>
# <p class="col-xs-6 col-sm-6 col-md-6 font_xs pad_none_tab pad_none_desk grid_p mar-btm">
# <span class="red_txt font_xs"><b>Model: </b></span>StarPro AZ 70mm Refr</p>
# <input id="modalZipCode" type="hidden" value="95112"/>
# <!-- SCR#626509	Start -->
# <p class="col-xs-6 col-xs-offset-6 text-left font_xs pad_none_tab pad_none_desk price-match-text">
# 									Price Match Request
#
#
# 							<a data-backdrop="static" data-fprice="114.97" data-prod-desc="Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm" data-prod-email="" data-prod-id="9742974" data-prod-phone="" data-prod-username=" " data-target="#priceMatchModal" data-toggle="modal" href="javascript:void(0);">
# <span aria-hidden="true" class="sr-only">Price Match Request</span><i class="far fa-question-circle"></i>
# </a>
# <!-- SCR#639684 -->
# </p>
# </div>
# <!-- SCR#626509	End -->
# <div class="clearfix"></div>
# <div id="guestZipWrapper9742974">
# <div class="col-xs-12 col-sm-12 col-md-12 guestZip" id="guestZip" style="border: 1px solid #949494; font-size:12px; padding: 5px; text-align: center;">
# <!-- change action from SIGN_IN_BRIDGE to SIGN_IN as per SCR#654306-->
# <b><a data-ajax="false" href="https://www.frys.com/wf?a%3DSIGN_IN%2Cw%3DCHECKOUT=1" id="search_sign_in" onclick="signIn(event,this)" style="text-decoration: underline;color:black;">Log In</a> or Enter your ZIP Code to <br/> view availability</b>
# <br/><span id="errormessageZip9742974" style="color:red;font-size:9px;"></span>
# <div class="input-group col-xs-12 col-sm-12 col-md-12" style="padding-top: 10px;  margin: 0 auto; width: 100%;text-align: center;">
# <div class="col-xs-5 col-xs-offset-2 pad_none_desk pad_none_tab">
# <label class="sr-only" for="pickupZip19742974">ZIP Code</label>
# <input class="form-control android-keypad-check" data-role="none" id="pickupZip19742974" inputmode="numeric" onkeydown="validateNumericZipCode(event,'pickupZip1','errormessageZip',changeForGuest,9742974,'SHIPPING');" pattern="[0-9]*" placeholder="ZIP Code" style="height: 30px;" type="tel"/></div> <!--Main code #665340 -->
# <div class="col-xs-3 pad_none_desk pad_none_tab" style="text-align: left;"> <span class="input-group-btn">
# <button class="btn btn-default visible-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9742974,'SHIPPING');" style="font-size: 10px; background-color: #000000; color: #ffffff;">SUBMIT</button>
# <button class="btn btn-default hidden-xs" data-role="none" id="zipSearch" onclick="changeForGuest(event,9742974,'SHIPPING');" style="font-size:12px; height:30px;background-color: #000000; color: #ffffff;" type="button">SUBMIT</button>
# </span></div>
# </div>
# </div></div>
# <!-- Store Pickup Modal Start -->
# <div aria-labelledby="storeModal" class="modal fade changeZipModalMain" id="storeModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-sm" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">x</span>
# </button>
# <h5 class="modal-title" id="storeModalHeader">Select a Store<span class="showingNearZipCode">(Showing Stores near ZIP <span aria-label="false" id="selectedStoreZip"></span>)</span></h5>
# </div>
# <div class="modal-body">
# <form class="form-inline pad_none_desk pad_none_mob">
# <div class="form-group mar_none_desk col-xs-12 pad_none_desk chamgeZipModalForm">
# <div class="col-xs-4 col-md-4 pad_none_desk" style="padding-right: -10px; padding-right: -19px;">
# <label class="mt3" for="enterZip" id="enterZipLabel">Enter Zip Code to Search</label>
# </div>
# <div class="col-xs-5 col-md-5 pad_none_desk">
# <input id="storeurl" type="hidden" value="/search?cat=-68822&amp;pType=pDisplay&amp;fq=a Regular Items"/>
# <input class="form-control android-keypad-check" id="zipcodefromsearch1" inputmode="numeric" onkeydown="validateNumericZipCode(event,'zipcodefromsearch1','errorinzipcodebox',validateZipCode);" pattern="[0-9]*" placeholder="" type="tel"/>
# <button class="btn btn-default btn-popup btnZipCodeSubmit" name="zipsubmit" onclick="validateZipCode(event,'storeSelectionPopup')" style="background-color: #000001; color: #fff;">Go</button>
# </div>
# <div class="col-xs-3 col-md-3 pad_none_desk pad_lr_subBtn btnZipCodeSearch">
# <button class="btn btn-default btn-popup" name="zipsubmit" onclick="validateZipCode(event)" style="background-color: #000001; color: #fff;">Submit</button>
# </div>
# </div>
# </form>
# <div class="col-xs-12 pad_none_desk mr_top_10 changeZipFindStores">
# <span class="col-xs-4 pad_none_desk font_sm mt5 pad_lr_17 pad_none_tab pad_none_mob"><span class="showing-within">Showing Stores within</span><span class="search-within">Search within</span></span>
# <span class="col-xs-5 pad_lr_desk5 font_sm pad_none_tab pad_none_mob">
# <select class="form-control input-sm" id="storewithinmiles" onchange="getStoresWithInMiles()" onmouseout="cancelBubble(event);" style="padding-left: 0px !important;padding-right: 0px !important;">
# <option class="storemileoption" value="10">10 miles</option>
# <option class="storemileoption" value="20">20 miles</option>
# <option class="storemileoption" selected="selected" value="50">50 miles</option>
# <option class="storemileoption" value="100">100 miles</option>
# <option class="storemileoption" value="10000">6.2pc (All Locations)</option>
# </select>
# </span>
# <span class="col-xs-3 pad_lr_desk5 font_sm mt5" id="storeZipCodeDefault"></span>
# <input id="storeZipCodeHidden" type="hidden" value=""/>
# </div>
# <div class="checkbox1 col-xs-12 pad_none_desk" id="chkLabelDiv" style="padding-left: 20px;padding-top: 10px;">
# <label id="chkLabel"> <input class="storeCheckbox" id="storeCheckbox" onchange="getMoreStoresForChk(event,'')" style="margin-top: 2px ! important;" type="checkbox"/>
# 															Show only stores with this item available today
# 														</label>
# </div>
# <div class="col-xs-12 mar_top_err mar_none_mob mar_none_tab pad_none_desk" style="margin-top: 6px; margin-bottom:8px;">
# <span id="errorinzipcodebox" style="color: red;"></span>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="modal-footer" id="storebox"></div>
# <div aria-label="Close" class="btn btn-block btn-danger btn-lg btn-store-modal-exit" data-dismiss="modal" type="button">Exit</div>
# </div>
# </div>
# </div>
# </div>
# <!-- Store Pickup Modal Ends -->
# <!-- prodcol ends -->
# <!-- SCR#525066(end) -->
# <div class="col-xs-12 col-sm-4 col-md-3 pad_lr_mob5 pad_l_none toGridPriceHeight" id="prodOther">
# <!-- scr#558221 -->
# <!-- End. -->
# <ul class="list-unstyled xs_text mar_none_tab mar_none_desk font_xs_desk pad_none_tab pad_none_desk font_xs_mob">
# <li class="cls_display_none pull-left col-xs-6 pad_none_desk text-right" id="did_price1textdiv">
# <p><span class="" id="l_price1_text_9742974">Price:</span></p>
# </li>
# <!-- 623552 starts -->
# <li class="pull-right col-xs-6 pad_none_desk text-right" id="did_price1valuediv">
# <!-- put check to increase the size of current price for WAS Products -->
# <p style="margin-bottom:0px; margin-top:10px;"><label class="red_txt" id="l_price1_value_9742974" style="font-size: 18px; margin-bottom:0px;">
# <b>$114.97</b></label></p>
# </li>
# <!-- 623552 ends -->
# <div class="" id="did_price2_combo">
# </div>
# <div class="cls_display_none" id="did_price3_combo">
# </div>
# <!-- SCR#525066(start) -->
# </ul>
# <!-- <div style="clear:both;"> -->
# <div class="clearfix"></div>
# <!-- SCR#525066(end) -->
# <!-- Clearance wrapper start  #SCR21629-->
# <!-- Clearance wrapper end  #SCR21629-->
# <div class="cls_display_block mt10" id="did_buttons" style="">
# <div class="cls_display_none" id="did_moreinfobutton" style="">
# <label class="" id="l_morebutton_9742974"><a href="/product/9742974"><img alt="Special Price" border="0" height="33" src="https://images.frys.com/art/a_new_home_page/images/moreinfo.gif" width="100"/></a></label>
# </div>
# <ul id="l_pricecartbutton_9742974" style="text-align:right;">
# <div><button class="btn btn-success pull-right hidden-xs" data-backdrop="static" data-keyboard="false" data-target="#addToCartModal" data-toggle="modal" onclick="addToCartBtnSearch(9742974)" value="Add To Cart"><span class="glyphicon glyphicon-shopping-cart" value="Add To Cart"></span> Add To Cart</button></div> </ul>
# <ul><div class="cls_display_none coming_soon9742974" id="did_price8textdiv" style="text-align:right;"><label class="gg" id="l_price8_text_9742974"><div style="float: right;"><div class="coming_soon_btn">Coming Soon<br/><div class="clockdiv" id="countDown" value=""><div><span class="days9742974"></span></div><div><span class="hours9742974"></span></div><div><span class="minutes9742974"></span></div><div><span class="seconds9742974"></span></div></div></div></div> </label></div></ul>
# <!-- Comming Soon -->
# <!-- </div> --><!--  All type of button AddToCart, Special Price, See Price In Cart, FromStore -->
# </div>
# <div>
# </div>
# <!-- --------------------SCR#589760------------------ -->
# <input name="ProdInfo9742974" type="hidden" value=" MinMap: 111.02 MapPrice: 129.0 MapMethod: 6 isFromAd: false UnilateralPrice: false RegularPrice: 129 Price114.97 WasPrice:129.0"/>
# <div class="prodOptionsClass0" id="prodOptions">
# <ul class="font_xs_desk font_xs" style="margin-bottom:0px;">
# </ul>
# </div></div>
# <div id="prod_score">
#
# 						8.1567
#
# 						</div>
# </div>

# %%
def scrap_telescope(telescope_container):
    product_dict= {}
    telescope_info = telescope_container.find('div', {"class":"col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc"})

    product_desc_container = telescope_info.find('p')
    product_desc = product_desc_container.text.strip()
    print(product_desc)
    
    product_dict['product_desc']=product_desc
    product_info_container =  telescope_info.find('div', {"class":"col-xs-12 pad_none_tab pad_none_desk prodModel"})

    product_attr_container = product_info_container.find_all('p')

    for product_attr in product_attr_container[:-1]:
        product_val = product_attr.text.strip().split(':')
        product_dict[product_val[0]] = product_val[1]
    return product_dict

# %%
for telescope_container in telescope_containers:
    print(scrap_telescope(telescope_container))
# Out:
# Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm
# {'product_desc': 'Meade StarPro AZ 70mm Refractor Telescope Meade StarPro AZ 70mm Meade StarPro AZ 70mm', 'Frys #': ' 9742974', 'Brand': ' MEADE', 'UPC ': ' 709942999839', 'Model': ' StarPro AZ 70mm Refr'}
# Meade 50mm Infinity Altazimuth Refractor Telescope
# {'product_desc': 'Meade 50mm Infinity\x99 Altazimuth Refractor Telescope', 'Frys #': ' 9672093', 'Brand': ' MEADE', 'UPC ': ' 709942997002', 'Model': ' 209001'}
# Meade ETX80 Observer 80mm f/5 Achromat Refractor Telescope
# {'product_desc': 'Meade ETX80 Observer 80mm f/5 Achromat Refractor Telescope', 'Frys #': ' 9672053', 'Brand': ' MEADE', 'UPC ': ' 709942997491', 'Model': ' 205002'}

# %% [markdown]
# ### Let's look at another example found in a pretty neat article [here](https://towardsdatascience.com/data-science-skills-web-scraping-using-python-d1a85ef607ed)

# %%
# import libraries
from bs4 import BeautifulSoup as bsoup
import urllib.request
import csv

# %%
# specify the url
urlpage =  'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)

# parse the html using beautiful soup and store in variable 'soup'
soup = bsoup(page, 'html.parser')

# %%
soup
# Out:
# <!-- Template Name: League Table page
# -->
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en-GB">
# <!--<![endif]-->
# <!-- the "no-js" class is for Modernizr. -->
# <head id="live2-fasttrack-com"><link data-minify="1" href="https://www.fasttrack.co.uk/wp-content/cache/min/1/491f36ab0b8dd6f7a583b637337b7273.css" rel="stylesheet"/>
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>
#         League table - Fast Track    </title>
# <meta content="League table - Fast Track" name="title"/>
# <meta content="" name="description"/>
# <meta content="" name="keyword"/>
# <meta content="ZYBMlezF37FAeJwYQIBdbJtogbNm9zRcb4fCelYavj8" name="google-site-verification">
# <!-- Speaking of Google, don't forget to set your site up: http://google.com/webmasters -->
# <!-- Start of Google Analytics Code -->
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-37401296-1', 'auto');
# ga('set', 'anonymizeIp', true);
#   ga('send', 'pageview');
#
# </script>
# <!-- End of Google Analytics Code -->
# <meta content="Fast Track" name="author"/>
# <meta content="Copyright Fast Track 2011. All Rights Reserved." name="Copyright"/>
# <!-- Dublin Core Metadata : http://dublincore.org/ -->
# <meta content="Fast Track" name="DC.title"/>
# <!--	<meta name="DC.subject" content="What you're about.">-->
# <meta content="TWK" name="DC.creator"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel="stylesheet" type="text/css"/>
# <!-- CSS: screen, mobile & print are all in the same file -->
# <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/screen.css?ver=3.2" rel="stylesheet"/>
# <link href="https://www.fasttrack.co.uk/xmlrpc.php" rel="pingback">
# <style type="text/css">
#         .hiring-link {
#             display: inline-block;
#             position: relative;
#             top: -23px;
#             margin-right: 30px;
#         }
#
# 				.hiring-link-2 {
# 					margin-right: 40px;
# 				}
#
#         .hiring-link span a {
#             color: white;
#             font-size: 1.2em;
#         }
#
#         .hiring-link span a:hover {
#             color: #b1b1b1;
#         }
#
# 				#menu_button {
# 					margin-left: 30px
# 				}
#
#         @media only screen and (max-width: 700px) {
#             .hiring-link {
#                 display: none;
#             }
#         }
#
#         #wrap-search input[type="text"]:focus {
#             background: black !important;
#         }
#
#     </style>
# <!-- ADD GA CODE HERE -->
# <!-- This site is optimized with the Yoast SEO plugin v14.0.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="index, follow" name="robots">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot">
# <link href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" rel="canonical">
# <meta content="en_GB" property="og:locale">
# <meta content="article" property="og:type">
# <meta content="League table - Fast Track" property="og:title">
# <meta content="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" property="og:url">
# <meta content="Fast Track" property="og:site_name">
# <meta content="2019-10-28T14:26:58+00:00" property="article:modified_time">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@ST_FastTrack" name="twitter:creator">
# <meta content="@ST_FastTrack" name="twitter:site">
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.fasttrack.co.uk/#organization","name":"The Sunday Times Fast Track","url":"https://www.fasttrack.co.uk/","sameAs":["https://www.instagram.com/thesundaytimesfasttrack/","https://www.linkedin.com/company/sunday-times-fast-track/","https://twitter.com/ST_FastTrack"],"logo":{"@type":"ImageObject","@id":"https://www.fasttrack.co.uk/#logo","inLanguage":"en-GB","url":"https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-twitter-logo.png","width":480,"height":480,"caption":"The Sunday Times Fast Track"},"image":{"@id":"https://www.fasttrack.co.uk/#logo"}},{"@type":"WebSite","@id":"https://www.fasttrack.co.uk/#website","url":"https://www.fasttrack.co.uk/","name":"Fast Track","description":"","publisher":{"@id":"https://www.fasttrack.co.uk/#organization"},"potentialAction":[{"@type":"SearchAction","target":"https://www.fasttrack.co.uk/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-GB"},{"@type":"WebPage","@id":"https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/#webpage","url":"https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/","name":"League table - Fast Track","isPartOf":{"@id":"https://www.fasttrack.co.uk/#website"},"datePublished":"2015-12-03T16:53:49+00:00","dateModified":"2019-10-28T14:26:58+00:00","inLanguage":"en-GB","potentialAction":[{"@type":"ReadAction","target":["https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/"]}]}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//js.hs-scripts.com" rel="dns-prefetch">
# <link href="//ajax.googleapis.com" rel="dns-prefetch">
# <link href="//s.w.org" rel="dns-prefetch">
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.fasttrack.co.uk\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.2"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var sdm_ajax_script = {"ajaxurl":"https:\/\/www.fasttrack.co.uk\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script src="https://www.fasttrack.co.uk/wp-content/plugins/simple-download-monitor/js/sdm_wp_scripts.js?ver=5.4.2" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/modernizr-2.6.2.min.js" type="text/javascript"></script>
# <link href="https://www.fasttrack.co.uk/wp-json/" rel="https://api.w.org/">
# <link href="https://www.fasttrack.co.uk/?p=359" rel="shortlink">
# <link href="https://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F" rel="alternate" type="application/json+oembed">
# <link href="https://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F&amp;format=xml" rel="alternate" type="text/xml+oembed">
# <!-- DO NOT COPY THIS SNIPPET! Start of Page Analytics Tracking for HubSpot WordPress plugin v7.30.4-->
# <script type="text/javascript">
# 				var _hsq = _hsq || [];
# 				_hsq.push(["setContentType", "standard-page"]);
# 			</script>
# <!-- DO NOT COPY THIS SNIPPET! End of Page Analytics Tracking for HubSpot WordPress plugin -->
# <style type="text/css">.recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}</style><link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-66x66.jpg" rel="icon" sizes="32x32">
# <link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="icon" sizes="192x192">
# <link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="apple-touch-icon">
# <meta content="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" name="msapplication-TileImage">
# </meta></link></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></link></meta></meta></meta></link></meta></head>
# <body class="page-template page-template-tpl page-template-tpl-league-table page-template-tpltpl-league-table-php page page-id-359 page-child parent-pageid-159">
# <div id="page-wrap">
# <!-- not needed? up to you: http://camendesign.com/code/developpeurs_sans_frontieres -->
# <nav class="navbar navbar-fixed-top">
# <div class="container-fluid">
# <div class="row align-items-center">
# <div class="col text-left">
# <a class="navbar-brand active d-md-none" href="https://www.fasttrack.co.uk">
#                         Tech Track 100</a>
# <a class="navbar-brand fast-track active d-none d-md-block" href="https://www.fasttrack.co.uk">FAST TRACK</a>
# </div>
# <div class="col-auto text-right">
# <div class="navbar-right">
# <div class="hiring-link hiring-link-1">
# <span>
# <a href="https://www.fasttrack.co.uk/covid-19-update/">COVID-19 update</a>
# </span>
# </div>
# <div class="hiring-link hiring-link-2">
# <span>
# <a href="https://www.fasttrack.co.uk/about-us/careers/">We're hiring</a>
# </span>
# </div>
# <div id="wrap-search">
# <form action="https://www.fasttrack.co.uk" autocomplete="on" id="searchform" method="get" name="searchbar_form">
# <input name="post_type[]" type="hidden" value="company_profile"/>
# <input id="search" name="s" placeholder="Company search..." type="text"/><input id="search_submit" type="submit" value="Rechercher"/>
# </form>
# </div>
# <div id="menu_button"><span></span></div>
# </div>
# </div>
# </div>
# <div id="side_menu">
# <ul>
# <li class="list-id-4"><a href="https://www.fasttrack.co.uk/">
#                                     Home</a>
# </li>
# <li class="list-id-29125"><a href="https://www.fasttrack.co.uk/blog/">
#                                     Blog</a>
# </li>
# <li class="list-id-156">
#                                 League tables                                <ul>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">
#                                             Fast Track 100</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/awards-dinners/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/ones-to-watch/">
#                                                     Disruptors/Ones to Watch</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/alumni/">
#                                                     Alumni dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">
#                                             SME Export Track 100</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/awards/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">
#                                             Tech Track 100</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">
#                                                     Green Tech/Ones to Watch</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">
#                                                     Alumni dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">
#                                             International Track 200</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/awards-dinners/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/alumni/">
#                                                     Alumni dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">
#                                             Profit Track 100</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/awards-dinners/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/ones-to-watch/">
#                                                     Ones to Watch</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/alumni/">
#                                                     Alumni dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">
#                                             Top Track 250</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/awards/">
#                                                     Awards dinner</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/top-track-250-ones-to-watch/">
#                                                     Ones to Watch</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/alumni/">
#                                                     Alumni dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# <li class="menu-dropdown"><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">
#                                             Top Track 100</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">Overview</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/league-table/">
#                                                     League table</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/supplement/">
#                                                     Supplement &amp; research</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/awards/">
#                                                     Directors' dinners</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/nominate-a-company/">
#                                                     Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/sponsorship/">
#                                                     Sponsorship</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="list-id-172 menu-dropdown"><a href="https://www.fasttrack.co.uk/about-us/">
#                                     About us</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/about-us/">
# </a></li>
# <li class="list-id-172-712"><a href="https://www.fasttrack.co.uk/about-us/the-team/">
#                                             The team</a></li>
# <li class="list-id-172-228"><a href="https://www.fasttrack.co.uk/about-us/careers/">
#                                             Careers</a></li>
# <li class="list-id-172-4192"><a href="https://www.fasttrack.co.uk/about-us/charity/">
#                                             Charity</a></li>
# <li class="list-id-172-20661"><a href="https://www.fasttrack.co.uk/about-us/data-partners/">
#                                             Data partners</a></li>
# </ul>
# </li>
# <li class="list-id-174"><a href="https://www.fasttrack.co.uk/nominate-a-company/">
#                                     Nominate a company</a>
# </li>
# <li class="list-id-176"><a href="https://www.fasttrack.co.uk/sponsorship/">
#                                     Sponsorship</a>
# </li>
# <li class="list-id-178 menu-dropdown"><a href="https://www.fasttrack.co.uk/media-and-logos/">
#                                     Media and logos</a>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/media-and-logos/">
#                                             Videos</a></li>
# <li class="list-id-178-4196"><a href="https://www.fasttrack.co.uk/media-and-logos/press-releases/">
#                                             Press releases</a></li>
# <li class="list-id-178-4198"><a href="https://www.fasttrack.co.uk/media-and-logos/downloads/">
#                                             Downloads and logos</a></li>
# </ul>
# </li>
# <li class="list-id-180"><a href="https://www.fasttrack.co.uk/contact-us/">
#                                     Contact us</a>
# </li>
# </ul>
# <a href="https://www.linkedin.com/company/sunday-times-fast-track" target="_blank"><img alt="linkedIn" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/linkedin_circle_icon.png"/></a>
# <a href="https://twitter.com/ST_FastTrack" target="_blank"><img alt="twitter" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/twitter_circle_icon.png"/></a>
# <a href="https://www.instagram.com/thesundaytimesfasttrack" target="_blank"><img alt="instagram" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/instagram_circle_icon.png" style="width: 40px; height: 35px;"/></a>
# </div>
# </div>
# </nav>
# <div class="" id="content-wrap">
# <section class="league_header d-none d-md-block">
# <div class="main-title-header">
#
# 					Tech Track 100
# 			</div>
# <div class="container">
# <div class="row justify-content-between">
# <div class="col-sm-4"><img src="https://www.fasttrack.co.uk/wp-content/uploads/TechTrack100-logo-masthead-20th-anniversary-e1586342340544.png" style="padding-bottom: 4px;"/></div>
# <div class="col-sm-8 text-right">
# <div class="title_sponsor">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/sage/">
# <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/Sage-1.png');"></div></a>
# </div>
# <div class="supported">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/barclays/">
# <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/Barclays.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/bdo/">
# <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/bdo.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/bgf/">
# <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/BGF-1.png');" title=""></div>
# </a>
# </div>
# <div class="supported">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/n1-singer/">
# <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/N1-Singer.png');" title=""></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="league_navigation">
# <div class="mobile-league-btn">Menu</div>
# <ul>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">Overview</a></li>
# <li><a class="active" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">League table</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">Supplement &amp; research</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">Awards dinner</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">Green Tech/Ones to Watch</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">Alumni dinners</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">Nominate a company</a></li>
# <li><a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">Sponsorship</a></li>
# </ul>
# </div>
# </section>
# <div class="strip-padding">
# <div class="container">
# <article class="post" id="post-359">
# <h1 class="text-center red-color">Tech Track 100 league table <div class="dropdown">
# <button class="dropbtn button skew_forward">2019</button>
# <div class="dropdown-content">
# <a href="?leagueyear=2019">2019</a>
# <a href="?leagueyear=2018">2018</a>
# <a href="?leagueyear=2017">2017</a>
# <a href="?leagueyear=2016">2016</a>
# <a href="?leagueyear=2015">2015</a>
# <a href="?leagueyear=2014">2014</a>
# <a href="?leagueyear=2013">2013</a>
# <a href="?leagueyear=2012">2012</a>
# <a href="?leagueyear=2011">2011</a>
# <a href="?leagueyear=2010">2010</a>
# <a href="?leagueyear=2009">2009</a>
# <a href="?leagueyear=2008">2008</a>
# <a href="?leagueyear=2007">2007</a>
# <a href="?leagueyear=2006">2006</a>
# <a href="?leagueyear=2005">2005</a>
# <a href="?leagueyear=2004">2004</a>
# <a href="?leagueyear=2003">2003</a>
# <a href="?leagueyear=2002">2002</a>
# <a href="?leagueyear=2001">2001</a>
# </div>
# </div>
# </h1>
# </article>
# <!--				Pull in data from the current year selected in page -->
# <div class="responsive-tabble-wrapper">
# <table class="tableSorter2">
# <thead>
# <tr>
# <th>Rank</th>
# <th>Company</th>
# <th class="">Location</th>
# <th class="no-word-wrap">Year end</th>
# <th class="" style="text-align:right;">Annual sales rise over 3 years</th>
# <th class="" style="text-align:right;">Latest sales £000s</th>
# <th class="" style="text-align:right;">Staff</th>
# <th class="">Comment</th>
# <!--				<th>FYE</th>-->
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/revolut-2/"><span class="company-name">Revolut</span></a>Digital banking services provider</td>
# <td>East London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">507.56%</td>
# <td style="text-align:right;">*58,300</td>
# <td style="text-align:right;">700</td>
# <td>Valued at $1.7bn in 2018 and reported to be raising an additional $500m this year that could value it at $5bn</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>2</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/bizuma-3/"><span class="company-name">Bizuma</span></a>B2B e-commerce platform</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">315.18%</td>
# <td style="text-align:right;">*26,414</td>
# <td style="text-align:right;">114</td>
# <td>Connects wholesale buyers and sellers from over 50 countries</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>3</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/global-e-2/"><span class="company-name">Global-e</span></a>Cross-border ecommerce solutions</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">303.09%</td>
# <td style="text-align:right;">29,297</td>
# <td style="text-align:right;">28</td>
# <td>Its technology helps ecommerce retailers localise their websites in more than 200 markets</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>4</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/jungle-creations/"><span class="company-name">Jungle Creations</span></a>Social media &amp; ecommerce services</td>
# <td>East London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">302.53%</td>
# <td style="text-align:right;">*15,972</td>
# <td style="text-align:right;">159</td>
# <td>Launched the first-ever delivery-only restaurant born from social media</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>5</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/oxford-nanopore-technologies-2/"><span class="company-name">Oxford Nanopore Technologies</span></a>DNA analysis technology</td>
# <td>Oxford</td>
# <td>Dec 18</td>
# <td style="text-align:right;">251.87%</td>
# <td style="text-align:right;">*32,500</td>
# <td style="text-align:right;">439</td>
# <td>Has raised £451m in funding and was valued at £1.5bn last year</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>6</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/lendable/"><span class="company-name">Lendable</span></a>Consumer lending platform</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">242.98%</td>
# <td style="text-align:right;">*19,366</td>
# <td style="text-align:right;">44</td>
# <td>Founder moved to the UK from Germany to start the firm, citing a more favourable financial market</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>7</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/verve-2/"><span class="company-name">Verve</span></a>Marketing software developer</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">235.72%</td>
# <td style="text-align:right;">*21,940</td>
# <td style="text-align:right;">230</td>
# <td>Has implemented full salary transparency in order to combat the gender pay gap</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>8</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/onfido-2/"><span class="company-name">Onfido</span></a>Identity verification software</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">209.15%</td>
# <td style="text-align:right;">*18,591</td>
# <td style="text-align:right;">240</td>
# <td>Has opened offices in the US, Europe, India and Singapore to service its 1,500 customers</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>9</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/reverse-media-group/"><span class="company-name">Reverse Media Group</span></a>Digital publishing agency</td>
# <td>Central London</td>
# <td>Jul 18</td>
# <td style="text-align:right;">208.10%</td>
# <td style="text-align:right;">*7,606</td>
# <td style="text-align:right;">15</td>
# <td>Originally started as an animal onesie clothing company before pivoting to online publishing</td>
# <!--						<td>Jul 18</td>-->
# </tr>
# <tr>
# <td>10</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/rebound-returns/"><span class="company-name">Rebound Returns</span></a>Ecommerce returns technology</td>
# <td>Telford</td>
# <td>Dec 18</td>
# <td style="text-align:right;">191.08%</td>
# <td style="text-align:right;">*16,659</td>
# <td style="text-align:right;">21</td>
# <td>Its platform handles more than 35m online returns transactions every year</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>11</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/clearscore-2/"><span class="company-name">ClearScore</span></a>Credit-checking technology developer</td>
# <td>South London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">177.20%</td>
# <td style="text-align:right;">*42,702</td>
# <td style="text-align:right;">135</td>
# <td>In 2018, £90m worth of mortgages were secured through its site</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>12</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/spoke/"><span class="company-name">SPOKE</span></a>Online menswear supplier</td>
# <td>Richmond</td>
# <td>Oct 18</td>
# <td style="text-align:right;">177.10%</td>
# <td style="text-align:right;">*5,566</td>
# <td style="text-align:right;">36</td>
# <td>Its technology helps customers find the right fit out of 200 clothing size options in just 60 seconds</td>
# <!--						<td>Oct 18</td>-->
# </tr>
# <tr>
# <td>13</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/fsb/"><span class="company-name">FSB</span></a>Gambling platform</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">175.54%</td>
# <td style="text-align:right;">*23,945</td>
# <td style="text-align:right;">93</td>
# <td>Has moved into William Hill's old R&amp;D offices in Shoreditch</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>14</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/decibel/"><span class="company-name">Decibel</span></a>Customer experience technology</td>
# <td>Central London</td>
# <td>Jun 18</td>
# <td style="text-align:right;">165.81%</td>
# <td style="text-align:right;">5,387</td>
# <td style="text-align:right;">68</td>
# <td>Uses AI and machine learning to detect consumers’ feelings of confusion, frustration and engagement</td>
# <!--						<td>Jun 18</td>-->
# </tr>
# <tr>
# <td>15</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/miss-group/"><span class="company-name">Miss Group</span></a>Web hosting provider</td>
# <td>Manchester</td>
# <td>Dec 18</td>
# <td style="text-align:right;">162.06%</td>
# <td style="text-align:right;">*6,925</td>
# <td style="text-align:right;">55</td>
# <td>Has made four acquisitions in the last year, with £19.4m investment from growth-capital firm BGF</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>16</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/complyadvantage-2/"><span class="company-name">ComplyAdvantage</span></a>Anti-money laundering database</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">160.61%</td>
# <td style="text-align:right;">*5,981</td>
# <td style="text-align:right;">165</td>
# <td>Its platform helps 450 customers in 45 countries address compliance issues</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>17</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/ota-insight-2/"><span class="company-name">OTA Insight</span></a>Hospitality technology provider</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">158.14%</td>
# <td style="text-align:right;">*10,295</td>
# <td style="text-align:right;">105</td>
# <td>Works with over 40,000 hotels in 126 countries, including some of the world's largest hotel groups</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>18</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/light-source/"><span class="company-name">Light Source</span></a>Telecoms infrastructure builder</td>
# <td>Nottinghamshire</td>
# <td>Mar 18</td>
# <td style="text-align:right;">146.90%</td>
# <td style="text-align:right;">31,098</td>
# <td style="text-align:right;">96</td>
# <td>Developing a pneumatic rocket launcher that can lay fibre cable 500m from its launch site</td>
# <!--						<td>Mar 18</td>-->
# </tr>
# <tr>
# <td>19</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/digi2al/"><span class="company-name">Digi2al</span></a>Digital technology developer</td>
# <td>Central London</td>
# <td>Jan 19</td>
# <td style="text-align:right;">141.56%</td>
# <td style="text-align:right;">*14,394</td>
# <td style="text-align:right;">11</td>
# <td>Called Digi2al because its software development team works in two-week sprints</td>
# <!--						<td>Jan 19</td>-->
# </tr>
# <tr>
# <td>20</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/perkbox-3/"><span class="company-name">Perkbox</span></a>Employee engagement services</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">131.50%</td>
# <td style="text-align:right;">*53,600</td>
# <td style="text-align:right;">250</td>
# <td>Raised £13.5m in April to boost its expansion in Australia and France</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>21</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/lending-works/"><span class="company-name">Lending Works</span></a>Peer-to-peer lender</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">128.54%</td>
# <td style="text-align:right;">*6,178</td>
# <td style="text-align:right;">42</td>
# <td>Aiming to reach £1bn in loan volume by 2023</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>22</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/faculty/"><span class="company-name">Faculty</span></a>AI software developer</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">125.91%</td>
# <td style="text-align:right;">*5,193</td>
# <td style="text-align:right;">65</td>
# <td>Has worked on more than 300 AI projects for clients including easyJet, Tesco and the BBC</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>23</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/internet-mobile-communications/"><span class="company-name">Internet Mobile Communications</span></a>Telecoms services provider</td>
# <td>Chelmsford</td>
# <td>Jun 19</td>
# <td style="text-align:right;">122.54%</td>
# <td style="text-align:right;">*60,241</td>
# <td style="text-align:right;">32</td>
# <td>Has offices in Chile and Moldova as well as its Essex headquarters</td>
# <!--						<td>Jun 19</td>-->
# </tr>
# <tr>
# <td>24</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/fruugo/"><span class="company-name">Fruugo</span></a>Online shopping platform</td>
# <td>Cumbria</td>
# <td>Dec 18</td>
# <td style="text-align:right;">116.00%</td>
# <td style="text-align:right;">*6,661</td>
# <td style="text-align:right;">35</td>
# <td>Its site has been used by 2m shoppers in 17 languages and 32 countries</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>25</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/featurespace-2/"><span class="company-name">Featurespace</span></a>Analytics software developer</td>
# <td>Cambridge</td>
# <td>Dec 18</td>
# <td style="text-align:right;">110.71%</td>
# <td style="text-align:right;">*9,953</td>
# <td style="text-align:right;">200</td>
# <td>Its anti-fraud technology is used by 19 banks across Europe, the US and Latin America</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>26</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/monterosa/"><span class="company-name">Monterosa</span></a>Audience interaction platform</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">109.56%</td>
# <td style="text-align:right;">*10,099</td>
# <td style="text-align:right;">72</td>
# <td>Its apps for clients including ITV, EA Sports and Nickelodeon have engaged 60m fans in 190 countries</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>27</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/lockwood-publishing/"><span class="company-name">Lockwood Publishing</span></a>Mobile games developer</td>
# <td>Nottingham</td>
# <td>Mar 19</td>
# <td style="text-align:right;">107.97%</td>
# <td style="text-align:right;">*17,950</td>
# <td style="text-align:right;">110</td>
# <td>Creates mobile video games where users can customise their avatar with its own line of evening wear</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>28</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/plan-com-2/"><span class="company-name">Plan.com</span></a>Communications provider</td>
# <td>Isle of Man</td>
# <td>Sep 18</td>
# <td style="text-align:right;">107.83%</td>
# <td style="text-align:right;">*47,881</td>
# <td style="text-align:right;">96</td>
# <td>About 650 partners use its telecoms platform to support more than 100,000 UK business customers</td>
# <!--						<td>Sep 18</td>-->
# </tr>
# <tr>
# <td>29</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/capital-on-tap-3/"><span class="company-name">Capital on Tap</span></a>Business finance provider</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">100.45%</td>
# <td style="text-align:right;">*39,285</td>
# <td style="text-align:right;">73</td>
# <td>Has lent over £1bn to more than 80,000 businesses across the UK</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>30</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/in-touch-networks/"><span class="company-name">In Touch Networks</span></a>Professional networking platform</td>
# <td>Manchester</td>
# <td>Feb 19</td>
# <td style="text-align:right;">98.10%</td>
# <td style="text-align:right;">*7,428</td>
# <td style="text-align:right;">139</td>
# <td>Its platform helps more than 125,000 members access training and find new roles</td>
# <!--						<td>Feb 19</td>-->
# </tr>
# <tr>
# <td>31</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/dv-signage-2/"><span class="company-name">DV Signage</span></a>Corporate AV specialist</td>
# <td>Hertfordshire</td>
# <td>Mar 18</td>
# <td style="text-align:right;">97.82%</td>
# <td style="text-align:right;">*5,150</td>
# <td style="text-align:right;">25</td>
# <td>Has developed a robot receptionist capable of welcoming guests and giving presentations</td>
# <!--						<td>Mar 18</td>-->
# </tr>
# <tr>
# <td>32</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/ogury-3/"><span class="company-name">Ogury</span></a>Mobile data marketing</td>
# <td>East London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">97.77%</td>
# <td style="text-align:right;">62,318</td>
# <td style="text-align:right;">210</td>
# <td>Services clients including eBay, Nike and McDonald's from 13 offices in Europe, the US and Mexico</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>33</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/chameleon-technology/"><span class="company-name">Chameleon Technology</span></a>Smart energy monitoring</td>
# <td>Harrogate</td>
# <td>Dec 18</td>
# <td style="text-align:right;">97.59%</td>
# <td style="text-align:right;">*21,752</td>
# <td style="text-align:right;">46</td>
# <td>More than 4m of its smart in-home displays have been installed in UK homes</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>34</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/iwoca-4/"><span class="company-name">iwoca</span></a>Business finance provider</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">97.06%</td>
# <td style="text-align:right;">*47,534</td>
# <td style="text-align:right;">230</td>
# <td>Has raised £352.7m to date, including a £150m funding round in February</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>35</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/byte/"><span class="company-name">Byte</span></a>Marketing technology agency</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">95.79%</td>
# <td style="text-align:right;">*18,315</td>
# <td style="text-align:right;">96</td>
# <td>3.6m people played an augmented reality rugby game it created for Just Eat</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>36</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/matillion/"><span class="company-name">Matillion</span></a>Data transformation software</td>
# <td>Altrincham</td>
# <td>Dec 18</td>
# <td style="text-align:right;">94.13%</td>
# <td style="text-align:right;">*6,504</td>
# <td style="text-align:right;">87</td>
# <td>Has around 600 customers, including GE, Siemens and Amazon, across 40 countries</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>37</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/bought-by-many-3/"><span class="company-name">Bought By Many</span></a>Specialist insurance platform</td>
# <td>Central London</td>
# <td>Mar 19</td>
# ...
# </tr>
# <tr>
# <td>81</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/captify-3/"><span class="company-name">Captify</span></a>Advertising technology company</td>
# <td>Central London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">58.86%</td>
# <td style="text-align:right;">*43,048</td>
# <td style="text-align:right;">197</td>
# <td>Provides data and marketing insights for over 800 brands including Disney, Apple and Adidas</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>82</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/adaptive-3/"><span class="company-name">Adaptive</span></a>Banking technology developer</td>
# <td>Central London</td>
# <td>Jun 19</td>
# <td style="text-align:right;">58.56%</td>
# <td style="text-align:right;">*28,151</td>
# <td style="text-align:right;">214</td>
# <td>Has more than 200 staff across offices in London, Barcelona, Montreal and New York</td>
# <!--						<td>Jun 19</td>-->
# </tr>
# <tr>
# <td>83</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/student-beans/"><span class="company-name">Student Beans</span></a>Student loyalty network</td>
# <td>Central London</td>
# <td>Jun 19</td>
# <td style="text-align:right;">57.62%</td>
# <td style="text-align:right;">*7,106</td>
# <td style="text-align:right;">107</td>
# <td>Says it helped students save on 72,856 mobile phones and 539,214 pairs of shoes in 12 months</td>
# <!--						<td>Jun 19</td>-->
# </tr>
# <tr>
# <td>84</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/godel-technologies-3/"><span class="company-name">Godel Technologies</span></a>Software developer</td>
# <td>Manchester</td>
# <td>Dec 18</td>
# <td style="text-align:right;">57.21%</td>
# <td style="text-align:right;">*21,711</td>
# <td style="text-align:right;">732</td>
# <td>Is named after the late German mathematician Kurt Gödel</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>85</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/mpb/"><span class="company-name">MPB</span></a>Photography equipment trading platform</td>
# <td>Brighton</td>
# <td>Mar 19</td>
# <td style="text-align:right;">56.21%</td>
# <td style="text-align:right;">*31,909</td>
# <td style="text-align:right;">125</td>
# <td>Building an operational centre in New York to service its US customers</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>86</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/smartsearch/"><span class="company-name">Smartsearch</span></a>Anti-fraud technology developer</td>
# <td>Leeds</td>
# <td>Dec 18</td>
# <td style="text-align:right;">56.21%</td>
# <td style="text-align:right;">8,129</td>
# <td style="text-align:right;">82</td>
# <td>Its anti-money laundering services are used by more than 4,000 client firms and 40,000 users around the world</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>87</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/liberis-2/"><span class="company-name">Liberis</span></a>Business finance provider</td>
# <td>West London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">56.07%</td>
# <td style="text-align:right;">*21,090</td>
# <td style="text-align:right;">105</td>
# <td>Its intelligent pricing tool uses machine learning to give customers bespoke pricing</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>88</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/cloudthing/"><span class="company-name">cloudThing</span></a>Software developer</td>
# <td>West Midlands</td>
# <td>Jan 19</td>
# <td style="text-align:right;">55.84%</td>
# <td style="text-align:right;">*6,056</td>
# <td style="text-align:right;">41</td>
# <td>Delivers IT transformation projects for the British Red Cross and Metropolitan Police</td>
# <!--						<td>Jan 19</td>-->
# </tr>
# <tr>
# <td>89</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/zappi/"><span class="company-name">Zappi</span></a>Consumer insights platform</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">55.19%</td>
# <td style="text-align:right;">24,760</td>
# <td style="text-align:right;">189</td>
# <td>Holds weekly hackathons with its clients and programmers</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>90</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/ticketer/"><span class="company-name">Ticketer</span></a>Electronic ticket machine developer</td>
# <td>Hungerford</td>
# <td>Aug 18</td>
# <td style="text-align:right;">53.83%</td>
# <td style="text-align:right;">14,692</td>
# <td style="text-align:right;">55</td>
# <td>Over 2 billion tickets have been purchased via its electronic ticketing machines</td>
# <!--						<td>Aug 18</td>-->
# </tr>
# <tr>
# <td>91</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/pharmacy-2u/"><span class="company-name">Pharmacy 2U</span></a>Online pharmacy</td>
# <td>Leeds</td>
# <td>Mar 19</td>
# <td style="text-align:right;">53.02%</td>
# <td style="text-align:right;">*61,022</td>
# <td style="text-align:right;">299</td>
# <td>Uses proprietary algorithms and warehouse automation to increase accuracy in medicine dispensing</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>92</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/adaptavist/"><span class="company-name">Adaptavist</span></a>IT consultancy</td>
# <td>Central London</td>
# <td>Sep 18</td>
# <td style="text-align:right;">52.46%</td>
# <td style="text-align:right;">*26,704</td>
# <td style="text-align:right;">162</td>
# <td>Says it works with more than half of Fortune 500 companies</td>
# <!--						<td>Sep 18</td>-->
# </tr>
# <tr>
# <td>93</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/alternative-airlines/"><span class="company-name">Alternative Airlines</span></a>Flight booking website</td>
# <td>Surrey</td>
# <td>Oct 18</td>
# <td style="text-align:right;">51.49%</td>
# <td style="text-align:right;">*9,985</td>
# <td style="text-align:right;">30</td>
# <td>Offers mobile payment solutions for customers from developing countries</td>
# <!--						<td>Oct 18</td>-->
# </tr>
# <tr>
# <td>94</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/biosite-systems-2/"><span class="company-name">Biosite Systems</span></a>Workforce management software</td>
# <td>Solihull</td>
# <td>Jul 18</td>
# <td style="text-align:right;">51.33%</td>
# <td style="text-align:right;">9,756</td>
# <td style="text-align:right;">165</td>
# <td>Its technology is used on 1,000 construction sites, including Hinkley Point C nuclear power station</td>
# <!--						<td>Jul 18</td>-->
# </tr>
# <tr>
# <td>95</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/justpark-2/"><span class="company-name">JustPark</span></a>Smart parking provider</td>
# <td>North London</td>
# <td>Mar 19</td>
# <td style="text-align:right;">50.70%</td>
# <td style="text-align:right;">*24,285</td>
# <td style="text-align:right;">70</td>
# <td>Over 3m drivers use its app to find car parking spaces across the UK</td>
# <!--						<td>Mar 19</td>-->
# </tr>
# <tr>
# <td>96</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/worldremit-4/"><span class="company-name">WorldRemit</span></a>Currency transfer provider</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">50.26%</td>
# <td style="text-align:right;">*90,965</td>
# <td style="text-align:right;">615</td>
# <td>Is valued at more than $900m, having raised more than $375m since 2010</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>97</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/e3d-online-2/"><span class="company-name">E3D Online</span></a>3D printer developer</td>
# <td>Oxfordshire</td>
# <td>Apr 19</td>
# <td style="text-align:right;">50.10%</td>
# <td style="text-align:right;">*6,900</td>
# <td style="text-align:right;">41</td>
# <td>Has grown its exports to account for 75% of its total sales</td>
# <!--						<td>Apr 19</td>-->
# </tr>
# <tr>
# <td>98</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/parentpay-2/"><span class="company-name">Parentpay</span></a>School payment services provider</td>
# <td>Coventry</td>
# <td>Nov 18</td>
# <td style="text-align:right;">49.97%</td>
# <td style="text-align:right;">*30,400</td>
# <td style="text-align:right;">210</td>
# <td>Bought Dutch rival WIS in 2018, gaining access to 85% of the secondary school market in the Netherlands</td>
# <!--						<td>Nov 18</td>-->
# </tr>
# <tr>
# <td>99</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/victor-6/"><span class="company-name">Victor</span></a>Online private jet hire</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">49.56%</td>
# <td style="text-align:right;">*55,100</td>
# <td style="text-align:right;">100</td>
# <td>Counts Sir Elton John among its investors</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# <tr>
# <td>100</td>
# <td><a href="https://www.fasttrack.co.uk/company_profile/dianomi-5/"><span class="company-name">Dianomi</span></a>Financial marketing platform</td>
# <td>Central London</td>
# <td>Dec 18</td>
# <td style="text-align:right;">49.21%</td>
# <td style="text-align:right;">*14,615</td>
# <td style="text-align:right;">27</td>
# <td>Works with eight of the top 10 global asset managers</td>
# <!--						<td>Dec 18</td>-->
# </tr>
# </tbody>
# </table> </div>
# <div class="row"><div class="col-md-8 legend"><p><span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'>* supplied by company  </span>†<span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'> annualised figure</span></p>
# </div></div>
# </div>
# </div>
# <section class="normal-padding d-md-none footer-sponsors">
# <div class="container"><div class="row justify-content-center">
# <div class="col-12"><h2>Sponsors</h2></div>
# <div class="col-6 text-center">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/sage/"><img src="https://www.fasttrack.co.uk/wp-content/uploads/Sage-1.png"/>
# </a>
# </div>
# <div class="col-6 text-center">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/barclays/"><img src="https://www.fasttrack.co.uk/wp-content/uploads/Barclays.png"/></a>
# </div>
# <div class="col-6 text-center">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/bdo/"><img src="https://www.fasttrack.co.uk/wp-content/uploads/bdo.png"/></a>
# </div>
# <div class="col-6 text-center">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/bgf/"><img src="https://www.fasttrack.co.uk/wp-content/uploads/BGF-1.png"/></a>
# </div>
# <div class="col-6 text-center">
# <a href="https://www.fasttrack.co.uk/sponsor-profiles/n1-singer/"><img src="https://www.fasttrack.co.uk/wp-content/uploads/N1-Singer.png"/></a>
# </div>
# </div></div>
# <div class="mobile-only text-center" style="margin-top: 20px;">
# <a class="button skew_forward" href="/league-tables/league-table/sponsorship/">Sponsorship</a>
# </div>
# </section>
# </div>
# </div> <!-- END DIV MAIN CONTENT -->
# <div class="site-footer">
# <div class="container">
# <div class="row">
# <div class="col-sm-3 d-none d-md-block">
# <img class="footer-logo" src="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-logo-white-strapline.png"/>
# </div>
# <div class="col-sm-4 col-md-3 col-6">
# <h5>League tables</h5>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">Fast Track 100</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">SME Export Track 100</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">Tech Track 100</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">International Track 200</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">Profit Track 100</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">Top Track 250</a></li>
# <li><a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">Top Track 100</a></li>
# </ul>
# </div>
# <div class="col-sm-4 col-md-3 col-6">
# <h5>Further info</h5>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/about-us/">About us</a></li>
# <li><a href="https://www.fasttrack.co.uk/nominate-a-company/">Nominate a company</a></li>
# <li><a href="https://www.fasttrack.co.uk/sponsorship/">Sponsorship</a></li>
# <li><a href="https://www.fasttrack.co.uk/media-and-logos/">Media and logos</a></li>
# <li><a href="https://www.fasttrack.co.uk/contact-us/">Contact us</a></li>
# </ul>
# </div>
# <div class="col-sm-4 col-md-3 col-xs-12">
# <h5>Other</h5>
# <ul>
# <li><a href="https://www.fasttrack.co.uk/privacy-cookies-policy/">Privacy &amp; cookies policy</a></li>
# </ul>
# <div class="social-links">
# <a href="https://www.linkedin.com/company/sunday-times-fast-track" target="_blank"><img alt="linkedIn" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/linkedin.svg"/></a>
# <a href="https://twitter.com/ST_FastTrack" target="_blank"><img alt="twitter" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/twitter.svg"/></a>
# <a href="https://www.instagram.com/thesundaytimesfasttrack" target="_blank"><img alt="instagram" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/instagram_circle_icon.png"/></a>
# </div>
# </div>
# </div>
# </div>
# <div class="site-footer__copyright">
# <div class="container">
# <div class="row">
# <div class="col-sm-6 text-center text-sm-left">Copyright Fast Track © 2020</div>
# <div class="col-sm-6 text-center text-sm-right"><a href="http://www.thewebkitchen.co.uk/" target="_blank">Web design</a> by <a href="http://www.thewebkitchen.co.uk/">TWK</a></div>
# </div>
# </div>
# </div>
# </div>
# </body></html>
#
# <script type="text/javascript">
#
# _linkedin_data_partner_id = "323508";
#
# </script><script type="text/javascript">
#
# (function(){var s = document.getElementsByTagName("script")[0];
#
# var b = document.createElement("script");
#
# b.type = "text/javascript";b.async = true;
#
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#
# s.parentNode.insertBefore(b, s);})();
#
# </script>
# <noscript>
# <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=323508&amp;fmt=gif" style="display:none;" width="1">
# </img></noscript>
# <!-- JS ARE LOADED HERE WITH FUNCTION.PHP -->
# <script type="text/javascript">
# /* <![CDATA[ */
# var leadin_wordpress = {"userRole":"visitor","pageType":"page","leadinPluginVersion":"7.30.4"};
# /* ]]> */
# </script>
# <script async="" defer="" id="hs-script-loader" src="//js.hs-scripts.com/6844576.js?integration=WordPress" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/bootstrap.min.js" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/owl.carousel.min.js" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/slick.js" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/lightbox.js" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/script.js?ver=7" type="text/javascript"></script>
# <script src="https://www.fasttrack.co.uk/wp-includes/js/wp-embed.min.js?ver=5.4.2" type="text/javascript"></script>
# <!-- Wordpress-friendly way via functions.php -->
# <!-- Asynchronous google analytics; this is the official snippet.
# 		 Replace UA-XXXXXX-XX with your site's ID and uncomment to enable.
#
# 	<script>
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-XXXXXX-XX']);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 	    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
# 	-->
#
#
# <!-- Cached page for great performance - Debug: cached@1593440272 -->

# %%
# Let's find the data from the table :
table = soup.find('table', attrs={'class': 'tableSorter2'})
results = table.find_all('tr')
print('Number of results', len(results))
# Out:
# Number of results 101

# %%
#Let's look at the top 2 rows to check the structure of each row in our table :
results[:2]
# Out:
# [<tr>
#  <th>Rank</th>
#  <th>Company</th>
#  <th class="">Location</th>
#  <th class="no-word-wrap">Year end</th>
#  <th class="" style="text-align:right;">Annual sales rise over 3 years</th>
#  <th class="" style="text-align:right;">Latest sales £000s</th>
#  <th class="" style="text-align:right;">Staff</th>
#  <th class="">Comment</th>
#  <!--				<th>FYE</th>-->
#  </tr>, <tr>
#  <td>1</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/revolut-2/"><span class="company-name">Revolut</span></a>Digital banking services provider</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">507.56%</td>
#  <td style="text-align:right;">*58,300</td>
#  <td style="text-align:right;">700</td>
#  <td>Valued at $1.7bn in 2018 and reported to be raising an additional $500m this year that could value it at $5bn</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>]

# %%
# create and write headers to a list 
rows = []
rows.append(['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'])
print(rows)
# Out:
# [['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments']]

# %%
results
# Out:
# [<tr>
#  <th>Rank</th>
#  <th>Company</th>
#  <th class="">Location</th>
#  <th class="no-word-wrap">Year end</th>
#  <th class="" style="text-align:right;">Annual sales rise over 3 years</th>
#  <th class="" style="text-align:right;">Latest sales £000s</th>
#  <th class="" style="text-align:right;">Staff</th>
#  <th class="">Comment</th>
#  <!--				<th>FYE</th>-->
#  </tr>, <tr>
#  <td>1</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/revolut-2/"><span class="company-name">Revolut</span></a>Digital banking services provider</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">507.56%</td>
#  <td style="text-align:right;">*58,300</td>
#  <td style="text-align:right;">700</td>
#  <td>Valued at $1.7bn in 2018 and reported to be raising an additional $500m this year that could value it at $5bn</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>2</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/bizuma-3/"><span class="company-name">Bizuma</span></a>B2B e-commerce platform</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">315.18%</td>
#  <td style="text-align:right;">*26,414</td>
#  <td style="text-align:right;">114</td>
#  <td>Connects wholesale buyers and sellers from over 50 countries</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>3</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/global-e-2/"><span class="company-name">Global-e</span></a>Cross-border ecommerce solutions</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">303.09%</td>
#  <td style="text-align:right;">29,297</td>
#  <td style="text-align:right;">28</td>
#  <td>Its technology helps ecommerce retailers localise their websites in more than 200 markets</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>4</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/jungle-creations/"><span class="company-name">Jungle Creations</span></a>Social media &amp; ecommerce services</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">302.53%</td>
#  <td style="text-align:right;">*15,972</td>
#  <td style="text-align:right;">159</td>
#  <td>Launched the first-ever delivery-only restaurant born from social media</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>5</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/oxford-nanopore-technologies-2/"><span class="company-name">Oxford Nanopore Technologies</span></a>DNA analysis technology</td>
#  <td>Oxford</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">251.87%</td>
#  <td style="text-align:right;">*32,500</td>
#  <td style="text-align:right;">439</td>
#  <td>Has raised £451m in funding and was valued at £1.5bn last year</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>6</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/lendable/"><span class="company-name">Lendable</span></a>Consumer lending platform</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">242.98%</td>
#  <td style="text-align:right;">*19,366</td>
#  <td style="text-align:right;">44</td>
#  <td>Founder moved to the UK from Germany to start the firm, citing a more favourable financial market</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>7</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/verve-2/"><span class="company-name">Verve</span></a>Marketing software developer</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">235.72%</td>
#  <td style="text-align:right;">*21,940</td>
#  <td style="text-align:right;">230</td>
#  <td>Has implemented full salary transparency in order to combat the gender pay gap</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>8</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/onfido-2/"><span class="company-name">Onfido</span></a>Identity verification software</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">209.15%</td>
#  <td style="text-align:right;">*18,591</td>
#  <td style="text-align:right;">240</td>
#  <td>Has opened offices in the US, Europe, India and Singapore to service its 1,500 customers</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>9</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/reverse-media-group/"><span class="company-name">Reverse Media Group</span></a>Digital publishing agency</td>
#  <td>Central London</td>
#  <td>Jul 18</td>
#  <td style="text-align:right;">208.10%</td>
#  <td style="text-align:right;">*7,606</td>
#  <td style="text-align:right;">15</td>
#  <td>Originally started as an animal onesie clothing company before pivoting to online publishing</td>
#  <!--						<td>Jul 18</td>-->
#  </tr>, <tr>
#  <td>10</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/rebound-returns/"><span class="company-name">Rebound Returns</span></a>Ecommerce returns technology</td>
#  <td>Telford</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">191.08%</td>
#  <td style="text-align:right;">*16,659</td>
#  <td style="text-align:right;">21</td>
#  <td>Its platform handles more than 35m online returns transactions every year</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>11</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/clearscore-2/"><span class="company-name">ClearScore</span></a>Credit-checking technology developer</td>
#  <td>South London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">177.20%</td>
#  <td style="text-align:right;">*42,702</td>
#  <td style="text-align:right;">135</td>
#  <td>In 2018, £90m worth of mortgages were secured through its site</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>12</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/spoke/"><span class="company-name">SPOKE</span></a>Online menswear supplier</td>
#  <td>Richmond</td>
#  <td>Oct 18</td>
#  <td style="text-align:right;">177.10%</td>
#  <td style="text-align:right;">*5,566</td>
#  <td style="text-align:right;">36</td>
#  <td>Its technology helps customers find the right fit out of 200 clothing size options in just 60 seconds</td>
#  <!--						<td>Oct 18</td>-->
#  </tr>, <tr>
#  <td>13</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/fsb/"><span class="company-name">FSB</span></a>Gambling platform</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">175.54%</td>
#  <td style="text-align:right;">*23,945</td>
#  <td style="text-align:right;">93</td>
#  <td>Has moved into William Hill's old R&amp;D offices in Shoreditch</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>14</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/decibel/"><span class="company-name">Decibel</span></a>Customer experience technology</td>
#  <td>Central London</td>
#  <td>Jun 18</td>
#  <td style="text-align:right;">165.81%</td>
#  <td style="text-align:right;">5,387</td>
#  <td style="text-align:right;">68</td>
#  <td>Uses AI and machine learning to detect consumers’ feelings of confusion, frustration and engagement</td>
#  <!--						<td>Jun 18</td>-->
#  </tr>, <tr>
#  <td>15</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/miss-group/"><span class="company-name">Miss Group</span></a>Web hosting provider</td>
#  <td>Manchester</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">162.06%</td>
#  <td style="text-align:right;">*6,925</td>
#  <td style="text-align:right;">55</td>
#  <td>Has made four acquisitions in the last year, with £19.4m investment from growth-capital firm BGF</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>16</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/complyadvantage-2/"><span class="company-name">ComplyAdvantage</span></a>Anti-money laundering database</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">160.61%</td>
#  <td style="text-align:right;">*5,981</td>
#  <td style="text-align:right;">165</td>
#  <td>Its platform helps 450 customers in 45 countries address compliance issues</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>17</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/ota-insight-2/"><span class="company-name">OTA Insight</span></a>Hospitality technology provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">158.14%</td>
#  <td style="text-align:right;">*10,295</td>
#  <td style="text-align:right;">105</td>
#  <td>Works with over 40,000 hotels in 126 countries, including some of the world's largest hotel groups</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>18</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/light-source/"><span class="company-name">Light Source</span></a>Telecoms infrastructure builder</td>
#  <td>Nottinghamshire</td>
#  <td>Mar 18</td>
#  <td style="text-align:right;">146.90%</td>
#  <td style="text-align:right;">31,098</td>
#  <td style="text-align:right;">96</td>
#  <td>Developing a pneumatic rocket launcher that can lay fibre cable 500m from its launch site</td>
#  <!--						<td>Mar 18</td>-->
#  </tr>, <tr>
#  <td>19</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/digi2al/"><span class="company-name">Digi2al</span></a>Digital technology developer</td>
#  <td>Central London</td>
#  <td>Jan 19</td>
#  <td style="text-align:right;">141.56%</td>
#  <td style="text-align:right;">*14,394</td>
#  <td style="text-align:right;">11</td>
#  <td>Called Digi2al because its software development team works in two-week sprints</td>
#  <!--						<td>Jan 19</td>-->
#  </tr>, <tr>
#  <td>20</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/perkbox-3/"><span class="company-name">Perkbox</span></a>Employee engagement services</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">131.50%</td>
#  <td style="text-align:right;">*53,600</td>
#  <td style="text-align:right;">250</td>
#  <td>Raised £13.5m in April to boost its expansion in Australia and France</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>21</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/lending-works/"><span class="company-name">Lending Works</span></a>Peer-to-peer lender</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">128.54%</td>
#  <td style="text-align:right;">*6,178</td>
#  <td style="text-align:right;">42</td>
#  <td>Aiming to reach £1bn in loan volume by 2023</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>22</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/faculty/"><span class="company-name">Faculty</span></a>AI software developer</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">125.91%</td>
#  <td style="text-align:right;">*5,193</td>
#  <td style="text-align:right;">65</td>
#  <td>Has worked on more than 300 AI projects for clients including easyJet, Tesco and the BBC</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>23</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/internet-mobile-communications/"><span class="company-name">Internet Mobile Communications</span></a>Telecoms services provider</td>
#  <td>Chelmsford</td>
#  <td>Jun 19</td>
#  <td style="text-align:right;">122.54%</td>
#  <td style="text-align:right;">*60,241</td>
#  <td style="text-align:right;">32</td>
#  <td>Has offices in Chile and Moldova as well as its Essex headquarters</td>
#  <!--						<td>Jun 19</td>-->
#  </tr>, <tr>
#  <td>24</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/fruugo/"><span class="company-name">Fruugo</span></a>Online shopping platform</td>
#  <td>Cumbria</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">116.00%</td>
#  <td style="text-align:right;">*6,661</td>
#  <td style="text-align:right;">35</td>
#  <td>Its site has been used by 2m shoppers in 17 languages and 32 countries</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>25</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/featurespace-2/"><span class="company-name">Featurespace</span></a>Analytics software developer</td>
#  <td>Cambridge</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">110.71%</td>
#  <td style="text-align:right;">*9,953</td>
#  <td style="text-align:right;">200</td>
#  <td>Its anti-fraud technology is used by 19 banks across Europe, the US and Latin America</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>26</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/monterosa/"><span class="company-name">Monterosa</span></a>Audience interaction platform</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">109.56%</td>
#  <td style="text-align:right;">*10,099</td>
#  <td style="text-align:right;">72</td>
#  <td>Its apps for clients including ITV, EA Sports and Nickelodeon have engaged 60m fans in 190 countries</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>27</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/lockwood-publishing/"><span class="company-name">Lockwood Publishing</span></a>Mobile games developer</td>
#  <td>Nottingham</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">107.97%</td>
#  <td style="text-align:right;">*17,950</td>
#  <td style="text-align:right;">110</td>
#  <td>Creates mobile video games where users can customise their avatar with its own line of evening wear</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>28</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/plan-com-2/"><span class="company-name">Plan.com</span></a>Communications provider</td>
#  <td>Isle of Man</td>
#  <td>Sep 18</td>
#  <td style="text-align:right;">107.83%</td>
#  <td style="text-align:right;">*47,881</td>
#  <td style="text-align:right;">96</td>
#  <td>About 650 partners use its telecoms platform to support more than 100,000 UK business customers</td>
#  <!--						<td>Sep 18</td>-->
#  </tr>, <tr>
#  <td>29</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/capital-on-tap-3/"><span class="company-name">Capital on Tap</span></a>Business finance provider</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">100.45%</td>
#  <td style="text-align:right;">*39,285</td>
#  <td style="text-align:right;">73</td>
#  <td>Has lent over £1bn to more than 80,000 businesses across the UK</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>30</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/in-touch-networks/"><span class="company-name">In Touch Networks</span></a>Professional networking platform</td>
#  <td>Manchester</td>
#  <td>Feb 19</td>
#  <td style="text-align:right;">98.10%</td>
#  <td style="text-align:right;">*7,428</td>
#  <td style="text-align:right;">139</td>
#  <td>Its platform helps more than 125,000 members access training and find new roles</td>
#  <!--						<td>Feb 19</td>-->
#  </tr>, <tr>
#  <td>31</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/dv-signage-2/"><span class="company-name">DV Signage</span></a>Corporate AV specialist</td>
#  <td>Hertfordshire</td>
#  <td>Mar 18</td>
#  <td style="text-align:right;">97.82%</td>
#  <td style="text-align:right;">*5,150</td>
#  <td style="text-align:right;">25</td>
#  <td>Has developed a robot receptionist capable of welcoming guests and giving presentations</td>
#  <!--						<td>Mar 18</td>-->
#  </tr>, <tr>
#  <td>32</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/ogury-3/"><span class="company-name">Ogury</span></a>Mobile data marketing</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">97.77%</td>
#  <td style="text-align:right;">62,318</td>
#  <td style="text-align:right;">210</td>
#  <td>Services clients including eBay, Nike and McDonald's from 13 offices in Europe, the US and Mexico</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>33</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/chameleon-technology/"><span class="company-name">Chameleon Technology</span></a>Smart energy monitoring</td>
#  <td>Harrogate</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">97.59%</td>
#  <td style="text-align:right;">*21,752</td>
#  <td style="text-align:right;">46</td>
#  <td>More than 4m of its smart in-home displays have been installed in UK homes</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>34</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/iwoca-4/"><span class="company-name">iwoca</span></a>Business finance provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">97.06%</td>
#  <td style="text-align:right;">*47,534</td>
#  <td style="text-align:right;">230</td>
#  <td>Has raised £352.7m to date, including a £150m funding round in February</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>35</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/byte/"><span class="company-name">Byte</span></a>Marketing technology agency</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">95.79%</td>
#  <td style="text-align:right;">*18,315</td>
#  <td style="text-align:right;">96</td>
#  <td>3.6m people played an augmented reality rugby game it created for Just Eat</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>36</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/matillion/"><span class="company-name">Matillion</span></a>Data transformation software</td>
#  <td>Altrincham</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">94.13%</td>
#  <td style="text-align:right;">*6,504</td>
#  <td style="text-align:right;">87</td>
#  <td>Has around 600 customers, including GE, Siemens and Amazon, across 40 countries</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>37</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/bought-by-many-3/"><span class="company-name">Bought By Many</span></a>Specialist insurance platform</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">93.91%</td>
#  <td style="text-align:right;">*35,000</td>
#  <td style="text-align:right;">101</td>
#  <td>Launched in Sweden this year, its first overseas market for its pet insurance</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>38</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/checkout-com/"><span class="company-name">Checkout.com</span></a>Payment services provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">93.34%</td>
#  <td style="text-align:right;">*55,713</td>
#  <td style="text-align:right;">450</td>
#  <td>Raised $230m in May, the highest early-stage funding round for a fintech company in Europe</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>39</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/fleximize/"><span class="company-name">Fleximize</span></a>Business finance provider</td>
#  <td>Ipswich</td>
#  <td>Aug 18</td>
#  <td style="text-align:right;">92.54%</td>
#  <td style="text-align:right;">*8,291</td>
#  <td style="text-align:right;">40</td>
#  <td>Has provided over £100m in loans to small businesses across the UK</td>
#  <!--						<td>Aug 18</td>-->
#  </tr>, <tr>
#  <td>40</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/hyperdrive-innovation-2/"><span class="company-name">Hyperdrive Innovation</span></a>Battery technology developer</td>
#  <td>Sunderland</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">90.00%</td>
#  <td style="text-align:right;">*7,286</td>
#  <td style="text-align:right;">40</td>
#  <td>Can produce up to 30,000 battery systems a year at its Sunderland production facility</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>41</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/gocardless-3/"><span class="company-name">GoCardless</span></a>Payment services provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">89.93%</td>
#  <td style="text-align:right;">*20,133</td>
#  <td style="text-align:right;">264</td>
#  <td>Processes $10bn of payments a year on behalf of 40,000 businesses worldwide</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>42</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/azuri-technologies/"><span class="company-name">Azuri Technologies</span></a>Solar technology developer</td>
#  <td>Cambridge</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">89.85%</td>
#  <td style="text-align:right;">*8,837</td>
#  <td style="text-align:right;">80</td>
#  <td>Over 750,000 people in 12 sub-Saharan countries use its solar power systems</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>43</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/receipt-bank-3/"><span class="company-name">Receipt Bank</span></a>Bookkeeping automation services</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">89.78%</td>
#  <td style="text-align:right;">*18,619</td>
#  <td style="text-align:right;">445</td>
#  <td>250,000 businesses in America, Europe and Australia use its book-keeping software</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>44</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/gohenry-2/"><span class="company-name">gohenry</span></a>Children's pre-paid card service</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">88.25%</td>
#  <td style="text-align:right;">*8,309</td>
#  <td style="text-align:right;">96</td>
#  <td>The company is named after the first child to make a transaction with one of its cards</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>45</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/gousto-2/"><span class="company-name">Gousto</span></a>Meal kit delivery services</td>
#  <td>West London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">87.68%</td>
#  <td style="text-align:right;">*49,284</td>
#  <td style="text-align:right;">371</td>
#  <td>On track to provide the ingredients for 400m meals in UK homes by 2025</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>46</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/depop-2/"><span class="company-name">Depop</span></a>Fashion marketplace app</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">87.48%</td>
#  <td style="text-align:right;">*171,989</td>
#  <td style="text-align:right;">159</td>
#  <td>More than 15m people use its platform to buy and sell second-hand clothing</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>47</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/giacom-3/"><span class="company-name">Giacom</span></a>Cloud services provider</td>
#  <td>Hull</td>
#  <td>Jul 18</td>
#  <td style="text-align:right;">87.43%</td>
#  <td style="text-align:right;">25,104</td>
#  <td style="text-align:right;">58</td>
#  <td>Founded in 1999, the firm is celebrating its 20th anniversary this year</td>
#  <!--						<td>Jul 18</td>-->
#  </tr>, <tr>
#  <td>48</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/account-technologies/"><span class="company-name">Account Technologies</span></a>Consumer finance provider</td>
#  <td>Buckinghamshire</td>
#  <td>Aug 18</td>
#  <td style="text-align:right;">87.39%</td>
#  <td style="text-align:right;">68,212</td>
#  <td style="text-align:right;">152</td>
#  <td>Has attracted 470,000 customers and provided £1.5bn in loans since launch in 2012</td>
#  <!--						<td>Aug 18</td>-->
#  </tr>, <tr>
#  <td>49</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/gigaclear-2/"><span class="company-name">Gigaclear</span></a>Internet services provider</td>
#  <td>Oxfordshire</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">87.19%</td>
#  <td style="text-align:right;">8,979</td>
#  <td style="text-align:right;">240</td>
#  <td>Has connected more than 19,000 rural customers to broadband across the UK</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>50</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/oakbrook-3/"><span class="company-name">Oakbrook</span></a>Consumer finance provider</td>
#  <td>Nottingham</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">86.86%</td>
#  <td style="text-align:right;">53,250</td>
#  <td style="text-align:right;">103</td>
#  <td>Uses machine learning to help estimate borrowers’ credit risk</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>51</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/hyperoptic-3/"><span class="company-name">Hyperoptic</span></a>Internet services provider</td>
#  <td>West London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">86.60%</td>
#  <td style="text-align:right;">*26,900</td>
#  <td style="text-align:right;">667</td>
#  <td>Aims to provide superfast broadband to more than 2m homes by 2022</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>52</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/transferwise-7/"><span class="company-name">TransferWise</span></a>Currency transfer provider</td>
#  <td>East London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">85.96%</td>
#  <td style="text-align:right;">*179,100</td>
#  <td style="text-align:right;">1,516</td>
#  <td>Was valued at $3.5bn in November after it raised $292m, taking its funding total to $689m</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>53</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/assetz-capital-2/"><span class="company-name">Assetz Capital</span></a>Business finance provider</td>
#  <td>Manchester</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">85.77%</td>
#  <td style="text-align:right;">*16,991</td>
#  <td style="text-align:right;">99</td>
#  <td>Its 35,000 lenders have earned over £80m in interest, and funded £800m of loans and 4,000 new homes</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>54</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/darktrace-4/"><span class="company-name">Darktrace</span></a>Cyber-security developer</td>
#  <td>Cambridge</td>
#  <td>Jun 19</td>
#  <td style="text-align:right;">84.73%</td>
#  <td style="text-align:right;">*107,664</td>
#  <td style="text-align:right;">948</td>
#  <td>Was reportedly valued at $1.65bn in 2018 following a $50m funding round</td>
#  <!--						<td>Jun 19</td>-->
#  </tr>, <tr>
#  <td>55</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/payen-2/"><span class="company-name">Payen</span></a>Payment services provider</td>
#  <td>Guildford</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">80.58%</td>
#  <td style="text-align:right;">*14,211</td>
#  <td style="text-align:right;">32</td>
#  <td>The Premier Lotto in Nigeria uses the company’s platform to prevent money laundering</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>56</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/thread-2/"><span class="company-name">Thread</span></a>Online fashion services</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">80.22%</td>
#  <td style="text-align:right;">*8,137</td>
#  <td style="text-align:right;">65</td>
#  <td>Has named its AI-driven personal stylist software "Thimble"</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>57</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/superawesome-3/"><span class="company-name">SuperAwesome</span></a>Children's privacy protection</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">79.00%</td>
#  <td style="text-align:right;">*26,200</td>
#  <td style="text-align:right;">120</td>
#  <td>High-profile customers include Disney, Nintendo, Hasbro and Cartoon Network</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>58</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/vizolution-2/"><span class="company-name">Vizolution</span></a>Business software developer</td>
#  <td>Swansea</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">77.76%</td>
#  <td style="text-align:right;">*10,234</td>
#  <td style="text-align:right;">154</td>
#  <td>Its software powers RBS’s paperless mortgage process which completes over £18bn of lending each year</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>59</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/bigchange-2/"><span class="company-name">BigChange</span></a>Workforce management software</td>
#  <td>Leeds</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">77.44%</td>
#  <td style="text-align:right;">*11,206</td>
#  <td style="text-align:right;">98</td>
#  <td>Its CEO has pledged to move the company to a four-day working week by 2021</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>60</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/symetrica-3/"><span class="company-name">Symetrica</span></a>Detection equipment manufacturer</td>
#  <td>Southampton</td>
#  <td>Sep 18</td>
#  <td style="text-align:right;">74.24%</td>
#  <td style="text-align:right;">11,019</td>
#  <td style="text-align:right;">59</td>
#  <td>Its technology is used at ports across the world to detect radioactive material used in bombs</td>
#  <!--						<td>Sep 18</td>-->
#  </tr>, <tr>
#  <td>61</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/starleaf-3/"><span class="company-name">StarLeaf</span></a>Video conferencing platform</td>
#  <td>Watford</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">73.53%</td>
#  <td style="text-align:right;">*17,600</td>
#  <td style="text-align:right;">201</td>
#  <td>Its founders set up the Tech Track 100 alumnus Codian and sold it for $270m in 2007</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>62</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/azimo-2/"><span class="company-name">Azimo</span></a>Currency transfer provider</td>
#  <td>Central London</td>
#  <td>Jun 18</td>
#  <td style="text-align:right;">72.44%</td>
#  <td style="text-align:right;">10,776</td>
#  <td style="text-align:right;">120</td>
#  <td>Enables users to transfer money to more than 200 countries in 80 currencies</td>
#  <!--						<td>Jun 18</td>-->
#  </tr>, <tr>
#  <td>63</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/endomag/"><span class="company-name">Endomag</span></a>Medical device developer</td>
#  <td>Cambridge</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">72.36%</td>
#  <td style="text-align:right;">*6,284</td>
#  <td style="text-align:right;">20</td>
#  <td>Its breast tumour detection technology is used in cancer hospitals such as The Royal Marsden</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>64</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/qhi-group-2/"><span class="company-name">QHi Group</span></a>Monitoring systems developer</td>
#  <td>Hertfordshire</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">71.02%</td>
#  <td style="text-align:right;">*5,102</td>
#  <td style="text-align:right;">15</td>
#  <td>Has opened a US office on Wall Street to service its clients in North America</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>65</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/threads-styling-3/"><span class="company-name">Threads Styling</span></a>Online fashion services</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">69.84%</td>
#  <td style="text-align:right;">*17,732</td>
#  <td style="text-align:right;">91</td>
#  <td>Raised £15.7m from Highland Europe and millennial services-focused fund C Ventures in 2018</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>66</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/unify-communications/"><span class="company-name">Unify Communications</span></a>Customer service software</td>
#  <td>Bristol</td>
#  <td>Aug 18</td>
#  <td style="text-align:right;">69.33%</td>
#  <td style="text-align:right;">*5,735</td>
#  <td style="text-align:right;">21</td>
#  <td>Its software created operational savings in excess of £2m per year for Shell Energy</td>
#  <!--						<td>Aug 18</td>-->
#  </tr>, <tr>
#  <td>67</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/miq-7/"><span class="company-name">MiQ</span></a>Digital marketing agency</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">68.48%</td>
#  <td style="text-align:right;">*196,869</td>
#  <td style="text-align:right;">570</td>
#  <td>Operates globally from 15 offices in North America, Europe and Asia Pacific</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>68</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/neyber/"><span class="company-name">Neyber</span></a>Personal finance technology developer</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">66.99%</td>
#  <td style="text-align:right;">*5,700</td>
#  <td style="text-align:right;">121</td>
#  <td>Co-founder's business idea was inspired by a 'Sou-Sou', an African savings club used by his mother</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>69</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/tvsquared-2/"><span class="company-name">TVSquared</span></a>TV advertising analytics</td>
#  <td>Edinburgh</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">66.86%</td>
#  <td style="text-align:right;">*7,187</td>
#  <td style="text-align:right;">93</td>
#  <td>Tracks 175m website hits per day for over 700 brands, agencies and networks</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>70</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/the-access-group/"><span class="company-name">The Access Group</span></a>Business software developer</td>
#  <td>Central London</td>
#  <td>Jun 18</td>
#  <td style="text-align:right;">66.83%</td>
#  <td style="text-align:right;">143,135</td>
#  <td style="text-align:right;">1,332</td>
#  <td>It was valued at £1bn last year after an undisclosed investment from HgCapital</td>
#  <!--						<td>Jun 18</td>-->
#  </tr>, <tr>
#  <td>71</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/contactengine/"><span class="company-name">ContactEngine</span></a>Conversational AI technology</td>
#  <td>Central London</td>
#  <td>Oct 18</td>
#  <td style="text-align:right;">66.34%</td>
#  <td style="text-align:right;">*6,684</td>
#  <td style="text-align:right;">57</td>
#  <td>Has an AI advisory board, chaired by a former UK government chief scientific adviser</td>
#  <!--						<td>Oct 18</td>-->
#  </tr>, <tr>
#  <td>72</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/hutch-3/"><span class="company-name">Hutch</span></a>Mobile games developer</td>
#  <td>Central London</td>
#  <td>Sep 18</td>
#  <td style="text-align:right;">65.97%</td>
#  <td style="text-align:right;">*11,585</td>
#  <td style="text-align:right;">68</td>
#  <td>Has secured a worldwide partnership with Formula 1 to create racing games for iOS and Android</td>
#  <!--						<td>Sep 18</td>-->
#  </tr>, <tr>
#  <td>73</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/sideshow/"><span class="company-name">Sideshow</span></a>Digital marketing agency</td>
#  <td>Bournemouth</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">65.93%</td>
#  <td style="text-align:right;">*21,744</td>
#  <td style="text-align:right;">180</td>
#  <td>Works with clients including KFC, BT and Tesco to improve customer experience</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>74</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/optal-8/"><span class="company-name">Optal</span></a>Payment services provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">65.90%</td>
#  <td style="text-align:right;">*269,640</td>
#  <td style="text-align:right;">75</td>
#  <td>Uses the Mastercard processing network to facilitate payments in 34 currencies</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>75</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/leisure-pass-group-11/"><span class="company-name">Leisure Pass Group</span></a>Tourism smartcard provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">62.95%</td>
#  <td style="text-align:right;">*276,790</td>
#  <td style="text-align:right;">121</td>
#  <td>Its technology processes more than 16m visits a year to sightseeing destinations worldwide</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>76</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/brompton-technology-3/"><span class="company-name">Brompton Technology</span></a>Video technology provider</td>
#  <td>West London</td>
#  <td>Aug 18</td>
#  <td style="text-align:right;">61.86%</td>
#  <td style="text-align:right;">*7,202</td>
#  <td style="text-align:right;">30</td>
#  <td>Musicians Drake and Ed Sheeran have used its equipment on their international tours</td>
#  <!--						<td>Aug 18</td>-->
#  </tr>, <tr>
#  <td>77</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/iplato/"><span class="company-name">iPlato</span></a>Healthcare app developer</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">61.24%</td>
#  <td style="text-align:right;">*5,450</td>
#  <td style="text-align:right;">62</td>
#  <td>Its myGP app is used to order one repeat prescription every minute</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>78</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/currencycloud-2/"><span class="company-name">Currencycloud</span></a>Payment services provider</td>
#  <td>East London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">60.87%</td>
#  <td style="text-align:right;">*20,351</td>
#  <td style="text-align:right;">190</td>
#  <td>Has processed more than $50bn in payments to over 180 countries</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>79</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/tharsus/"><span class="company-name">Tharsus</span></a>Robot designer and manufacturer</td>
#  <td>Northumberland</td>
#  <td>Nov 18</td>
#  <td style="text-align:right;">60.85%</td>
#  <td style="text-align:right;">51,178</td>
#  <td style="text-align:right;">264</td>
#  <td>Manufactures robots that pick and carry groceries at Ocado's automated warehouses</td>
#  <!--						<td>Nov 18</td>-->
#  </tr>, <tr>
#  <td>80</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/ensek-2/"><span class="company-name">ENSEK</span></a>Energy software developer</td>
#  <td>Nottingham</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">60.80%</td>
#  <td style="text-align:right;">*8,677</td>
#  <td style="text-align:right;">129</td>
#  <td>Counts the former managing director of British Gas, Ian Peters, as its chairman</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>81</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/captify-3/"><span class="company-name">Captify</span></a>Advertising technology company</td>
#  <td>Central London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">58.86%</td>
#  <td style="text-align:right;">*43,048</td>
#  <td style="text-align:right;">197</td>
#  <td>Provides data and marketing insights for over 800 brands including Disney, Apple and Adidas</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>82</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/adaptive-3/"><span class="company-name">Adaptive</span></a>Banking technology developer</td>
#  <td>Central London</td>
#  <td>Jun 19</td>
#  <td style="text-align:right;">58.56%</td>
#  <td style="text-align:right;">*28,151</td>
#  <td style="text-align:right;">214</td>
#  <td>Has more than 200 staff across offices in London, Barcelona, Montreal and New York</td>
#  <!--						<td>Jun 19</td>-->
#  </tr>, <tr>
#  <td>83</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/student-beans/"><span class="company-name">Student Beans</span></a>Student loyalty network</td>
#  <td>Central London</td>
#  <td>Jun 19</td>
#  <td style="text-align:right;">57.62%</td>
#  <td style="text-align:right;">*7,106</td>
#  <td style="text-align:right;">107</td>
#  <td>Says it helped students save on 72,856 mobile phones and 539,214 pairs of shoes in 12 months</td>
#  <!--						<td>Jun 19</td>-->
#  </tr>, <tr>
#  <td>84</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/godel-technologies-3/"><span class="company-name">Godel Technologies</span></a>Software developer</td>
#  <td>Manchester</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">57.21%</td>
#  <td style="text-align:right;">*21,711</td>
#  <td style="text-align:right;">732</td>
#  <td>Is named after the late German mathematician Kurt Gödel</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>85</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/mpb/"><span class="company-name">MPB</span></a>Photography equipment trading platform</td>
#  <td>Brighton</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">56.21%</td>
#  <td style="text-align:right;">*31,909</td>
#  <td style="text-align:right;">125</td>
#  <td>Building an operational centre in New York to service its US customers</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>86</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/smartsearch/"><span class="company-name">Smartsearch</span></a>Anti-fraud technology developer</td>
#  <td>Leeds</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">56.21%</td>
#  <td style="text-align:right;">8,129</td>
#  <td style="text-align:right;">82</td>
#  <td>Its anti-money laundering services are used by more than 4,000 client firms and 40,000 users around the world</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>87</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/liberis-2/"><span class="company-name">Liberis</span></a>Business finance provider</td>
#  <td>West London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">56.07%</td>
#  <td style="text-align:right;">*21,090</td>
#  <td style="text-align:right;">105</td>
#  <td>Its intelligent pricing tool uses machine learning to give customers bespoke pricing</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>88</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/cloudthing/"><span class="company-name">cloudThing</span></a>Software developer</td>
#  <td>West Midlands</td>
#  <td>Jan 19</td>
#  <td style="text-align:right;">55.84%</td>
#  <td style="text-align:right;">*6,056</td>
#  <td style="text-align:right;">41</td>
#  <td>Delivers IT transformation projects for the British Red Cross and Metropolitan Police</td>
#  <!--						<td>Jan 19</td>-->
#  </tr>, <tr>
#  <td>89</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/zappi/"><span class="company-name">Zappi</span></a>Consumer insights platform</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">55.19%</td>
#  <td style="text-align:right;">24,760</td>
#  <td style="text-align:right;">189</td>
#  <td>Holds weekly hackathons with its clients and programmers</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>90</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/ticketer/"><span class="company-name">Ticketer</span></a>Electronic ticket machine developer</td>
#  <td>Hungerford</td>
#  <td>Aug 18</td>
#  <td style="text-align:right;">53.83%</td>
#  <td style="text-align:right;">14,692</td>
#  <td style="text-align:right;">55</td>
#  <td>Over 2 billion tickets have been purchased via its electronic ticketing machines</td>
#  <!--						<td>Aug 18</td>-->
#  </tr>, <tr>
#  <td>91</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/pharmacy-2u/"><span class="company-name">Pharmacy 2U</span></a>Online pharmacy</td>
#  <td>Leeds</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">53.02%</td>
#  <td style="text-align:right;">*61,022</td>
#  <td style="text-align:right;">299</td>
#  <td>Uses proprietary algorithms and warehouse automation to increase accuracy in medicine dispensing</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>92</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/adaptavist/"><span class="company-name">Adaptavist</span></a>IT consultancy</td>
#  <td>Central London</td>
#  <td>Sep 18</td>
#  <td style="text-align:right;">52.46%</td>
#  <td style="text-align:right;">*26,704</td>
#  <td style="text-align:right;">162</td>
#  <td>Says it works with more than half of Fortune 500 companies</td>
#  <!--						<td>Sep 18</td>-->
#  </tr>, <tr>
#  <td>93</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/alternative-airlines/"><span class="company-name">Alternative Airlines</span></a>Flight booking website</td>
#  <td>Surrey</td>
#  <td>Oct 18</td>
#  <td style="text-align:right;">51.49%</td>
#  <td style="text-align:right;">*9,985</td>
#  <td style="text-align:right;">30</td>
#  <td>Offers mobile payment solutions for customers from developing countries</td>
#  <!--						<td>Oct 18</td>-->
#  </tr>, <tr>
#  <td>94</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/biosite-systems-2/"><span class="company-name">Biosite Systems</span></a>Workforce management software</td>
#  <td>Solihull</td>
#  <td>Jul 18</td>
#  <td style="text-align:right;">51.33%</td>
#  <td style="text-align:right;">9,756</td>
#  <td style="text-align:right;">165</td>
#  <td>Its technology is used on 1,000 construction sites, including Hinkley Point C nuclear power station</td>
#  <!--						<td>Jul 18</td>-->
#  </tr>, <tr>
#  <td>95</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/justpark-2/"><span class="company-name">JustPark</span></a>Smart parking provider</td>
#  <td>North London</td>
#  <td>Mar 19</td>
#  <td style="text-align:right;">50.70%</td>
#  <td style="text-align:right;">*24,285</td>
#  <td style="text-align:right;">70</td>
#  <td>Over 3m drivers use its app to find car parking spaces across the UK</td>
#  <!--						<td>Mar 19</td>-->
#  </tr>, <tr>
#  <td>96</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/worldremit-4/"><span class="company-name">WorldRemit</span></a>Currency transfer provider</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">50.26%</td>
#  <td style="text-align:right;">*90,965</td>
#  <td style="text-align:right;">615</td>
#  <td>Is valued at more than $900m, having raised more than $375m since 2010</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>97</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/e3d-online-2/"><span class="company-name">E3D Online</span></a>3D printer developer</td>
#  <td>Oxfordshire</td>
#  <td>Apr 19</td>
#  <td style="text-align:right;">50.10%</td>
#  <td style="text-align:right;">*6,900</td>
#  <td style="text-align:right;">41</td>
#  <td>Has grown its exports to account for 75% of its total sales</td>
#  <!--						<td>Apr 19</td>-->
#  </tr>, <tr>
#  <td>98</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/parentpay-2/"><span class="company-name">Parentpay</span></a>School payment services provider</td>
#  <td>Coventry</td>
#  <td>Nov 18</td>
#  <td style="text-align:right;">49.97%</td>
#  <td style="text-align:right;">*30,400</td>
#  <td style="text-align:right;">210</td>
#  <td>Bought Dutch rival WIS in 2018, gaining access to 85% of the secondary school market in the Netherlands</td>
#  <!--						<td>Nov 18</td>-->
#  </tr>, <tr>
#  <td>99</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/victor-6/"><span class="company-name">Victor</span></a>Online private jet hire</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">49.56%</td>
#  <td style="text-align:right;">*55,100</td>
#  <td style="text-align:right;">100</td>
#  <td>Counts Sir Elton John among its investors</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>, <tr>
#  <td>100</td>
#  <td><a href="https://www.fasttrack.co.uk/company_profile/dianomi-5/"><span class="company-name">Dianomi</span></a>Financial marketing platform</td>
#  <td>Central London</td>
#  <td>Dec 18</td>
#  <td style="text-align:right;">49.21%</td>
#  <td style="text-align:right;">*14,615</td>
#  <td style="text-align:right;">27</td>
#  <td>Works with eight of the top 10 global asset managers</td>
#  <!--						<td>Dec 18</td>-->
#  </tr>]

# %%
# loop over results
for result in results:
    # find all columns per result
    data = result.find_all('td')
    # check that columns have data 
    if len(data) == 0: 
        continue
        
    # write columns to variables
    rank = data[0].getText()
    company = data[1].getText()
    location = data[2].getText()
    yearend = data[3].getText()
    salesrise = data[4].getText()
    sales = data[5].getText()
    staff = data[6].getText()
    comments = data[7].getText()
    
#     print('Company is', company) 
#     print('Sales', sales)
    
    
    # extract description from the name
    companyname = data[1].find('span', attrs={'class':'company-name'}).getText()    
    description = company.replace(companyname, '')
    
    # remove unwanted characters
    sales = sales.strip('*').strip('†').replace(',','')
    
    
    # go to link and extract company website
    url = data[1].find('a').get('href')
    page = urllib.request.urlopen(url)
    # parse the html 
    soup = bsoup(page, 'html.parser')
    # find the last result in the table and get the link
    try:
        tableRow = soup.find('table').find_all('tr')[-1]
        webpage = tableRow.find('a').get('href')
    except:
        webpage = None
        
    # write each result to rows
    rows.append([rank, companyname, webpage, description, location, yearend, salesrise, sales, staff, comments])
## print(rows)

# %%
for row in rows:
    print(row)
# Out:
# ['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments']
# ['1', 'Revolut', 'http://www.revolut.com', 'Digital banking services provider', 'East London', 'Dec 18', '507.56%', '58300', '700', 'Valued at $1.7bn in 2018 and reported to be raising an additional $500m this year that could value it at $5bn']
# ['2', 'Bizuma', 'http://www.bizuma.com', 'B2B e-commerce platform', 'Central London', 'Mar 19', '315.18%', '26414', '114', 'Connects wholesale buyers and sellers from over 50 countries']
# ['3', 'Global-e', 'http://www.global-e.com', 'Cross-border ecommerce solutions', 'Central London', 'Dec 18', '303.09%', '29297', '28', 'Its technology helps ecommerce retailers localise their websites in more than 200 markets']
# ['4', 'Jungle Creations', 'http://www.junglecreations.com', 'Social media & ecommerce services', 'East London', 'Dec 18', '302.53%', '15972', '159', 'Launched the first-ever delivery-only restaurant born from social media']
# ['5', 'Oxford Nanopore Technologies', 'http://www.nanoporetech.com', 'DNA analysis technology', 'Oxford', 'Dec 18', '251.87%', '32500', '439', 'Has raised £451m in funding and was valued at £1.5bn last year']
# ['6', 'Lendable', 'http://www.lendable.co.uk', 'Consumer lending platform', 'Central London', 'Dec 18', '242.98%', '19366', '44', 'Founder moved to the UK from Germany to start the firm, citing a more favourable financial market']
# ['7', 'Verve', 'http://www.verve.co', 'Marketing software developer', 'Central London', 'Dec 18', '235.72%', '21940', '230', 'Has implemented full salary transparency in order to combat the gender pay gap']
# ['8', 'Onfido', 'http://www.onfido.com', 'Identity verification software', 'Central London', 'Dec 18', '209.15%', '18591', '240', 'Has opened offices in the US, Europe, India and Singapore to service its 1,500 customers']
# ['9', 'Reverse Media Group', 'http://www.reversemediagroup.com', 'Digital publishing agency', 'Central London', 'Jul 18', '208.10%', '7606', '15', 'Originally started as an animal onesie clothing company before pivoting to online publishing']
# ['10', 'Rebound Returns', 'http://www.reboundreturns.com', 'Ecommerce returns technology', 'Telford', 'Dec 18', '191.08%', '16659', '21', 'Its platform handles more than 35m online returns transactions every year']
# ['11', 'ClearScore', 'http://www.clearscore.com', 'Credit-checking technology developer', 'South London', 'Dec 18', '177.20%', '42702', '135', 'In 2018, £90m worth of mortgages were secured through its site']
# ['12', 'SPOKE', 'http://www.spoke-london.com', 'Online menswear supplier', 'Richmond', 'Oct 18', '177.10%', '5566', '36', 'Its technology helps customers find the right fit out of 200 clothing size options in just 60 seconds']
# ['13', 'FSB', 'http://www.fsbtech.com', 'Gambling platform', 'Central London', 'Dec 18', '175.54%', '23945', '93', "Has moved into William Hill's old R&D offices in Shoreditch"]
# ['14', 'Decibel', 'http://www.decibelinsight.com', 'Customer experience technology', 'Central London', 'Jun 18', '165.81%', '5387', '68', 'Uses AI and machine learning to detect consumers’ feelings of confusion, frustration and engagement']
# ['15', 'Miss Group', 'http://www.missgroup.com', 'Web hosting provider', 'Manchester', 'Dec 18', '162.06%', '6925', '55', 'Has made four acquisitions in the last year, with £19.4m investment from growth-capital firm BGF']
# ['16', 'ComplyAdvantage', 'http://www.complyadvantage.com', 'Anti-money laundering database', 'Central London', 'Mar 19', '160.61%', '5981', '165', 'Its platform helps 450 customers in 45 countries address compliance issues']
# ['17', 'OTA Insight', 'http://www.otainsight.com', 'Hospitality technology provider', 'Central London', 'Dec 18', '158.14%', '10295', '105', "Works with over 40,000 hotels in 126 countries, including some of the world's largest hotel groups"]
# ['18', 'Light Source', 'http://www.lightsourceuk.net', 'Telecoms infrastructure builder', 'Nottinghamshire', 'Mar 18', '146.90%', '31098', '96', 'Developing a pneumatic rocket launcher that can lay fibre cable 500m from its launch site']
# ['19', 'Digi2al', 'http://www.digi2al.com', 'Digital technology developer', 'Central London', 'Jan 19', '141.56%', '14394', '11', 'Called Digi2al because its software development team works in two-week sprints']
# ['20', 'Perkbox', 'http://www.perkbox.com', 'Employee engagement services', 'Central London', 'Dec 18', '131.50%', '53600', '250', 'Raised £13.5m in April to boost its expansion in Australia and France']
# ['21', 'Lending Works', 'http://www.lendingworks.co.uk', 'Peer-to-peer lender', 'Central London', 'Dec 18', '128.54%', '6178', '42', 'Aiming to reach £1bn in loan volume by 2023']
# ['22', 'Faculty', 'http://www.faculty.ai', 'AI software developer', 'Central London', 'Mar 19', '125.91%', '5193', '65', 'Has worked on more than 300 AI projects for clients including easyJet, Tesco and the BBC']
# ['23', 'Internet Mobile Communications', 'http://www.im-comms.com', 'Telecoms services provider', 'Chelmsford', 'Jun 19', '122.54%', '60241', '32', 'Has offices in Chile and Moldova as well as its Essex headquarters']
# ['24', 'Fruugo', 'http://www.fruugo.co.uk', 'Online shopping platform', 'Cumbria', 'Dec 18', '116.00%', '6661', '35', 'Its site has been used by 2m shoppers in 17 languages and 32 countries']
# ['25', 'Featurespace', 'http://www.featurespace.com', 'Analytics software developer', 'Cambridge', 'Dec 18', '110.71%', '9953', '200', 'Its anti-fraud technology is used by 19 banks across Europe, the US and Latin America']
# ['26', 'Monterosa', 'http://www.monterosa.co.uk', 'Audience interaction platform', 'Central London', 'Mar 19', '109.56%', '10099', '72', 'Its apps for clients including ITV, EA Sports and Nickelodeon have engaged 60m fans in 190 countries']
# ['27', 'Lockwood Publishing', 'http://www.lockwoodpublishing.com', 'Mobile games developer', 'Nottingham', 'Mar 19', '107.97%', '17950', '110', 'Creates mobile video games where users can customise their avatar with its own line of evening wear']
# ['28', 'Plan.com', 'http://www.plan.com', 'Communications provider', 'Isle of Man', 'Sep 18', '107.83%', '47881', '96', 'About 650 partners use its telecoms platform to support more than 100,000 UK business customers']
# ['29', 'Capital on Tap', 'http://www.capitalontap.com', 'Business finance provider', 'Central London', 'Mar 19', '100.45%', '39285', '73', 'Has lent over £1bn to more than 80,000 businesses across the UK']
# ['30', 'In Touch Networks', 'http://www.intouchnetworks.com', 'Professional networking platform', 'Manchester', 'Feb 19', '98.10%', '7428', '139', 'Its platform helps more than 125,000 members access training and find new roles']
# ['31', 'DV Signage', 'http://www.dvsignage.com', 'Corporate AV specialist', 'Hertfordshire', 'Mar 18', '97.82%', '5150', '25', 'Has developed a robot receptionist capable of welcoming guests and giving presentations']
# ['32', 'Ogury', 'http://www.ogury.com', 'Mobile data marketing', 'East London', 'Dec 18', '97.77%', '62318', '210', "Services clients including eBay, Nike and McDonald's from 13 offices in Europe, the US and Mexico"]
# ['33', 'Chameleon Technology', 'http://www.chameleontechnology.co.uk', 'Smart energy monitoring', 'Harrogate', 'Dec 18', '97.59%', '21752', '46', 'More than 4m of its smart in-home displays have been installed in UK homes']
# ['34', 'iwoca', 'http://www.iwoca.co.uk', 'Business finance provider', 'Central London', 'Dec 18', '97.06%', '47534', '230', 'Has raised £352.7m to date, including a £150m funding round in February']
# ['35', 'Byte', 'http://www.bytelondon.com', 'Marketing technology agency', 'Central London', 'Dec 18', '95.79%', '18315', '96', '3.6m people played an augmented reality rugby game it created for Just Eat']
# ['36', 'Matillion', 'http://www.matillion.com', 'Data transformation software', 'Altrincham', 'Dec 18', '94.13%', '6504', '87', 'Has around 600 customers, including GE, Siemens and Amazon, across 40 countries']
# ['37', 'Bought By Many', 'http://www.boughtbymany.com', 'Specialist insurance platform', 'Central London', 'Mar 19', '93.91%', '35000', '101', 'Launched in Sweden this year, its first overseas market for its pet insurance']
# ['38', 'Checkout.com', 'http://www.checkout.com', 'Payment services provider', 'Central London', 'Dec 18', '93.34%', '55713', '450', 'Raised $230m in May, the highest early-stage funding round for a fintech company in Europe']
# ['39', 'Fleximize', 'http://www.fleximize.com', 'Business finance provider', 'Ipswich', 'Aug 18', '92.54%', '8291', '40', 'Has provided over £100m in loans to small businesses across the UK']
# ['40', 'Hyperdrive Innovation', 'http://www.hyperdriveinnovation.com', 'Battery technology developer', 'Sunderland', 'Mar 19', '90.00%', '7286', '40', 'Can produce up to 30,000 battery systems a year at its Sunderland production facility']
# ['41', 'GoCardless', 'http://www.gocardless.com', 'Payment services provider', 'Central London', 'Dec 18', '89.93%', '20133', '264', 'Processes $10bn of payments a year on behalf of 40,000 businesses worldwide']
# ['42', 'Azuri Technologies', 'http://www.azuri-technologies.com', 'Solar technology developer', 'Cambridge', 'Dec 18', '89.85%', '8837', '80', 'Over 750,000 people in 12 sub-Saharan countries use its solar power systems']
# ['43', 'Receipt Bank', 'http://www.receipt-bank.com', 'Bookkeeping automation services', 'Central London', 'Dec 18', '89.78%', '18619', '445', '250,000 businesses in America, Europe and Australia use its book-keeping software']
# ['44', 'gohenry', 'http://www.gohenry.co.uk', "Children's pre-paid card service", 'Central London', 'Dec 18', '88.25%', '8309', '96', 'The company is named after the first child to make a transaction with one of its cards']
# ['45', 'Gousto', 'http://www.gousto.co.uk', 'Meal kit delivery services', 'West London', 'Dec 18', '87.68%', '49284', '371', 'On track to provide the ingredients for 400m meals in UK homes by 2025']
# ['46', 'Depop', 'http://www.depop.com', 'Fashion marketplace app', 'Central London', 'Dec 18', '87.48%', '171989', '159', 'More than 15m people use its platform to buy and sell second-hand clothing']
# ['47', 'Giacom', 'http://www.cloudmarket.com', 'Cloud services provider', 'Hull', 'Jul 18', '87.43%', '25104', '58', 'Founded in 1999, the firm is celebrating its 20th anniversary this year']
# ['48', 'Account Technologies', 'http://www.accounttechnologies.com', 'Consumer finance provider', 'Buckinghamshire', 'Aug 18', '87.39%', '68212', '152', 'Has attracted 470,000 customers and provided £1.5bn in loans since launch in 2012']
# ['49', 'Gigaclear', 'http://www.gigaclear.com', 'Internet services provider', 'Oxfordshire', 'Dec 18', '87.19%', '8979', '240', 'Has connected more than 19,000 rural customers to broadband across the UK']
# ['50', 'Oakbrook', 'http://www.oakbrookfinance.com', 'Consumer finance provider', 'Nottingham', 'Dec 18', '86.86%', '53250', '103', 'Uses machine learning to help estimate borrowers’ credit risk']
# ['51', 'Hyperoptic', 'http://www.hyperoptic.com', 'Internet services provider', 'West London', 'Dec 18', '86.60%', '26900', '667', 'Aims to provide superfast broadband to more than 2m homes by 2022']
# ['52', 'TransferWise', 'http://www.transferwise.com', 'Currency transfer provider', 'East London', 'Mar 19', '85.96%', '179100', '1,516', 'Was valued at $3.5bn in November after it raised $292m, taking its funding total to $689m']
# ['53', 'Assetz Capital', 'http://www.assetzcapital.co.uk', 'Business finance provider', 'Manchester', 'Mar 19', '85.77%', '16991', '99', 'Its 35,000 lenders have earned over £80m in interest, and funded £800m of loans and 4,000 new homes']
# ['54', 'Darktrace', 'http://www.darktrace.com', 'Cyber-security developer', 'Cambridge', 'Jun 19', '84.73%', '107664', '948', 'Was reportedly valued at $1.65bn in 2018 following a $50m funding round']
# ['55', 'Payen', 'http://www.payen.com', 'Payment services provider', 'Guildford', 'Mar 19', '80.58%', '14211', '32', 'The Premier Lotto in Nigeria uses the company’s platform to prevent money laundering']
# ['56', 'Thread', 'http://www.thread.com', 'Online fashion services', 'Central London', 'Dec 18', '80.22%', '8137', '65', 'Has named its AI-driven personal stylist software "Thimble"']
# ['57', 'SuperAwesome', 'http://www.superawesome.tv', "Children's privacy protection", 'Central London', 'Dec 18', '79.00%', '26200', '120', 'High-profile customers include Disney, Nintendo, Hasbro and Cartoon Network']
# ['58', 'Vizolution', 'http://www.vizolution.co.uk', 'Business software developer', 'Swansea', 'Dec 18', '77.76%', '10234', '154', 'Its software powers RBS’s paperless mortgage process which completes over £18bn of lending each year']
# ['59', 'BigChange', 'http://www.bigchangeapps.com', 'Workforce management software', 'Leeds', 'Dec 18', '77.44%', '11206', '98', 'Its CEO has pledged to move the company to a four-day working week by 2021']
# ['60', 'Symetrica', 'http://www.symetrica.com', 'Detection equipment manufacturer', 'Southampton', 'Sep 18', '74.24%', '11019', '59', 'Its technology is used at ports across the world to detect radioactive material used in bombs']
# ['61', 'StarLeaf', 'http://www.starleaf.com', 'Video conferencing platform', 'Watford', 'Dec 18', '73.53%', '17600', '201', 'Its founders set up the Tech Track 100 alumnus Codian and sold it for $270m in 2007']
# ['62', 'Azimo', 'http://www.azimo.com', 'Currency transfer provider', 'Central London', 'Jun 18', '72.44%', '10776', '120', 'Enables users to transfer money to more than 200 countries in 80 currencies']
# ['63', 'Endomag', 'http://www.endomag.com', 'Medical device developer', 'Cambridge', 'Dec 18', '72.36%', '6284', '20', 'Its breast tumour detection technology is used in cancer hospitals such as The Royal Marsden']
# ['64', 'QHi Group', 'http://www.qhigroup.com', 'Monitoring systems developer', 'Hertfordshire', 'Mar 19', '71.02%', '5102', '15', 'Has opened a US office on Wall Street to service its clients in North America']
# ['65', 'Threads Styling', 'http://www.threadsstyling.com', 'Online fashion services', 'East London', 'Dec 18', '69.84%', '17732', '91', 'Raised £15.7m from Highland Europe and millennial services-focused fund C Ventures in 2018']
# ['66', 'Unify Communications', 'http://www.unifyus.com', 'Customer service software', 'Bristol', 'Aug 18', '69.33%', '5735', '21', 'Its software created operational savings in excess of £2m per year for Shell Energy']
# ['67', 'MiQ', 'http://www.wearemiq.com', 'Digital marketing agency', 'Central London', 'Dec 18', '68.48%', '196869', '570', 'Operates globally from 15 offices in North America, Europe and Asia Pacific']
# ['68', 'Neyber', 'http://www.neyber.co.uk', 'Personal finance technology developer', 'Central London', 'Mar 19', '66.99%', '5700', '121', "Co-founder's business idea was inspired by a 'Sou-Sou', an African savings club used by his mother"]
# ['69', 'TVSquared', 'http://www.tvsquared.com', 'TV advertising analytics', 'Edinburgh', 'Dec 18', '66.86%', '7187', '93', 'Tracks 175m website hits per day for over 700 brands, agencies and networks']
# ['70', 'The Access Group', 'http://www.theaccessgroup.com', 'Business software developer', 'Central London', 'Jun 18', '66.83%', '143135', '1,332', 'It was valued at £1bn last year after an undisclosed investment from HgCapital']
# ['71', 'ContactEngine', 'http://www.contactengine.com', 'Conversational AI technology', 'Central London', 'Oct 18', '66.34%', '6684', '57', 'Has an AI advisory board, chaired by a former UK government chief scientific adviser']
# ['72', 'Hutch', 'http://www.hutchgames.com', 'Mobile games developer', 'Central London', 'Sep 18', '65.97%', '11585', '68', 'Has secured a worldwide partnership with Formula 1 to create racing games for iOS and Android']
# ['73', 'Sideshow', 'http://www.sideshowagency.com', 'Digital marketing agency', 'Bournemouth', 'Mar 19', '65.93%', '21744', '180', 'Works with clients including KFC, BT and Tesco to improve customer experience']
# ['74', 'Optal', 'http://www.optal.com', 'Payment services provider', 'Central London', 'Dec 18', '65.90%', '269640', '75', 'Uses the Mastercard processing network to facilitate payments in 34 currencies']
# ['75', 'Leisure Pass Group', 'http://www.leisurepassgroup.com', 'Tourism smartcard provider', 'Central London', 'Dec 18', '62.95%', '276790', '121', 'Its technology processes more than 16m visits a year to sightseeing destinations worldwide']
# ['76', 'Brompton Technology', 'http://www.bromptontech.com', 'Video technology provider', 'West London', 'Aug 18', '61.86%', '7202', '30', 'Musicians Drake and Ed Sheeran have used its equipment on their international tours']
# ['77', 'iPlato', 'http://www.iplato.net', 'Healthcare app developer', 'Central London', 'Dec 18', '61.24%', '5450', '62', 'Its myGP app is used to order one repeat prescription every minute']
# ['78', 'Currencycloud', 'http://www.thecurrencycloud.com', 'Payment services provider', 'East London', 'Dec 18', '60.87%', '20351', '190', 'Has processed more than $50bn in payments to over 180 countries']
# ['79', 'Tharsus', 'http://www.tharsus.co.uk', 'Robot designer and manufacturer', 'Northumberland', 'Nov 18', '60.85%', '51178', '264', "Manufactures robots that pick and carry groceries at Ocado's automated warehouses"]
# ['80', 'ENSEK', 'http://www.ensek.co.uk', 'Energy software developer', 'Nottingham', 'Mar 19', '60.80%', '8677', '129', 'Counts the former managing director of British Gas, Ian Peters, as its chairman']
# ['81', 'Captify', 'http://www.captify.co.uk', 'Advertising technology company', 'Central London', 'Mar 19', '58.86%', '43048', '197', 'Provides data and marketing insights for over 800 brands including Disney, Apple and Adidas']
# ['82', 'Adaptive', 'http://www.weareadaptive.com', 'Banking technology developer', 'Central London', 'Jun 19', '58.56%', '28151', '214', 'Has more than 200 staff across offices in London, Barcelona, Montreal and New York']
# ['83', 'Student Beans', 'http://www.studentbeans.com', 'Student loyalty network', 'Central London', 'Jun 19', '57.62%', '7106', '107', 'Says it helped students save on 72,856 mobile phones and 539,214 pairs of shoes in 12 months']
# ['84', 'Godel Technologies', 'http://www.godeltech.com', 'Software developer', 'Manchester', 'Dec 18', '57.21%', '21711', '732', 'Is named after the late German mathematician Kurt Gödel']
# ['85', 'MPB', 'http://www.mpb.com', 'Photography equipment trading platform', 'Brighton', 'Mar 19', '56.21%', '31909', '125', 'Building an operational centre in New York to service its US customers']
# ['86', 'Smartsearch', 'https://www.smartsearch.com/', 'Anti-fraud technology developer', 'Leeds', 'Dec 18', '56.21%', '8129', '82', 'Its anti-money laundering services are used by more than 4,000 client firms and 40,000 users around the world']
# ['87', 'Liberis', 'http://www.liberis.co.uk', 'Business finance provider', 'West London', 'Dec 18', '56.07%', '21090', '105', 'Its intelligent pricing tool uses machine learning to give customers bespoke pricing']
# ['88', 'cloudThing', 'http://www.cloudthing.com', 'Software developer', 'West Midlands', 'Jan 19', '55.84%', '6056', '41', 'Delivers IT transformation projects for the British Red Cross and Metropolitan Police']
# ['89', 'Zappi', 'http://www.zappi.io', 'Consumer insights platform', 'Central London', 'Dec 18', '55.19%', '24760', '189', 'Holds weekly hackathons with its clients and programmers']
# ['90', 'Ticketer', 'http://www.ticketer.co.uk', 'Electronic ticket machine developer', 'Hungerford', 'Aug 18', '53.83%', '14692', '55', 'Over 2 billion tickets have been purchased via its electronic ticketing machines']
# ['91', 'Pharmacy 2U', 'http://www.pharmacy2u.co.uk', 'Online pharmacy', 'Leeds', 'Mar 19', '53.02%', '61022', '299', 'Uses proprietary algorithms and warehouse automation to increase accuracy in medicine dispensing']
# ['92', 'Adaptavist', 'http://www.adaptavist.com', 'IT consultancy', 'Central London', 'Sep 18', '52.46%', '26704', '162', 'Says it works with more than half of Fortune 500 companies']
# ['93', 'Alternative Airlines', 'http://www.alternativeairlines.com', 'Flight booking website', 'Surrey', 'Oct 18', '51.49%', '9985', '30', 'Offers mobile payment solutions for customers from developing countries']
# ['94', 'Biosite Systems', 'http://www.biositesystems.com', 'Workforce management software', 'Solihull', 'Jul 18', '51.33%', '9756', '165', 'Its technology is used on 1,000 construction sites, including Hinkley Point C nuclear power station']
# ['95', 'JustPark', 'http://www.justpark.com', 'Smart parking provider', 'North London', 'Mar 19', '50.70%', '24285', '70', 'Over 3m drivers use its app to find car parking spaces across the UK']
# ['96', 'WorldRemit', 'http://www.worldremit.com', 'Currency transfer provider', 'Central London', 'Dec 18', '50.26%', '90965', '615', 'Is valued at more than $900m, having raised more than $375m since 2010']
# ['97', 'E3D Online', 'http://www.e3d-online.com', '3D printer developer', 'Oxfordshire', 'Apr 19', '50.10%', '6900', '41', 'Has grown its exports to account for 75% of its total sales']
# ['98', 'Parentpay', 'http://www.parentpay.com', 'School payment services provider', 'Coventry', 'Nov 18', '49.97%', '30400', '210', 'Bought Dutch rival WIS in 2018, gaining access to 85% of the secondary school market in the Netherlands']
# ['99', 'Victor', 'http://www.flyvictor.com', 'Online private jet hire', 'Central London', 'Dec 18', '49.56%', '55100', '100', 'Counts Sir Elton John among its investors']
# ['100', 'Dianomi', 'http://www.dianomi.com', 'Financial marketing platform', 'Central London', 'Dec 18', '49.21%', '14615', '27', 'Works with eight of the top 10 global asset managers']

# %%
# Create csv and write rows to output file
with open('techtrack100.csv','w', newline='') as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerows(rows)
